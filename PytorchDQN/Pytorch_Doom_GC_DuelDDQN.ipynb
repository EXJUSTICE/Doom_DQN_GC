# %% [markdown]
# # Automated Doom with Dueling Double Deep Q-learning, in Pytorch
#
# A Colaboratory notebook for GradientCrescent, by Adrian Yijie Xu.
#
# If you enjoyed this notebook, please consider leaving a star on the GradientCrescent Github (https://github.com/EXJUSTICE/GradientCrescent), and visting the publication for more articles on applied and theoretical aspects of AI (https://medium.com/@adrianitsaxu).

# %% [markdown]
# ## Setup
#
# First we import all the necessary libraries. This may take a significant time, but should only be done once per session. After execution, make sure to restart the runtime.
#
# If you wish rerun the notebook, make sure to comment it out. </font>

# %%
#Visualization cobe for running within Colab
# !sudo apt-get update
# !sudo apt-get install build-essential zlib1g-dev libsdl2-dev libjpeg-dev nasm tar libbz2-dev libgtk2.0-dev cmake git libfluidsynth-dev libgme-dev libopenal-dev timidity libwildmidi-dev unzip

# Boost libraries
# !sudo apt-get install libboost-all-dev

# Lua binding dependencies
# !apt-get install liblua5.1-dev
# !sudo apt-get install cmake libboost-all-dev libgtk2.0-dev libsdl2-dev python-numpy git
# !git clone https://github.com/shakenes/vizdoomgym.git
# !python3 -m pip install -e vizdoomgym/
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Hit:6 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:12 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:13 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,868 kB]
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,094 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,430 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [903 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [1,385 kB]
# Get:19 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [901 kB]
# Fetched 7,853 kB in 5s (1,497 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# unzip is already the newest version (6.0-21ubuntu1).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2).
# zlib1g-dev set to manually installed.
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# git is already the newest version (1:2.17.1-1ubuntu0.7).
# libbz2-dev is already the newest version (1.0.6-8.1ubuntu0.2).
# libbz2-dev set to manually installed.
# tar is already the newest version (1.29b-2ubuntu0.1).
# The following additional packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file freepats gettext gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-2.0 gir1.2-ibus-1.0
#   gir1.2-pango-1.0 intltool-debian libarchive-cpio-perl libarchive-zip-perl
#   libatk1.0-dev libaudio2 libcairo-script-interpreter2 libcairo2-dev
#   libcapnp-0.6.1 libdbus-1-dev libfile-stripnondeterminism-perl libfluidsynth1
#   libgdk-pixbuf2.0-dev libibus-1.0-5 libibus-1.0-dev libmagic-mgc libmagic1
#   libmail-sendmail-perl libmirclient-dev libmirclient9 libmircommon-dev
#   libmircommon7 libmircookie-dev libmircookie2 libmircore-dev libmircore1
#   libmirprotobuf3 libpango1.0-dev libpangoxft-1.0-0 libpixman-1-dev
#   libprotobuf-dev libprotobuf-lite10 libpulse-dev libpulse-mainloop-glib0
#   libsigsegv2 libsndio-dev libsys-hostname-long-perl libtimedate-perl libtool
#   libudev-dev libwildmidi-config libwildmidi2 libxcb-shm0-dev
#   libxcomposite-dev libxcursor-dev libxinerama-dev libxkbcommon-dev
#   libxml2-utils libxrandr-dev libxv-dev m4 po-debconf timidity-daemon
#   x11proto-composite-dev x11proto-randr-dev x11proto-xinerama-dev
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc dh-make dwz gettext-doc
#   libasprintf-dev libgettextpo-dev nas libcairo2-doc fluidr3mono-gm-soundfont
#   | timgm6mb-soundfont | fluid-soundfont-gm libgtk2.0-doc imagemagick
#   libpango1.0-doc libtool-doc gcj-jdk m4-doc libmail-box-perl
#   fluid-soundfont-gm fluid-soundfont-gs pmidi
# The following NEW packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file freepats gettext gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-2.0 gir1.2-ibus-1.0
#   gir1.2-pango-1.0 intltool-debian libarchive-cpio-perl libarchive-zip-perl
#   libatk1.0-dev libaudio2 libcairo-script-interpreter2 libcairo2-dev
#   libcapnp-0.6.1 libdbus-1-dev libfile-stripnondeterminism-perl
#   libfluidsynth-dev libfluidsynth1 libgdk-pixbuf2.0-dev libgme-dev
#   libgtk2.0-dev libibus-1.0-5 libibus-1.0-dev libmagic-mgc libmagic1
#   libmail-sendmail-perl libmirclient-dev libmirclient9 libmircommon-dev
#   libmircommon7 libmircookie-dev libmircookie2 libmircore-dev libmircore1
#   libmirprotobuf3 libopenal-dev libpango1.0-dev libpangoxft-1.0-0
#   libpixman-1-dev libprotobuf-dev libprotobuf-lite10 libpulse-dev
#   libpulse-mainloop-glib0 libsdl2-dev libsigsegv2 libsndio-dev
#   libsys-hostname-long-perl libtimedate-perl libtool libudev-dev
#   libwildmidi-config libwildmidi-dev libwildmidi2 libxcb-shm0-dev
#   libxcomposite-dev libxcursor-dev libxinerama-dev libxkbcommon-dev
#   libxml2-utils libxrandr-dev libxv-dev m4 nasm po-debconf timidity
#   timidity-daemon x11proto-composite-dev x11proto-randr-dev
#   x11proto-xinerama-dev
# 0 upgraded, 80 newly installed, 0 to remove and 36 not upgraded.
# Need to get 43.2 MB of archives.
# After this operation, 114 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext-base amd64 0.19.8.1-6ubuntu0.3 [113 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 autopoint all 0.19.8.1-6ubuntu0.3 [426 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool all 2.4.6-2 [194 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-autoreconf all 17 [15.8 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libarchive-zip-perl all 1.60-1ubuntu0.1 [84.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-stripnondeterminism-perl all 0.040-1.1~build1 [13.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-strip-nondeterminism all 0.040-1.1~build1 [5,208 B]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext amd64 0.19.8.1-6ubuntu0.3 [1,293 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 intltool-debian all 0.35.0+20060710.4 [24.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 po-debconf all 1.0.20 [232 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 debhelper all 11.1.6ubuntu2 [902 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/universe amd64 freepats all 20060219-1 [29.0 MB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-atk-1.0 amd64 2.28.1-1 [17.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-freedesktop amd64 1.56.1-1 [9,080 B]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.36.11-2 [7,748 B]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangoxft-1.0-0 amd64 1.40.14-1ubuntu0.1 [15.0 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-pango-1.0 amd64 1.40.14-1ubuntu0.1 [21.6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gtk-2.0 amd64 2.24.32-1ubuntu1 [172 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libibus-1.0-5 amd64 1.5.17-3ubuntu5.3 [133 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-ibus-1.0 amd64 1.5.17-3ubuntu5.3 [66.5 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libarchive-cpio-perl all 0.10-1 [9,644 B]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk1.0-dev amd64 2.28.1-1 [79.9 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libaudio2 amd64 1.9.4-6 [50.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-script-interpreter2 amd64 1.15.10-2ubuntu0.1 [53.5 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shm0-dev amd64 1.13-2~ubuntu18.04 [6,684 B]
# Get:36 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo2-dev amd64 1.15.10-2ubuntu0.1 [626 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcapnp-0.6.1 amd64 0.6.1-1ubuntu1 [658 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdbus-1-dev amd64 1.12.2-1ubuntu1.2 [165 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfluidsynth1 amd64 1.1.9-1 [137 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfluidsynth-dev amd64 1.1.9-1 [19.7 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-dev amd64 2.36.11-2 [46.8 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgme-dev amd64 0.6.2-1 [5,796 B]
# Get:43 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpango1.0-dev amd64 1.40.14-1ubuntu0.1 [288 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xinerama-dev all 2018.4-4 [2,628 B]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama-dev amd64 2:1.1.3-1 [8,404 B]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-randr-dev all 2018.4-4 [2,620 B]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr-dev amd64 2:1.5.1-1 [24.0 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor-dev amd64 1:1.1.15-1 [26.5 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-composite-dev all 1:2018.4-4 [2,620 B]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcomposite-dev amd64 1:0.4.4-2 [9,136 B]
# Get:51 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxml2-utils amd64 2.9.4+dfsg1-6.1ubuntu1.3 [35.9 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-dev amd64 2.24.32-1ubuntu1 [2,652 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libibus-1.0-dev amd64 1.5.17-3ubuntu5.3 [145 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsys-hostname-long-perl all 1.5-1 [11.7 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmail-sendmail-perl all 0.80-1 [22.6 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore1 amd64 0.31.1-0ubuntu1 [26.5 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon7 amd64 0.31.1-0ubuntu1 [73.9 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-lite10 amd64 3.0.0-9.1ubuntu1 [97.7 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirprotobuf3 amd64 0.31.1-0ubuntu1 [127 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient9 amd64 0.31.1-0ubuntu1 [199 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore-dev amd64 0.31.1-0ubuntu1 [21.7 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-dev amd64 3.0.0-9.1ubuntu1 [959 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxkbcommon-dev amd64 0.8.2-1~ubuntu18.04.1 [150 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon-dev amd64 0.31.1-0ubuntu1 [13.9 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie2 amd64 0.31.1-0ubuntu1 [19.7 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie-dev amd64 0.31.1-0ubuntu1 [4,392 B]
# Get:67 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient-dev amd64 0.31.1-0ubuntu1 [47.8 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenal-dev amd64 1:1.18.2-2 [20.9 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse-mainloop-glib0 amd64 1:11.1-1ubuntu7.10 [22.1 kB]
# Get:70 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse-dev amd64 1:11.1-1ubuntu7.10 [81.5 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsndio-dev amd64 1.1.0-3 [13.3 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libudev-dev amd64 237-3ubuntu10.42 [19.1 kB]
# Get:73 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxv-dev amd64 2:1.0.11-1 [32.5 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsdl2-dev amd64 2.0.8+dfsg1-1ubuntu1.18.04.4 [683 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwildmidi-config all 0.4.2-1 [7,212 B]
# Get:76 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwildmidi2 amd64 0.4.2-1 [55.8 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwildmidi-dev amd64 0.4.2-1 [86.4 kB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic/universe amd64 nasm amd64 2.13.02-0.1 [359 kB]
# Get:79 http://archive.ubuntu.com/ubuntu bionic/universe amd64 timidity amd64 2.13.2-41 [585 kB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic/universe amd64 timidity-daemon all 2.13.2-41 [5,984 B]
# Fetched 43.2 MB in 8s (5,568 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 80.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 144676 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package gettext-base.
# Preparing to unpack .../03-gettext-base_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../04-libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../05-m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../06-autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../07-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../08-automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../09-autopoint_0.19.8.1-6ubuntu0.3_all.deb ...
# Unpacking autopoint (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../10-libtool_2.4.6-2_all.deb ...
# Unpacking libtool (2.4.6-2) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../11-dh-autoreconf_17_all.deb ...
# Unpacking dh-autoreconf (17) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../12-libarchive-zip-perl_1.60-1ubuntu0.1_all.deb ...
# Unpacking libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../13-libfile-stripnondeterminism-perl_0.040-1.1~build1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../14-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../15-dh-strip-nondeterminism_0.040-1.1~build1_all.deb ...
# Unpacking dh-strip-nondeterminism (0.040-1.1~build1) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../16-gettext_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../17-intltool-debian_0.35.0+20060710.4_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.4) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../18-po-debconf_1.0.20_all.deb ...
# Unpacking po-debconf (1.0.20) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../19-debhelper_11.1.6ubuntu2_all.deb ...
# Unpacking debhelper (11.1.6ubuntu2) ...
# Selecting previously unselected package freepats.
# Preparing to unpack .../20-freepats_20060219-1_all.deb ...
# Unpacking freepats (20060219-1) ...
# Selecting previously unselected package gir1.2-atk-1.0:amd64.
# Preparing to unpack .../21-gir1.2-atk-1.0_2.28.1-1_amd64.deb ...
# Unpacking gir1.2-atk-1.0:amd64 (2.28.1-1) ...
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# Preparing to unpack .../22-gir1.2-freedesktop_1.56.1-1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Selecting previously unselected package gir1.2-gdkpixbuf-2.0:amd64.
# Preparing to unpack .../23-gir1.2-gdkpixbuf-2.0_2.36.11-2_amd64.deb ...
# Unpacking gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../24-libpangoxft-1.0-0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../25-gir1.2-pango-1.0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-gtk-2.0.
# Preparing to unpack .../26-gir1.2-gtk-2.0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking gir1.2-gtk-2.0 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libibus-1.0-5:amd64.
# Preparing to unpack .../27-libibus-1.0-5_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking libibus-1.0-5:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package gir1.2-ibus-1.0:amd64.
# Preparing to unpack .../28-gir1.2-ibus-1.0_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking gir1.2-ibus-1.0:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../29-libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libatk1.0-dev:amd64.
# Preparing to unpack .../30-libatk1.0-dev_2.28.1-1_amd64.deb ...
# Unpacking libatk1.0-dev:amd64 (2.28.1-1) ...
# Selecting previously unselected package libaudio2:amd64.
# Preparing to unpack .../31-libaudio2_1.9.4-6_amd64.deb ...
# Unpacking libaudio2:amd64 (1.9.4-6) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../32-libcairo-script-interpreter2_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../33-libpixman-1-dev_0.34.0-2_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../34-libxcb-shm0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../35-libcairo2-dev_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libcapnp-0.6.1:amd64.
# Preparing to unpack .../36-libcapnp-0.6.1_0.6.1-1ubuntu1_amd64.deb ...
# Unpacking libcapnp-0.6.1:amd64 (0.6.1-1ubuntu1) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../37-libdbus-1-dev_1.12.2-1ubuntu1.2_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.2-1ubuntu1.2) ...
# Selecting previously unselected package libfluidsynth1:amd64.
# Preparing to unpack .../38-libfluidsynth1_1.1.9-1_amd64.deb ...
# Unpacking libfluidsynth1:amd64 (1.1.9-1) ...
# Selecting previously unselected package libfluidsynth-dev:amd64.
# Preparing to unpack .../39-libfluidsynth-dev_1.1.9-1_amd64.deb ...
# Unpacking libfluidsynth-dev:amd64 (1.1.9-1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-dev.
# Preparing to unpack .../40-libgdk-pixbuf2.0-dev_2.36.11-2_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Selecting previously unselected package libgme-dev:amd64.
# Preparing to unpack .../41-libgme-dev_0.6.2-1_amd64.deb ...
# Unpacking libgme-dev:amd64 (0.6.2-1) ...
# Selecting previously unselected package libpango1.0-dev.
# Preparing to unpack .../42-libpango1.0-dev_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../43-x11proto-xinerama-dev_2018.4-4_all.deb ...
# Unpacking x11proto-xinerama-dev (2018.4-4) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../44-libxinerama-dev_2%3a1.1.3-1_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.3-1) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../45-x11proto-randr-dev_2018.4-4_all.deb ...
# Unpacking x11proto-randr-dev (2018.4-4) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../46-libxrandr-dev_2%3a1.5.1-1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.1-1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../47-libxcursor-dev_1%3a1.1.15-1_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.1.15-1) ...
# Selecting previously unselected package x11proto-composite-dev.
# Preparing to unpack .../48-x11proto-composite-dev_1%3a2018.4-4_all.deb ...
# Unpacking x11proto-composite-dev (1:2018.4-4) ...
# Selecting previously unselected package libxcomposite-dev:amd64.
# Preparing to unpack .../49-libxcomposite-dev_1%3a0.4.4-2_amd64.deb ...
# Unpacking libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Selecting previously unselected package libxml2-utils.
# Preparing to unpack .../50-libxml2-utils_2.9.4+dfsg1-6.1ubuntu1.3_amd64.deb ...
# Unpacking libxml2-utils (2.9.4+dfsg1-6.1ubuntu1.3) ...
# Selecting previously unselected package libgtk2.0-dev.
# Preparing to unpack .../51-libgtk2.0-dev_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-dev (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libibus-1.0-dev:amd64.
# Preparing to unpack .../52-libibus-1.0-dev_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking libibus-1.0-dev:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../53-libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../54-libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Selecting previously unselected package libmircore1:amd64.
# Preparing to unpack .../55-libmircore1_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircore1:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircommon7:amd64.
# Preparing to unpack .../56-libmircommon7_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libprotobuf-lite10:amd64.
# Preparing to unpack .../57-libprotobuf-lite10_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libmirprotobuf3:amd64.
# Preparing to unpack .../58-libmirprotobuf3_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmirclient9:amd64.
# Preparing to unpack .../59-libmirclient9_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircore-dev:amd64.
# Preparing to unpack .../60-libmircore-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircore-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libprotobuf-dev:amd64.
# Preparing to unpack .../61-libprotobuf-dev_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../62-libxkbcommon-dev_0.8.2-1~ubuntu18.04.1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Selecting previously unselected package libmircommon-dev:amd64.
# Preparing to unpack .../63-libmircommon-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircookie2:amd64.
# Preparing to unpack .../64-libmircookie2_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircookie2:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircookie-dev:amd64.
# Preparing to unpack .../65-libmircookie-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmirclient-dev:amd64.
# Preparing to unpack .../66-libmirclient-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libopenal-dev:amd64.
# Preparing to unpack .../67-libopenal-dev_1%3a1.18.2-2_amd64.deb ...
# Unpacking libopenal-dev:amd64 (1:1.18.2-2) ...
# Selecting previously unselected package libpulse-mainloop-glib0:amd64.
# Preparing to unpack .../68-libpulse-mainloop-glib0_1%3a11.1-1ubuntu7.10_amd64.deb ...
# Unpacking libpulse-mainloop-glib0:amd64 (1:11.1-1ubuntu7.10) ...
# Selecting previously unselected package libpulse-dev:amd64.
# Preparing to unpack .../69-libpulse-dev_1%3a11.1-1ubuntu7.10_amd64.deb ...
# Unpacking libpulse-dev:amd64 (1:11.1-1ubuntu7.10) ...
# Selecting previously unselected package libsndio-dev:amd64.
# Preparing to unpack .../70-libsndio-dev_1.1.0-3_amd64.deb ...
# Unpacking libsndio-dev:amd64 (1.1.0-3) ...
# Selecting previously unselected package libudev-dev:amd64.
# Preparing to unpack .../71-libudev-dev_237-3ubuntu10.42_amd64.deb ...
# Unpacking libudev-dev:amd64 (237-3ubuntu10.42) ...
# Selecting previously unselected package libxv-dev:amd64.
# Preparing to unpack .../72-libxv-dev_2%3a1.0.11-1_amd64.deb ...
# Unpacking libxv-dev:amd64 (2:1.0.11-1) ...
# Selecting previously unselected package libsdl2-dev:amd64.
# Preparing to unpack .../73-libsdl2-dev_2.0.8+dfsg1-1ubuntu1.18.04.4_amd64.deb ...
# Unpacking libsdl2-dev:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# Selecting previously unselected package libwildmidi-config.
# Preparing to unpack .../74-libwildmidi-config_0.4.2-1_all.deb ...
# Unpacking libwildmidi-config (0.4.2-1) ...
# Selecting previously unselected package libwildmidi2:amd64.
# Preparing to unpack .../75-libwildmidi2_0.4.2-1_amd64.deb ...
# Unpacking libwildmidi2:amd64 (0.4.2-1) ...
# Selecting previously unselected package libwildmidi-dev.
# Preparing to unpack .../76-libwildmidi-dev_0.4.2-1_amd64.deb ...
# Unpacking libwildmidi-dev (0.4.2-1) ...
# Selecting previously unselected package nasm.
# Preparing to unpack .../77-nasm_2.13.02-0.1_amd64.deb ...
# Unpacking nasm (2.13.02-0.1) ...
# Selecting previously unselected package timidity.
# Preparing to unpack .../78-timidity_2.13.2-41_amd64.deb ...
# Unpacking timidity (2.13.2-41) ...
# Selecting previously unselected package timidity-daemon.
# Preparing to unpack .../79-timidity-daemon_2.13.2-41_all.deb ...
# Unpacking timidity-daemon (2.13.2-41) ...
# Setting up libdbus-1-dev:amd64 (1.12.2-1ubuntu1.2) ...
# Setting up libxcursor-dev:amd64 (1:1.1.15-1) ...
# Setting up gir1.2-atk-1.0:amd64 (2.28.1-1) ...
# Setting up libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Setting up libpulse-mainloop-glib0:amd64 (1:11.1-1ubuntu7.10) ...
# Setting up libpulse-dev:amd64 (1:11.1-1ubuntu7.10) ...
# Setting up libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Setting up libmircore-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up libgme-dev:amd64 (0.6.2-1) ...
# Setting up gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Setting up libsndio-dev:amd64 (1.1.0-3) ...
# Setting up libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libxml2-utils (2.9.4+dfsg1-6.1ubuntu1.3) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Setting up libatk1.0-dev:amd64 (2.28.1-1) ...
# Setting up gettext-base (0.19.8.1-6ubuntu0.3) ...
# Setting up m4 (1.4.18-1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libopenal-dev:amd64 (1:1.18.2-2) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up libwildmidi-config (0.4.2-1) ...
# Setting up libmircookie2:amd64 (0.31.1-0ubuntu1) ...
# Setting up libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Setting up x11proto-xinerama-dev (2018.4-4) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up libpixman-1-dev:amd64 (0.34.0-2) ...
# Setting up x11proto-randr-dev (2018.4-4) ...
# Setting up libxinerama-dev:amd64 (2:1.1.3-1) ...
# Setting up libxv-dev:amd64 (2:1.0.11-1) ...
# Setting up nasm (2.13.02-0.1) ...
# Setting up libcapnp-0.6.1:amd64 (0.6.1-1ubuntu1) ...
# Setting up libibus-1.0-5:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up libmircore1:amd64 (0.31.1-0ubuntu1) ...
# Setting up freepats (20060219-1) ...
# Setting up libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libudev-dev:amd64 (237-3ubuntu10.42) ...
# Setting up libfluidsynth1:amd64 (1.1.9-1) ...
# Setting up x11proto-composite-dev (1:2018.4-4) ...
# Setting up autopoint (0.19.8.1-6ubuntu0.3) ...
# Setting up libaudio2:amd64 (1.9.4-6) ...
# Setting up libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Setting up gir1.2-gtk-2.0 (2.24.32-1ubuntu1) ...
# Setting up gir1.2-ibus-1.0:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up libxrandr-dev:amd64 (2:1.5.1-1) ...
# Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up gettext (0.19.8.1-6ubuntu0.3) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Setting up libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Setting up libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up autoconf (2.69-11) ...
# Setting up libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libwildmidi2:amd64 (0.4.2-1) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up intltool-debian (0.35.0+20060710.4) ...
# Setting up libibus-1.0-dev:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Setting up libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Setting up libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Setting up libfluidsynth-dev:amd64 (1.1.9-1) ...
# Setting up timidity (2.13.2-41) ...
# Setting up libtool (2.4.6-2) ...
# Setting up po-debconf (1.0.20) ...
# Setting up libwildmidi-dev (0.4.2-1) ...
# Setting up libgtk2.0-dev (2.24.32-1ubuntu1) ...
# Setting up libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Setting up libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up timidity-daemon (2.13.2-41) ...
# Adding group timidity....done
# Adding system user timidity....done
# Adding user `timidity' to group `audio' ...
# Adding user timidity to group audio
# Done.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of stop.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libsdl2-dev:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# Setting up debhelper (11.1.6ubuntu2) ...
# Setting up dh-autoreconf (17) ...
# Setting up dh-strip-nondeterminism (0.040-1.1~build1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.2) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for systemd (237-3ubuntu10.42) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libboost-all-dev is already the newest version (1.65.1.0ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'liblua5.1-0-dev' instead of 'liblua5.1-dev'
# The following additional packages will be installed:
#   libtool-bin
# The following NEW packages will be installed:
#   liblua5.1-0-dev libtool-bin
# 0 upgraded, 2 newly installed, 0 to remove and 36 not upgraded.
# Need to get 198 kB of archives.
# After this operation, 1,188 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 liblua5.1-0-dev amd64 5.1.5-8.1build2 [119 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool-bin amd64 2.4.6-2 [79.5 kB]
# Fetched 198 kB in 2s (113 kB/s)
# Selecting previously unselected package liblua5.1-0-dev:amd64.
# (Reading database ... 147702 files and directories currently installed.)
# Preparing to unpack .../liblua5.1-0-dev_5.1.5-8.1build2_amd64.deb ...
# Unpacking liblua5.1-0-dev:amd64 (5.1.5-8.1build2) ...
# Selecting previously unselected package libtool-bin.
# Preparing to unpack .../libtool-bin_2.4.6-2_amd64.deb ...
# Unpacking libtool-bin (2.4.6-2) ...
# Setting up libtool-bin (2.4.6-2) ...
# Setting up liblua5.1-0-dev:amd64 (5.1.5-8.1build2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgtk2.0-dev is already the newest version (2.24.32-1ubuntu1).
# python-numpy is already the newest version (1:1.13.3-2ubuntu1).
# python-numpy set to manually installed.
# libboost-all-dev is already the newest version (1.65.1.0ubuntu1).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# git is already the newest version (1:2.17.1-1ubuntu0.7).
# libsdl2-dev is already the newest version (2.0.8+dfsg1-1ubuntu1.18.04.4).
# 0 upgraded, 0 newly installed, 0 to remove and 36 not upgraded.
# Cloning into 'vizdoomgym'...
# remote: Enumerating objects: 267, done.
# remote: Counting objects: 100% (267/267), done.
# remote: Compressing objects: 100% (170/170), done.
# remote: Total 574 (delta 136), reused 142 (delta 69), pack-reused 307
# Receiving objects: 100% (574/574), 186.22 KiB | 529.00 KiB/s, done.
# Resolving deltas: 100% (302/302), done.
# Obtaining file:///content/vizdoomgym
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (from vizdoomgym==1.0) (0.17.2)
# Collecting vizdoom@ https://github.com/mwydmuch/ViZDoom/tarball/1.1.8pre
#   Downloading https://github.com/mwydmuch/ViZDoom/tarball/1.1.8pre
#      / 6.1MB 871kB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from vizdoomgym==1.0) (1.18.5)
# Collecting pre-commit
#   Downloading https://files.pythonhosted.org/packages/2c/88/966da62ec93566c221bf8bf0c1b7f04e70f002960a98da05d3fd8bc3b2e7/pre_commit-2.7.1-py2.py3-none-any.whl (171kB)
#      |████████████████████████████████| 174kB 2.7MB/s
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym->vizdoomgym==1.0) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym->vizdoomgym==1.0) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym->vizdoomgym==1.0) (1.4.1)
# Collecting importlib-resources; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/ba/03/0f9595c0c2ef12590877f3c47e5f579759ce5caf817f8256d5dcbd8a1177/importlib_resources-3.0.0-py2.py3-none-any.whl
# Collecting pyyaml>=5.1
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
#      |████████████████████████████████| 276kB 11.0MB/s
# Collecting cfgv>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/45/cd/3878c9248e59e5e2ebd0dc741ab984b18d86e7283ae9b127b05fc287d239/cfgv-3.2.0-py2.py3-none-any.whl
# Requirement already satisfied: toml in /usr/local/lib/python3.6/dist-packages (from pre-commit->vizdoomgym==1.0) (0.10.1)
# Collecting identify>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/12/b3/1b132da31e1a83a022db9d376b786870ee57ef343df850e9531168d5acf7/identify-1.5.3-py2.py3-none-any.whl (97kB)
#      |████████████████████████████████| 102kB 6.8MB/s
# Collecting virtualenv>=20.0.8
#   Downloading https://files.pythonhosted.org/packages/12/51/36c685ff2c1b2f7b4b5db29f3153159102ae0e0adaff3a26fd1448232e06/virtualenv-20.0.31-py2.py3-none-any.whl (4.9MB)
#      |████████████████████████████████| 4.9MB 12.1MB/s
# Collecting nodeenv>=0.11.1
#   Downloading https://files.pythonhosted.org/packages/ae/d0/efdf54539948315cc76e5a66b709212963101d002822c3b54369dbf9b5e0/nodeenv-1.5.0-py2.py3-none-any.whl
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from pre-commit->vizdoomgym==1.0) (1.7.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->vizdoomgym==1.0) (0.16.0)
# Requirement already satisfied: zipp>=0.4; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from importlib-resources; python_version < "3.7"->pre-commit->vizdoomgym==1.0) (3.1.0)
# Requirement already satisfied: filelock<4,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from virtualenv>=20.0.8->pre-commit->vizdoomgym==1.0) (3.0.12)
# Collecting appdirs<2,>=1.4.3
#   Downloading https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl
# Collecting distlib<1,>=0.3.1
#   Downloading https://files.pythonhosted.org/packages/f5/0a/490fa011d699bb5a5f3a0cf57de82237f52a6db9d40f33c53b2736c9a1f9/distlib-0.3.1-py2.py3-none-any.whl (335kB)
#      |████████████████████████████████| 337kB 38.9MB/s
# Requirement already satisfied: six<2,>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from virtualenv>=20.0.8->pre-commit->vizdoomgym==1.0) (1.15.0)
# Building wheels for collected packages: vizdoom, pyyaml
#   Building wheel for vizdoom (setup.py) ... done
#   Created wheel for vizdoom: filename=vizdoom-1.1.8-cp36-none-any.whl size=14293710 sha256=147460c9bbe5b1bb83e8c2a3d015f3611d81c0c6a68e2b5d4245b1e02dbec50d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-sp9u9qo_/wheels/1b/e8/11/2c308b2447cf5421008b1de5216938fb990878fead56eb135d
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44619 sha256=810f805fc3466ee845ec2d901cfecfab30b21375796c8cb1fe002081db4aba65
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# Successfully built vizdoom pyyaml
# Installing collected packages: vizdoom, importlib-resources, pyyaml, cfgv, identify, appdirs, distlib, virtualenv, nodeenv, pre-commit, vizdoomgym
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Running setup.py develop for vizdoomgym
# Successfully installed appdirs-1.4.4 cfgv-3.2.0 distlib-0.3.1 identify-1.5.3 importlib-resources-3.0.0 nodeenv-1.5.0 pre-commit-2.7.1 pyyaml-5.3.1 virtualenv-20.0.31 vizdoom-1.1.8 vizdoomgym

# %%
# !pip install av
# Out:
# Collecting av
#   Downloading https://files.pythonhosted.org/packages/9e/62/9a992be76f8e13ce0e3a24a838191b546805545116f9fc869bd11bd21b5f/av-8.0.2-cp36-cp36m-manylinux2010_x86_64.whl (36.9MB)
#      |████████████████████████████████| 36.9MB 83kB/s
# Installing collected packages: av
# Successfully installed av-8.0.2

# %%
# Evaluation code
#Visualization cobe for running within Colab

# Install dependencies first for graphics visualization within Colaboratory
# !pip install folium==0.2.1
#remove " > /dev/null 2>&1" to see what is going on under the hood
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# Out:
# Collecting folium==0.2.1
#   Downloading https://files.pythonhosted.org/packages/72/dd/75ced7437bfa7cb9a88b96ee0177953062803c3b4cde411a97d98c35adaf/folium-0.2.1.tar.gz (69kB)
#      |████████████████████████████████| 71kB 2.0MB/s
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.6/dist-packages (from folium==0.2.1) (2.11.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2->folium==0.2.1) (1.1.1)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.2.1-cp36-none-any.whl size=79980 sha256=400bb95f9afc8fcc814d7267f0510696cb31b3a27a66a46bf3b6241353932dc0
#   Stored in directory: /root/.cache/pip/wheels/b8/09/f0/52d2ef419c2aaf4fb149f92a33e0008bdce7ae816f0dd8f0c5
# Successfully built folium
# Installing collected packages: folium
#   Found existing installation: folium 0.8.3
#     Uninstalling folium-0.8.3:
#       Successfully uninstalled folium-0.8.3
# Successfully installed folium-0.2.1
# Requirement already up-to-date: setuptools in /usr/local/lib/python3.6/dist-packages (50.3.0)

# %% [markdown]
# Inspect the environment. You'll need to restart the runtime for it to work

# %%
#Check the environment. You'll need to restart the runtime for it to work
import gym
import vizdoomgym

env = gym.make('VizdoomCorridor-v0')

# use like a normal Gym environment
state = env.reset()
state, reward, done, info = env.step(env.action_space.sample())
print(state.shape)
# env.render()
env.close()
# Out:
# Cannot connect to "None"
# (240, 320, 3)

# %%
import gym
import vizdoomgym

env = gym.make('VizdoomCorridor-v0')
n_outputs = env.action_space.n
print(n_outputs)


observation = env.reset()

import matplotlib.pyplot as plt


for i in range(22):
  
  if i > 20:
    print(observation.shape)
    plt.imshow(observation)
    plt.show()

  observation, _, _, _ = env.step(1)
# Out:
# 7
# (240, 320, 3)

# %%
import numpy as np


from collections import deque, Counter
import random
from datetime import datetime
from __future__ import division
from __future__ import print_function
from vizdoom import *
import itertools as it
from random import sample, randint, random
from time import time, sleep
import numpy as np
import skimage.color, skimage.transform
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from tqdm import trange

# %% [markdown]
# ## Preprocessing
#
# We'll define a set of wrappers to modify our gym environment to provide preprocessed observations.
#
# We’ll start defining a wrapper to repeat every action for a number of frames, and perform an element-wise maxima in order to increase the intensity of any actions.
#
# Next, we define the preprocessing function for our observations. We’ll make our environment symmetrical by converting it into the Box space, swapping the channel integer to the front of our tensor, and resizing it to an area of (84,84) from its original (320,480) resolution. We’ll also greyscale our environment, and normalize the entire image by dividing by a constant.
#
# Next, we create a wrapper to handle frame-stacking. The objective here is to help capture motion and direction from stacking frames, by stacking several frames together as a single batch. In this way, we can capture position, translation, velocity, and acceleration of the elements in the environment. With stacking, our input adopts a shape of (4,84,84,1).

# %%
#11072020 Utililities support class

import collections
import cv2
import numpy as np
import matplotlib.pyplot as plt
import gym

def plot_learning_curve(x, scores, epsilons, filename, lines=None):
    fig=plt.figure()
    ax=fig.add_subplot(111, label="1")
    ax2=fig.add_subplot(111, label="2", frame_on=False)

    ax.plot(x, epsilons, color="C0")
    ax.set_xlabel("Episodes", color="C0")
    ax.set_ylabel("Epsilon", color="C0")
    ax.tick_params(axis='x', colors="C0")
    ax.tick_params(axis='y', colors="C0")

    N = len(scores)
    running_avg = np.empty(N)
    for t in range(N):
	    running_avg[t] = np.mean(scores[max(0, t-20):(t+1)])

    ax2.scatter(x, running_avg, color="C1")
    ax2.axes.get_xaxis().set_visible(False)
    ax2.yaxis.tick_right()
    ax2.set_ylabel('Average Score', color="C1")
    ax2.yaxis.set_label_position('right')
    ax2.tick_params(axis='y', colors="C1")

    if lines is not None:
        for line in lines:
            plt.axvline(x=line)

    

class RepeatActionAndMaxFrame(gym.Wrapper):
  #input: environment, repeat
  #init frame buffer as an array of zeros in shape 2 x the obs space
    def __init__(self, env=None, repeat=4, clip_reward=False, no_ops=0,
                 fire_first=False):
        super(RepeatActionAndMaxFrame, self).__init__(env)
        self.repeat = repeat
        self.shape = env.observation_space.low.shape
        self.frame_buffer = np.zeros_like((2, self.shape))
        self.clip_reward = clip_reward
        self.no_ops = no_ops
        self.fire_first = fire_first

    def step(self, action):
        t_reward = 0.0
        done = False
        for i in range(self.repeat):
            obs, reward, done, info = self.env.step(action)
            if self.clip_reward:
                reward = np.clip(np.array([reward]), -1, 1)[0]
            t_reward += reward
            idx = i % 2
            self.frame_buffer[idx] = obs
            if done:
                break

        max_frame = np.maximum(self.frame_buffer[0], self.frame_buffer[1])
        return max_frame, t_reward, done, info

    def reset(self):
        obs = self.env.reset()
        no_ops = np.random.randint(self.no_ops)+1 if self.no_ops > 0 else 0
        for _ in range(no_ops):
            _, _, done, _ = self.env.step(0)
            if done:
                self.env.reset()
        #Fire first seems quite useless, probably meant for something like space invader
        if self.fire_first:
            assert self.env.unwrapped.get_action_meanings()[1] == 'FIRE'
            obs, _, _, _ = self.env.step(1)

        self.frame_buffer = np.zeros_like((2,self.shape))
        self.frame_buffer[0] = obs

        return obs

class PreprocessFrame(gym.ObservationWrapper):
  #set shape by swapping channels axis
	#set observation space to new shape using gym.spaces.Box (0 to 1.0)
    def __init__(self, shape, env=None):
        super(PreprocessFrame, self).__init__(env)
        self.shape = (shape[2], shape[0], shape[1])
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0,
                                    shape=self.shape, dtype=np.float32)

    def observation(self, obs):
        new_frame = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)
        resized_screen = cv2.resize(new_frame, self.shape[1:],
                                    interpolation=cv2.INTER_AREA)
        new_obs = np.array(resized_screen, dtype=np.uint8).reshape(self.shape)
        new_obs = new_obs / 255.0

        return new_obs

class StackFrames(gym.ObservationWrapper):
  #init the new obs space (gym.spaces.Box) low & high bounds as repeat of n_steps. These should have been defined for vizdooom
  #WE may not have to use boxes in ur final model. But we can keep it for now
  #Create a return a stack of observations
    def __init__(self, env, repeat):
        super(StackFrames, self).__init__(env)
        self.observation_space = gym.spaces.Box(
                            env.observation_space.low.repeat(repeat, axis=0),
                            env.observation_space.high.repeat(repeat, axis=0),
                            dtype=np.float32)
        self.stack = collections.deque(maxlen=repeat)

    def reset(self):
        self.stack.clear()
        observation = self.env.reset()
        for _ in range(self.stack.maxlen):
            self.stack.append(observation)

        return np.array(self.stack).reshape(self.observation_space.low.shape)

    def observation(self, observation):
        self.stack.append(observation)

        return np.array(self.stack).reshape(self.observation_space.low.shape)

#This shape command should not be 84,84,1 take a look at what we went with in our TF example
#Note how fire_first is false here, probably useless in the context of Pong
def make_env(env_name, shape=(84,84,1), repeat=4, clip_rewards=False,
             no_ops=0, fire_first=False):
    env = gym.make(env_name)
    env = PreprocessFrame(shape, env)
    env = RepeatActionAndMaxFrame(env, repeat, clip_rewards, no_ops, fire_first)
    
    env = StackFrames(env, repeat)

    return env

# %% [markdown]
# Next, let’s define our model, a deep Q-network. This is essentially a three layer convolutional network that takes preprocessed input obserations, with the generated flattened output fed to a fully-connected layer, which is then split into two streams, one representing the state-value and one representing the actin space of the game (between 4 and 18 in the Atari games)

# %%
import os
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

class DeepQNetwork(nn.Module):
    def __init__(self, lr, n_actions, name, input_dims, chkpt_dir):
        super(DeepQNetwork, self).__init__()
        self.checkpoint_dir = chkpt_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir, name)

        self.conv1 = nn.Conv2d(input_dims[0], 32, 8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, 4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, 3, stride=1)

        fc_input_dims = self.calculate_conv_output_dims(input_dims)

        self.fc1 = nn.Linear(fc_input_dims,1024)
        self.fc2 = nn.Linear(1024, 512)
        #Here we split the linear layer into the State and Advantage streams
        self.V = nn.Linear(512, 1)
        self.A = nn.Linear(512, n_actions)

        self.optimizer = optim.RMSprop(self.parameters(), lr=lr)

        self.loss = nn.MSELoss()
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def calculate_conv_output_dims(self, input_dims):
        state = T.zeros(1, *input_dims)
        dims = self.conv1(state)
        dims = self.conv2(dims)
        dims = self.conv3(dims)
        return int(np.prod(dims.size()))

    def forward(self, state):
        conv1 = F.relu(self.conv1(state))
        conv2 = F.relu(self.conv2(conv1))
        conv3 = F.relu(self.conv3(conv2))
        # conv3 shape is BS x n_filters x H x W
        conv_state = conv3.view(conv3.size()[0], -1)
        # conv_state shape is BS x (n_filters * H * W)
        flat1 = F.relu(self.fc1(conv_state))
        flat2 = F.relu(self.fc2(flat1))

        V = self.V(flat2)
        A = self.A(flat2)

        return V, A

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_file))

# %% [markdown]
# ## Storing Replay Memories
#
# In this section we will create a mechanism for the agent to keep track of states, actions, rewards, new states, and the final state.
#
# All of these factors will be used in the calculation of the Target for the loss function of the DQN.
#
# For maximum flexibility of the agent the memory should accomodate states with an arbitrary shape.
#
# We should also sample from the memory uniformly, meaning each memory will have an equal probability of being sampled, and we should not repeat memories.

# %%
#11072020 New ReplayMemory Class

import numpy as np

class ReplayBuffer(object):
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_shape),
                                     dtype=np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_shape),
                                         dtype=np.float32)

        self.action_memory = np.zeros(self.mem_size, dtype=np.int64)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)

    #Identify index and store  the the current SARSA into batch memory
    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = done
        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)
        batch = np.random.choice(max_mem, batch_size, replace=False)
        #I believe batch here is creating a list limit that is acquired through max_mem, whihch we use to subselect memory
        states = self.state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        states_ = self.new_state_memory[batch]
        terminal = self.terminal_memory[batch]

        return states, actions, rewards, states_, terminal

# %% [markdown]
# ## Agent Class
#
# Our agent be using an epsilon greedy policy with a decaying exploration rate, in order to maximize exploitation over time. To learn to predict state-action-values that maximize our cumulative reward, our agent will be using the discounted future rewards obtained by sampling the memory.
#
# You’’ll notice that we initialize two copies of our DQN as part of our agent, with methods to copy weight parameters of our original network into a target network. This dual-network approach allows us to generate data during the training process using an existing policy while still optimizing our parameters for the next policy iteration, reducing loss oscillations. We will leverage this for our DDQN implementation.
#
# For reference, the original vanilla DQN update function is shown below:
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import torch as T
#from deep_q_network import DeepQNetwork
#from replay_memory import ReplayBuffer

#Combining the value stream splitting of a DuelDQN with the update approach of a DDQN
class DuelDDQNAgent(object):
    def __init__(self, gamma, epsilon, lr, n_actions, input_dims,
                 mem_size, batch_size, eps_min=0.01, eps_dec=5e-7,
                 replace=1000, algo=None, env_name=None, chkpt_dir='tmp/dqn'):
        self.gamma = gamma
        self.epsilon = epsilon
        self.lr = lr
        self.n_actions = n_actions
        self.input_dims = input_dims
        self.batch_size = batch_size
        self.eps_min = eps_min
        self.eps_dec = eps_dec
        self.replace_target_cnt = replace
        self.algo = algo
        self.env_name = env_name
        self.chkpt_dir = chkpt_dir
        self.action_space = [i for i in range(n_actions)]
        self.learn_step_counter = 0

        self.memory = ReplayBuffer(mem_size, input_dims, n_actions)

        self.q_eval = DeepQNetwork(self.lr, self.n_actions,
                                    input_dims=self.input_dims,
                                    name=self.env_name+'_'+self.algo+'_q_eval',
                                    chkpt_dir=self.chkpt_dir)

        self.q_next = DeepQNetwork(self.lr, self.n_actions,
                                    input_dims=self.input_dims,
                                    name=self.env_name+'_'+self.algo+'_q_next',
                                    chkpt_dir=self.chkpt_dir)

    #Epsilon greedy action selection
    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
          # Add dimension to observation to match input_dims x batch_size by placing in list, then converting to tensor
            state = T.tensor([observation],dtype=T.float).to(self.q_eval.device)
            #As our forward function now has both state and advantage, fetch latter for actio selection
            _, advantage = self.q_eval.forward(state)
            action = T.argmax(advantage).item()
        else:
            action = np.random.choice(self.action_space)

        return action

    def store_transition(self, state, action, reward, state_, done):
        self.memory.store_transition(state, action, reward, state_, done)

    def sample_memory(self):
        state, action, reward, new_state, done = \
                                self.memory.sample_buffer(self.batch_size)

        states = T.tensor(state).to(self.q_eval.device)
        rewards = T.tensor(reward).to(self.q_eval.device)
        dones = T.tensor(done).to(self.q_eval.device)
        actions = T.tensor(action).to(self.q_eval.device)
        states_ = T.tensor(new_state).to(self.q_eval.device)

        return states, actions, rewards, states_, dones

    def replace_target_network(self):
        if self.learn_step_counter % self.replace_target_cnt == 0:
            self.q_next.load_state_dict(self.q_eval.state_dict())

    def decrement_epsilon(self):
        self.epsilon = self.epsilon - self.eps_dec \
                           if self.epsilon > self.eps_min else self.eps_min

    def save_models(self):
        self.q_eval.save_checkpoint()
        self.q_next.save_checkpoint()

    def load_models(self):
        self.q_eval.load_checkpoint()
        self.q_next.load_checkpoint()
    #Make sure you understand this line by line
    #For DDQN main difference is here - Consult the lecture to gain a stronger understanding of why things differe here
    def learn(self):

      #First check if memory is even big enough
        if self.memory.mem_cntr < self.batch_size:
            return

        self.q_eval.optimizer.zero_grad()

        #Replace target network if appropriate
        self.replace_target_network()

        states, actions, rewards, states_, dones = self.sample_memory()
        #Fetch states and advantage actions for current state using eval network
        #Also fetch the same for next state using target network
        V_s, A_s = self.q_eval.forward(states)
        V_s_, A_s_ = self.q_next.forward(states_)
        
        #Eval network calculation of next state V and A
        V_s_eval, A_s_eval = self.q_eval.forward(states_)

        #Indices for matrix multiplication
        indices = np.arange(self.batch_size)

        #Calculate current state Q-values and next state max Q-value by aggregation, subtracting constant advantage mean
        #Along first dimension, which is action dimension, keeping original matrix dimensions
        
        #recall [indices,actions] is used to maintain array shape of (batch_size) instead of (batch_size,actions)
        #Essentilly by adding a a batch index to our vector array we ensure that calculated Q_pred is not tabular, but applicable for a batch update
        q_pred = T.add(V_s,
                        (A_s - A_s.mean(dim=1, keepdim=True)))[indices, actions]
        #For q_next, fetch max along the action dimension. 0th element, because max returns a tuple,
        #of which 0th position are values and 1st position the indices.
        q_next = T.add(V_s_,
                        (A_s_ - A_s_.mean(dim=1, keepdim=True)))
        
        #QEval q-values for DDQN
        q_eval = T.add(V_s_eval, (A_s_eval - A_s_eval.mean(dim=1,keepdim=True)))
        max_actions = T.argmax(q_eval, dim=1)
        q_next[dones] = 0.0
        #Build your target using the current state reward and q_next, DDQN setup
        q_target = rewards + self.gamma*q_next[indices, max_actions]

        loss = self.q_eval.loss(q_target, q_pred).to(self.q_eval.device)
        loss.backward()
        self.q_eval.optimizer.step()
        self.learn_step_counter += 1

        self.decrement_epsilon()

# %% [markdown]
# # Main Training Loop
#
# 1. For every step of a training episode, we feed an input image stack into our network to generate a probability distribution of the available actions, before using an epsilon-greedy policy to select the next action.
#
# 2. We then input this into the network, and obtain information on the next state and accompanying rewards, and store this into our buffer. We update our stack and repeat this process over a number of pre-defined steps.
#
# 3. At the end of an episode, we feed the next states into our network in order to obtain the next action. We also calculate the next reward by discounting the current one.
#
# 4. We generate our target y-values through the Q-learning update function, and train our network.
#
# 5. By minimizing the training loss, we update the network weight parameters to output improved state-action values for the next policy.

# %%
# Main thread

env = make_env('VizdoomCorridor-v0')
best_score = -np.inf
load_checkpoint = False
n_games = 20000

agent = DuelDDQNAgent(gamma=0.99, epsilon=1.0, lr=0.001,input_dims=(env.observation_space.shape),n_actions=env.action_space.n, mem_size=5000, eps_min=0.15,batch_size=32, replace=1000, eps_dec=1e-5,chkpt_dir='/content/', algo='DuelDDQNAgent',env_name='vizdoogym')

if load_checkpoint:
  agent.load_models()

fname = agent.algo + '_' + agent.env_name + '_lr' + str(agent.lr) +'_'+ str(n_games) + 'games'
figure_file = 'plots/' + fname + '.png'

n_steps = 0
scores, eps_history, steps_array = [], [], []

for i in range(n_games):
  done = False
  observation = env.reset()

  score = 0
  while not done:
    action = agent.choose_action(observation)
    observation_, reward, done, info = env.step(action)
    score += reward

    if not load_checkpoint:
      agent.store_transition(observation, action,reward, observation_, int(done))
      agent.learn()
    observation = observation_
    n_steps += 1

  scores.append(score)
  steps_array.append(n_steps)

  avg_score = np.mean(scores[-100:])
 

  if avg_score > best_score:
    best_score = avg_score
      
    
    print('Checkpoint saved at episode ', i)
    agent.save_models()

  print('Episode: ', i,'Score: ', score,' Average score: %.2f' % avg_score, 'Best average: %.2f' % best_score,'Epsilon: %.2f' % agent.epsilon, 'Steps:', n_steps)  

  eps_history.append(agent.epsilon)
  if load_checkpoint and n_steps >= 18000:
    break

#x = [i+1 for i in range(len(scores))]
# Out:
# Streaming output truncated to the last 5000 lines.
# Episode:  15013 Score:  359.3072814941406  Average score: 159.34 Best average: 211.36 Epsilon: 0.15 Steps: 503943
# Episode:  15014 Score:  198.98475646972656  Average score: 159.69 Best average: 211.36 Epsilon: 0.15 Steps: 503977
# Episode:  15015 Score:  272.48890686035156  Average score: 160.29 Best average: 211.36 Epsilon: 0.15 Steps: 504008
# Episode:  15016 Score:  173.6026153564453  Average score: 161.38 Best average: 211.36 Epsilon: 0.15 Steps: 504036
# Episode:  15017 Score:  309.9269256591797  Average score: 165.14 Best average: 211.36 Epsilon: 0.15 Steps: 504082
# Episode:  15018 Score:  275.3975524902344  Average score: 167.37 Best average: 211.36 Epsilon: 0.15 Steps: 504117
# Episode:  15019 Score:  -28.052398681640625  Average score: 166.25 Best average: 211.36 Epsilon: 0.15 Steps: 504142
# Episode:  15020 Score:  321.16575622558594  Average score: 166.37 Best average: 211.36 Epsilon: 0.15 Steps: 504180
# Episode:  15021 Score:  229.13662719726562  Average score: 169.65 Best average: 211.36 Epsilon: 0.15 Steps: 504222
# Episode:  15022 Score:  285.46556091308594  Average score: 169.57 Best average: 211.36 Epsilon: 0.15 Steps: 504261
# Episode:  15023 Score:  -18.418930053710938  Average score: 167.40 Best average: 211.36 Epsilon: 0.15 Steps: 504279
# Episode:  15024 Score:  136.87875366210938  Average score: 167.98 Best average: 211.36 Epsilon: 0.15 Steps: 504304
# Episode:  15025 Score:  84.81878662109375  Average score: 168.99 Best average: 211.36 Epsilon: 0.15 Steps: 504338
# Episode:  15026 Score:  292.79173278808594  Average score: 170.99 Best average: 211.36 Epsilon: 0.15 Steps: 504380
# Episode:  15027 Score:  140.28440856933594  Average score: 171.75 Best average: 211.36 Epsilon: 0.15 Steps: 504422
# Episode:  15028 Score:  284.5176544189453  Average score: 173.29 Best average: 211.36 Epsilon: 0.15 Steps: 504458
# Episode:  15029 Score:  320.8457489013672  Average score: 176.19 Best average: 211.36 Epsilon: 0.15 Steps: 504493
# Episode:  15030 Score:  44.074676513671875  Average score: 173.45 Best average: 211.36 Epsilon: 0.15 Steps: 504520
# Episode:  15031 Score:  258.5592956542969  Average score: 175.66 Best average: 211.36 Epsilon: 0.15 Steps: 504560
# Episode:  15032 Score:  92.66084289550781  Average score: 176.62 Best average: 211.36 Epsilon: 0.15 Steps: 504586
# Episode:  15033 Score:  263.8341369628906  Average score: 178.20 Best average: 211.36 Epsilon: 0.15 Steps: 504626
# Episode:  15034 Score:  238.6574249267578  Average score: 178.32 Best average: 211.36 Epsilon: 0.15 Steps: 504655
# Episode:  15035 Score:  256.8536682128906  Average score: 179.11 Best average: 211.36 Epsilon: 0.15 Steps: 504690
# Episode:  15036 Score:  -1.215179443359375  Average score: 177.12 Best average: 211.36 Epsilon: 0.15 Steps: 504724
# Episode:  15037 Score:  63.138946533203125  Average score: 175.08 Best average: 211.36 Epsilon: 0.15 Steps: 504752
# Episode:  15038 Score:  288.55889892578125  Average score: 176.68 Best average: 211.36 Epsilon: 0.15 Steps: 504798
# Episode:  15039 Score:  172.06451416015625  Average score: 177.42 Best average: 211.36 Epsilon: 0.15 Steps: 504843
# Episode:  15040 Score:  206.3016815185547  Average score: 176.42 Best average: 211.36 Epsilon: 0.15 Steps: 504874
# Episode:  15041 Score:  150.98654174804688  Average score: 175.57 Best average: 211.36 Epsilon: 0.15 Steps: 504923
# Episode:  15042 Score:  244.58880615234375  Average score: 179.05 Best average: 211.36 Epsilon: 0.15 Steps: 504962
# Episode:  15043 Score:  176.80685424804688  Average score: 181.96 Best average: 211.36 Epsilon: 0.15 Steps: 504997
# Episode:  15044 Score:  134.42774963378906  Average score: 180.43 Best average: 211.36 Epsilon: 0.15 Steps: 505030
# Episode:  15045 Score:  186.10321044921875  Average score: 179.37 Best average: 211.36 Epsilon: 0.15 Steps: 505084
# Episode:  15046 Score:  -83.28816223144531  Average score: 175.39 Best average: 211.36 Epsilon: 0.15 Steps: 505102
# Episode:  15047 Score:  46.0498046875  Average score: 172.91 Best average: 211.36 Epsilon: 0.15 Steps: 505135
# Episode:  15048 Score:  114.05564880371094  Average score: 170.50 Best average: 211.36 Epsilon: 0.15 Steps: 505161
# Episode:  15049 Score:  -71.45835876464844  Average score: 168.88 Best average: 211.36 Epsilon: 0.15 Steps: 505181
# Episode:  15050 Score:  -97.20686340332031  Average score: 167.49 Best average: 211.36 Epsilon: 0.15 Steps: 505201
# Episode:  15051 Score:  168.84405517578125  Average score: 166.22 Best average: 211.36 Epsilon: 0.15 Steps: 505251
# Episode:  15052 Score:  381.02789306640625  Average score: 169.33 Best average: 211.36 Epsilon: 0.15 Steps: 505295
# Episode:  15053 Score:  103.5400390625  Average score: 166.96 Best average: 211.36 Epsilon: 0.15 Steps: 505329
# Episode:  15054 Score:  208.9128875732422  Average score: 166.83 Best average: 211.36 Epsilon: 0.15 Steps: 505386
# Episode:  15055 Score:  -31.45367431640625  Average score: 163.56 Best average: 211.36 Epsilon: 0.15 Steps: 505412
# Episode:  15056 Score:  -115.94454956054688  Average score: 160.20 Best average: 211.36 Epsilon: 0.15 Steps: 505432
# Episode:  15057 Score:  31.263931274414062  Average score: 158.27 Best average: 211.36 Epsilon: 0.15 Steps: 505472
# Episode:  15058 Score:  199.9984588623047  Average score: 158.79 Best average: 211.36 Epsilon: 0.15 Steps: 505514
# Episode:  15059 Score:  106.31019592285156  Average score: 158.78 Best average: 211.36 Epsilon: 0.15 Steps: 505539
# Episode:  15060 Score:  341.0021209716797  Average score: 160.45 Best average: 211.36 Epsilon: 0.15 Steps: 505579
# Episode:  15061 Score:  183.079345703125  Average score: 161.90 Best average: 211.36 Epsilon: 0.15 Steps: 505629
# Episode:  15062 Score:  289.81861877441406  Average score: 162.90 Best average: 211.36 Epsilon: 0.15 Steps: 505671
# Episode:  15063 Score:  -53.742645263671875  Average score: 158.57 Best average: 211.36 Epsilon: 0.15 Steps: 505684
# Episode:  15064 Score:  47.771575927734375  Average score: 155.06 Best average: 211.36 Epsilon: 0.15 Steps: 505717
# Episode:  15065 Score:  229.7439727783203  Average score: 155.21 Best average: 211.36 Epsilon: 0.15 Steps: 505767
# Episode:  15066 Score:  -90.93055725097656  Average score: 151.93 Best average: 211.36 Epsilon: 0.15 Steps: 505787
# Episode:  15067 Score:  2.0649871826171875  Average score: 148.40 Best average: 211.36 Epsilon: 0.15 Steps: 505821
# Episode:  15068 Score:  -15.468856811523438  Average score: 146.56 Best average: 211.36 Epsilon: 0.15 Steps: 505847
# Episode:  15069 Score:  -86.82260131835938  Average score: 144.53 Best average: 211.36 Epsilon: 0.15 Steps: 505874
# Episode:  15070 Score:  -86.85348510742188  Average score: 141.43 Best average: 211.36 Epsilon: 0.15 Steps: 505887
# Episode:  15071 Score:  99.13604736328125  Average score: 140.98 Best average: 211.36 Epsilon: 0.15 Steps: 505922
# Episode:  15072 Score:  271.91627502441406  Average score: 140.90 Best average: 211.36 Epsilon: 0.15 Steps: 505968
# Episode:  15073 Score:  -27.201278686523438  Average score: 140.08 Best average: 211.36 Epsilon: 0.15 Steps: 505987
# Episode:  15074 Score:  305.4412078857422  Average score: 142.45 Best average: 211.36 Epsilon: 0.15 Steps: 506023
# Episode:  15075 Score:  91.85653686523438  Average score: 143.24 Best average: 211.36 Epsilon: 0.15 Steps: 506048
# Episode:  15076 Score:  217.15570068359375  Average score: 145.40 Best average: 211.36 Epsilon: 0.15 Steps: 506090
# Episode:  15077 Score:  -6.51373291015625  Average score: 142.98 Best average: 211.36 Epsilon: 0.15 Steps: 506116
# Episode:  15078 Score:  114.19029235839844  Average score: 141.94 Best average: 211.36 Epsilon: 0.15 Steps: 506157
# Episode:  15079 Score:  247.9785614013672  Average score: 141.00 Best average: 211.36 Epsilon: 0.15 Steps: 506197
# Episode:  15080 Score:  2.2052764892578125  Average score: 140.39 Best average: 211.36 Epsilon: 0.15 Steps: 506232
# Episode:  15081 Score:  243.8672332763672  Average score: 141.20 Best average: 211.36 Epsilon: 0.15 Steps: 506280
# Episode:  15082 Score:  52.548492431640625  Average score: 140.08 Best average: 211.36 Epsilon: 0.15 Steps: 506337
# Episode:  15083 Score:  -53.82853698730469  Average score: 137.04 Best average: 211.36 Epsilon: 0.15 Steps: 506349
# Episode:  15084 Score:  219.9831085205078  Average score: 136.94 Best average: 211.36 Epsilon: 0.15 Steps: 506384
# Episode:  15085 Score:  154.37733459472656  Average score: 136.29 Best average: 211.36 Epsilon: 0.15 Steps: 506463
# Episode:  15086 Score:  -108.77938842773438  Average score: 134.14 Best average: 211.36 Epsilon: 0.15 Steps: 506474
# Episode:  15087 Score:  -115.08258056640625  Average score: 133.64 Best average: 211.36 Epsilon: 0.15 Steps: 506495
# Episode:  15088 Score:  155.50363159179688  Average score: 135.55 Best average: 211.36 Epsilon: 0.15 Steps: 506536
# Episode:  15089 Score:  -56.57859802246094  Average score: 131.40 Best average: 211.36 Epsilon: 0.15 Steps: 506557
# Episode:  15090 Score:  32.702484130859375  Average score: 131.59 Best average: 211.36 Epsilon: 0.15 Steps: 506590
# Episode:  15091 Score:  247.2925567626953  Average score: 131.52 Best average: 211.36 Epsilon: 0.15 Steps: 506630
# Episode:  15092 Score:  303.64503479003906  Average score: 131.48 Best average: 211.36 Epsilon: 0.15 Steps: 506667
# Episode:  15093 Score:  211.16490173339844  Average score: 130.70 Best average: 211.36 Epsilon: 0.15 Steps: 506698
# Episode:  15094 Score:  -86.70796203613281  Average score: 127.13 Best average: 211.36 Epsilon: 0.15 Steps: 506719
# Episode:  15095 Score:  -29.356399536132812  Average score: 124.32 Best average: 211.36 Epsilon: 0.15 Steps: 506747
# Episode:  15096 Score:  115.89997863769531  Average score: 125.61 Best average: 211.36 Epsilon: 0.15 Steps: 506782
# Episode:  15097 Score:  -96.61123657226562  Average score: 120.90 Best average: 211.36 Epsilon: 0.15 Steps: 506810
# Episode:  15098 Score:  6.015716552734375  Average score: 121.81 Best average: 211.36 Epsilon: 0.15 Steps: 506830
# Episode:  15099 Score:  -115.97578430175781  Average score: 120.11 Best average: 211.36 Epsilon: 0.15 Steps: 506843
# Episode:  15100 Score:  -93.17184448242188  Average score: 119.46 Best average: 211.36 Epsilon: 0.15 Steps: 506862
# Episode:  15101 Score:  329.1825714111328  Average score: 119.99 Best average: 211.36 Epsilon: 0.15 Steps: 506890
# Episode:  15102 Score:  58.0462646484375  Average score: 121.03 Best average: 211.36 Epsilon: 0.15 Steps: 506931
# Episode:  15103 Score:  167.87197875976562  Average score: 122.00 Best average: 211.36 Epsilon: 0.15 Steps: 506966
# Episode:  15104 Score:  -69.40390014648438  Average score: 122.19 Best average: 211.36 Epsilon: 0.15 Steps: 506987
# Episode:  15105 Score:  -112.19918823242188  Average score: 118.38 Best average: 211.36 Epsilon: 0.15 Steps: 507016
# Episode:  15106 Score:  279.1310577392578  Average score: 119.69 Best average: 211.36 Epsilon: 0.15 Steps: 507070
# Episode:  15107 Score:  262.2168273925781  Average score: 119.57 Best average: 211.36 Epsilon: 0.15 Steps: 507104
# Episode:  15108 Score:  278.1339111328125  Average score: 120.08 Best average: 211.36 Epsilon: 0.15 Steps: 507155
# Episode:  15109 Score:  -81.67619323730469  Average score: 118.76 Best average: 211.36 Epsilon: 0.15 Steps: 507175
# Episode:  15110 Score:  159.1609649658203  Average score: 120.19 Best average: 211.36 Epsilon: 0.15 Steps: 507201
# Episode:  15111 Score:  257.4340515136719  Average score: 122.20 Best average: 211.36 Epsilon: 0.15 Steps: 507265
# Episode:  15112 Score:  367.8561706542969  Average score: 123.35 Best average: 211.36 Epsilon: 0.15 Steps: 507311
# Episode:  15113 Score:  -26.932586669921875  Average score: 119.48 Best average: 211.36 Epsilon: 0.15 Steps: 507330
# Episode:  15114 Score:  68.63984680175781  Average score: 118.18 Best average: 211.36 Epsilon: 0.15 Steps: 507365
# Episode:  15115 Score:  200.51036071777344  Average score: 117.46 Best average: 211.36 Epsilon: 0.15 Steps: 507406
# Episode:  15116 Score:  -91.32525634765625  Average score: 114.81 Best average: 211.36 Epsilon: 0.15 Steps: 507425
# Episode:  15117 Score:  328.8467254638672  Average score: 115.00 Best average: 211.36 Epsilon: 0.15 Steps: 507467
# Episode:  15118 Score:  98.48002624511719  Average score: 113.23 Best average: 211.36 Epsilon: 0.15 Steps: 507487
# Episode:  15119 Score:  316.7023620605469  Average score: 116.68 Best average: 211.36 Epsilon: 0.15 Steps: 507525
# Episode:  15120 Score:  232.1868438720703  Average score: 115.79 Best average: 211.36 Epsilon: 0.15 Steps: 507558
# Episode:  15121 Score:  -115.99496459960938  Average score: 112.34 Best average: 211.36 Epsilon: 0.15 Steps: 507578
# Episode:  15122 Score:  9.0213623046875  Average score: 109.57 Best average: 211.36 Epsilon: 0.15 Steps: 507597
# Episode:  15123 Score:  270.66807556152344  Average score: 112.46 Best average: 211.36 Epsilon: 0.15 Steps: 507629
# Episode:  15124 Score:  -50.980499267578125  Average score: 110.59 Best average: 211.36 Epsilon: 0.15 Steps: 507641
# Episode:  15125 Score:  223.12437438964844  Average score: 111.97 Best average: 211.36 Epsilon: 0.15 Steps: 507680
# Episode:  15126 Score:  -39.2156982421875  Average score: 108.65 Best average: 211.36 Epsilon: 0.15 Steps: 507700
# Episode:  15127 Score:  237.35585021972656  Average score: 109.62 Best average: 211.36 Epsilon: 0.15 Steps: 507734
# Episode:  15128 Score:  349.1298065185547  Average score: 110.27 Best average: 211.36 Epsilon: 0.15 Steps: 507773
# Episode:  15129 Score:  326.2852325439453  Average score: 110.32 Best average: 211.36 Epsilon: 0.15 Steps: 507803
# Episode:  15130 Score:  111.22787475585938  Average score: 110.99 Best average: 211.36 Epsilon: 0.15 Steps: 507833
# Episode:  15131 Score:  227.28407287597656  Average score: 110.68 Best average: 211.36 Epsilon: 0.15 Steps: 507867
# Episode:  15132 Score:  43.61985778808594  Average score: 110.19 Best average: 211.36 Epsilon: 0.15 Steps: 507892
# Episode:  15133 Score:  72.82827758789062  Average score: 108.28 Best average: 211.36 Epsilon: 0.15 Steps: 507935
# Episode:  15134 Score:  33.54368591308594  Average score: 106.23 Best average: 211.36 Epsilon: 0.15 Steps: 507955
# Episode:  15135 Score:  5.5125732421875  Average score: 103.71 Best average: 211.36 Epsilon: 0.15 Steps: 507982
# Episode:  15136 Score:  210.5630340576172  Average score: 105.83 Best average: 211.36 Epsilon: 0.15 Steps: 508022
# Episode:  15137 Score:  -115.9984130859375  Average score: 104.04 Best average: 211.36 Epsilon: 0.15 Steps: 508086
# Episode:  15138 Score:  74.62640380859375  Average score: 101.90 Best average: 211.36 Epsilon: 0.15 Steps: 508121
# Episode:  15139 Score:  114.76445007324219  Average score: 101.33 Best average: 211.36 Epsilon: 0.15 Steps: 508162
# Episode:  15140 Score:  139.0797576904297  Average score: 100.66 Best average: 211.36 Epsilon: 0.15 Steps: 508203
# Episode:  15141 Score:  -31.419189453125  Average score: 98.83 Best average: 211.36 Epsilon: 0.15 Steps: 508228
# Episode:  15142 Score:  9.8021240234375  Average score: 96.48 Best average: 211.36 Epsilon: 0.15 Steps: 508261
# Episode:  15143 Score:  -75.77809143066406  Average score: 93.96 Best average: 211.36 Epsilon: 0.15 Steps: 508280
# Episode:  15144 Score:  99.64521789550781  Average score: 93.61 Best average: 211.36 Epsilon: 0.15 Steps: 508306
# Episode:  15145 Score:  -69.93977355957031  Average score: 91.05 Best average: 211.36 Epsilon: 0.15 Steps: 508341
# Episode:  15146 Score:  235.69505310058594  Average score: 94.24 Best average: 211.36 Epsilon: 0.15 Steps: 508396
# Episode:  15147 Score:  111.17298889160156  Average score: 94.89 Best average: 211.36 Epsilon: 0.15 Steps: 508422
# Episode:  15148 Score:  -69.44233703613281  Average score: 93.06 Best average: 211.36 Epsilon: 0.15 Steps: 508435
# Episode:  15149 Score:  240.52670288085938  Average score: 96.18 Best average: 211.36 Epsilon: 0.15 Steps: 508471
# Episode:  15150 Score:  -76.17726135253906  Average score: 96.39 Best average: 211.36 Epsilon: 0.15 Steps: 508483
# Episode:  15151 Score:  -115.99784851074219  Average score: 93.54 Best average: 211.36 Epsilon: 0.15 Steps: 508495
# Episode:  15152 Score:  -27.417037963867188  Average score: 89.45 Best average: 211.36 Epsilon: 0.15 Steps: 508523
# Episode:  15153 Score:  -38.3748779296875  Average score: 88.03 Best average: 211.36 Epsilon: 0.15 Steps: 508536
# Episode:  15154 Score:  395.09828186035156  Average score: 89.90 Best average: 211.36 Epsilon: 0.15 Steps: 508589
# Episode:  15155 Score:  -1.511077880859375  Average score: 90.20 Best average: 211.36 Epsilon: 0.15 Steps: 508610
# Episode:  15156 Score:  273.2066192626953  Average score: 94.09 Best average: 211.36 Epsilon: 0.15 Steps: 508652
# Episode:  15157 Score:  -68.14784240722656  Average score: 93.09 Best average: 211.36 Epsilon: 0.15 Steps: 508671
# Episode:  15158 Score:  217.75479125976562  Average score: 93.27 Best average: 211.36 Epsilon: 0.15 Steps: 508712
# Episode:  15159 Score:  344.48670959472656  Average score: 95.65 Best average: 211.36 Epsilon: 0.15 Steps: 508746
# Episode:  15160 Score:  85.29402160644531  Average score: 93.10 Best average: 211.36 Epsilon: 0.15 Steps: 508765
# Episode:  15161 Score:  312.15736389160156  Average score: 94.39 Best average: 211.36 Epsilon: 0.15 Steps: 508811
# Episode:  15162 Score:  177.10525512695312  Average score: 93.26 Best average: 211.36 Epsilon: 0.15 Steps: 508852
# Episode:  15163 Score:  212.79421997070312  Average score: 95.92 Best average: 211.36 Epsilon: 0.15 Steps: 508889
# Episode:  15164 Score:  293.5013732910156  Average score: 98.38 Best average: 211.36 Epsilon: 0.15 Steps: 508937
# Episode:  15165 Score:  159.23316955566406  Average score: 97.68 Best average: 211.36 Epsilon: 0.15 Steps: 508972
# Episode:  15166 Score:  112.24266052246094  Average score: 99.71 Best average: 211.36 Epsilon: 0.15 Steps: 508998
# Episode:  15167 Score:  327.15309143066406  Average score: 102.96 Best average: 211.36 Epsilon: 0.15 Steps: 509039
# Episode:  15168 Score:  270.33929443359375  Average score: 105.82 Best average: 211.36 Epsilon: 0.15 Steps: 509083
# Episode:  15169 Score:  228.6147918701172  Average score: 108.97 Best average: 211.36 Epsilon: 0.15 Steps: 509116
# Episode:  15170 Score:  164.2777557373047  Average score: 111.48 Best average: 211.36 Epsilon: 0.15 Steps: 509150
# Episode:  15171 Score:  158.0117950439453  Average score: 112.07 Best average: 211.36 Epsilon: 0.15 Steps: 509184
# Episode:  15172 Score:  -115.99107360839844  Average score: 108.19 Best average: 211.36 Epsilon: 0.15 Steps: 509204
# Episode:  15173 Score:  130.85533142089844  Average score: 109.77 Best average: 211.36 Epsilon: 0.15 Steps: 509246
# Episode:  15174 Score:  -70.93638610839844  Average score: 106.01 Best average: 211.36 Epsilon: 0.15 Steps: 509259
# Episode:  15175 Score:  33.97349548339844  Average score: 105.43 Best average: 211.36 Epsilon: 0.15 Steps: 509285
# Episode:  15176 Score:  -8.03033447265625  Average score: 103.18 Best average: 211.36 Epsilon: 0.15 Steps: 509303
# Episode:  15177 Score:  275.7779846191406  Average score: 106.00 Best average: 211.36 Epsilon: 0.15 Steps: 509340
# Episode:  15178 Score:  179.29722595214844  Average score: 106.65 Best average: 211.36 Epsilon: 0.15 Steps: 509381
# Episode:  15179 Score:  268.48291015625  Average score: 106.86 Best average: 211.36 Epsilon: 0.15 Steps: 509412
# Episode:  15180 Score:  176.67787170410156  Average score: 108.60 Best average: 211.36 Epsilon: 0.15 Steps: 509438
# Episode:  15181 Score:  236.30372619628906  Average score: 108.53 Best average: 211.36 Epsilon: 0.15 Steps: 509468
# Episode:  15182 Score:  168.7943878173828  Average score: 109.69 Best average: 211.36 Epsilon: 0.15 Steps: 509503
# Episode:  15183 Score:  51.706573486328125  Average score: 110.74 Best average: 211.36 Epsilon: 0.15 Steps: 509528
# Episode:  15184 Score:  148.3142852783203  Average score: 110.03 Best average: 211.36 Epsilon: 0.15 Steps: 509559
# Episode:  15185 Score:  118.17733764648438  Average score: 109.67 Best average: 211.36 Epsilon: 0.15 Steps: 509585
# Episode:  15186 Score:  170.6769561767578  Average score: 112.46 Best average: 211.36 Epsilon: 0.15 Steps: 509618
# Episode:  15187 Score:  6.81292724609375  Average score: 113.68 Best average: 211.36 Epsilon: 0.15 Steps: 509638
# Episode:  15188 Score:  57.43418884277344  Average score: 112.70 Best average: 211.36 Epsilon: 0.15 Steps: 509664
# Episode:  15189 Score:  210.86131286621094  Average score: 115.37 Best average: 211.36 Epsilon: 0.15 Steps: 509703
# Episode:  15190 Score:  19.47979736328125  Average score: 115.24 Best average: 211.36 Epsilon: 0.15 Steps: 509721
# Episode:  15191 Score:  37.537078857421875  Average score: 113.14 Best average: 211.36 Epsilon: 0.15 Steps: 509749
# Episode:  15192 Score:  310.37220764160156  Average score: 113.21 Best average: 211.36 Epsilon: 0.15 Steps: 509790
# Episode:  15193 Score:  32.914886474609375  Average score: 111.43 Best average: 211.36 Epsilon: 0.15 Steps: 509812
# Episode:  15194 Score:  23.047027587890625  Average score: 112.53 Best average: 211.36 Epsilon: 0.15 Steps: 509846
# Episode:  15195 Score:  153.4909210205078  Average score: 114.35 Best average: 211.36 Epsilon: 0.15 Steps: 509886
# Episode:  15196 Score:  -46.37895202636719  Average score: 112.73 Best average: 211.36 Epsilon: 0.15 Steps: 509899
# Episode:  15197 Score:  13.322677612304688  Average score: 113.83 Best average: 211.36 Epsilon: 0.15 Steps: 509926
# Episode:  15198 Score:  364.08802795410156  Average score: 117.41 Best average: 211.36 Epsilon: 0.15 Steps: 509967
# Episode:  15199 Score:  268.14161682128906  Average score: 121.25 Best average: 211.36 Epsilon: 0.15 Steps: 510000
# Episode:  15200 Score:  66.45675659179688  Average score: 122.85 Best average: 211.36 Epsilon: 0.15 Steps: 510020
# Episode:  15201 Score:  30.108551025390625  Average score: 119.86 Best average: 211.36 Epsilon: 0.15 Steps: 510054
# Episode:  15202 Score:  245.4723663330078  Average score: 121.73 Best average: 211.36 Epsilon: 0.15 Steps: 510084
# Episode:  15203 Score:  156.49533081054688  Average score: 121.62 Best average: 211.36 Epsilon: 0.15 Steps: 510126
# Episode:  15204 Score:  320.64674377441406  Average score: 125.52 Best average: 211.36 Epsilon: 0.15 Steps: 510173
# Episode:  15205 Score:  -9.561614990234375  Average score: 126.55 Best average: 211.36 Epsilon: 0.15 Steps: 510202
# Episode:  15206 Score:  -58.10546875  Average score: 123.17 Best average: 211.36 Epsilon: 0.15 Steps: 510220
# Episode:  15207 Score:  96.91566467285156  Average score: 121.52 Best average: 211.36 Epsilon: 0.15 Steps: 510253
# Episode:  15208 Score:  259.26251220703125  Average score: 121.33 Best average: 211.36 Epsilon: 0.15 Steps: 510299
# Episode:  15209 Score:  154.81353759765625  Average score: 123.70 Best average: 211.36 Epsilon: 0.15 Steps: 510334
# Episode:  15210 Score:  208.4586639404297  Average score: 124.19 Best average: 211.36 Epsilon: 0.15 Steps: 510373
# Episode:  15211 Score:  -66.65927124023438  Average score: 120.95 Best average: 211.36 Epsilon: 0.15 Steps: 510407
# Episode:  15212 Score:  148.9869384765625  Average score: 118.76 Best average: 211.36 Epsilon: 0.15 Steps: 510448
# Episode:  15213 Score:  -72.54969787597656  Average score: 118.30 Best average: 211.36 Epsilon: 0.15 Steps: 510460
# Episode:  15214 Score:  327.0511474609375  Average score: 120.89 Best average: 211.36 Epsilon: 0.15 Steps: 510494
# Episode:  15215 Score:  199.1346893310547  Average score: 120.87 Best average: 211.36 Epsilon: 0.15 Steps: 510543
# Episode:  15216 Score:  304.9195556640625  Average score: 124.84 Best average: 211.36 Epsilon: 0.15 Steps: 510594
# Episode:  15217 Score:  -23.98504638671875  Average score: 121.31 Best average: 211.36 Epsilon: 0.15 Steps: 510620
# Episode:  15218 Score:  -65.25102233886719  Average score: 119.67 Best average: 211.36 Epsilon: 0.15 Steps: 510661
# Episode:  15219 Score:  181.8372039794922  Average score: 118.32 Best average: 211.36 Epsilon: 0.15 Steps: 510702
# Episode:  15220 Score:  263.8725128173828  Average score: 118.64 Best average: 211.36 Epsilon: 0.15 Steps: 510756
# Episode:  15221 Score:  -90.24273681640625  Average score: 118.90 Best average: 211.36 Epsilon: 0.15 Steps: 510769
# Episode:  15222 Score:  -90.92391967773438  Average score: 117.90 Best average: 211.36 Epsilon: 0.15 Steps: 510798
# Episode:  15223 Score:  269.3417053222656  Average score: 117.88 Best average: 211.36 Epsilon: 0.15 Steps: 510832
# Episode:  15224 Score:  249.49627685546875  Average score: 120.89 Best average: 211.36 Epsilon: 0.15 Steps: 510866
# Episode:  15225 Score:  283.0894470214844  Average score: 121.49 Best average: 211.36 Epsilon: 0.15 Steps: 510918
# Episode:  15226 Score:  25.707351684570312  Average score: 122.14 Best average: 211.36 Epsilon: 0.15 Steps: 510951
# Episode:  15227 Score:  1.2630615234375  Average score: 119.78 Best average: 211.36 Epsilon: 0.15 Steps: 510977
# Episode:  15228 Score:  -46.950347900390625  Average score: 115.82 Best average: 211.36 Epsilon: 0.15 Steps: 510997
# Episode:  15229 Score:  129.57989501953125  Average score: 113.85 Best average: 211.36 Epsilon: 0.15 Steps: 511037
# Episode:  15230 Score:  210.2430877685547  Average score: 114.84 Best average: 211.36 Epsilon: 0.15 Steps: 511064
# Episode:  15231 Score:  306.43479919433594  Average score: 115.63 Best average: 211.36 Epsilon: 0.15 Steps: 511108
# Episode:  15232 Score:  237.2163543701172  Average score: 117.57 Best average: 211.36 Epsilon: 0.15 Steps: 511143
# Episode:  15233 Score:  221.0650634765625  Average score: 119.05 Best average: 211.36 Epsilon: 0.15 Steps: 511185
# Episode:  15234 Score:  97.35867309570312  Average score: 119.69 Best average: 211.36 Epsilon: 0.15 Steps: 511220
# Episode:  15235 Score:  0.89056396484375  Average score: 119.64 Best average: 211.36 Epsilon: 0.15 Steps: 511231
# Episode:  15236 Score:  304.06236267089844  Average score: 120.58 Best average: 211.36 Epsilon: 0.15 Steps: 511270
# Episode:  15237 Score:  9.823822021484375  Average score: 121.83 Best average: 211.36 Epsilon: 0.15 Steps: 511298
# Episode:  15238 Score:  -115.94895935058594  Average score: 119.93 Best average: 211.36 Epsilon: 0.15 Steps: 511311
# Episode:  15239 Score:  42.36274719238281  Average score: 119.20 Best average: 211.36 Epsilon: 0.15 Steps: 511336
# Episode:  15240 Score:  129.27853393554688  Average score: 119.11 Best average: 211.36 Epsilon: 0.15 Steps: 511362
# Episode:  15241 Score:  -52.991485595703125  Average score: 118.89 Best average: 211.36 Epsilon: 0.15 Steps: 511388
# Episode:  15242 Score:  145.99371337890625  Average score: 120.25 Best average: 211.36 Epsilon: 0.15 Steps: 511436
# Episode:  15243 Score:  280.4982604980469  Average score: 123.81 Best average: 211.36 Epsilon: 0.15 Steps: 511491
# Episode:  15244 Score:  -84.13885498046875  Average score: 121.98 Best average: 211.36 Epsilon: 0.15 Steps: 511524
# Episode:  15245 Score:  25.9552001953125  Average score: 122.94 Best average: 211.36 Epsilon: 0.15 Steps: 511551
# Episode:  15246 Score:  -21.01849365234375  Average score: 120.37 Best average: 211.36 Epsilon: 0.15 Steps: 511572
# Episode:  15247 Score:  -22.942535400390625  Average score: 119.03 Best average: 211.36 Epsilon: 0.15 Steps: 511591
# Episode:  15248 Score:  212.6696014404297  Average score: 121.85 Best average: 211.36 Epsilon: 0.15 Steps: 511625
# Episode:  15249 Score:  232.8655548095703  Average score: 121.77 Best average: 211.36 Epsilon: 0.15 Steps: 511673
# Episode:  15250 Score:  -64.58497619628906  Average score: 121.89 Best average: 211.36 Epsilon: 0.15 Steps: 511685
# Episode:  15251 Score:  179.29942321777344  Average score: 124.84 Best average: 211.36 Epsilon: 0.15 Steps: 511733
# Episode:  15252 Score:  -69.60270690917969  Average score: 124.42 Best average: 211.36 Epsilon: 0.15 Steps: 511754
# Episode:  15253 Score:  -115.95828247070312  Average score: 123.64 Best average: 211.36 Epsilon: 0.15 Steps: 511767
# Episode:  15254 Score:  -40.92083740234375  Average score: 119.28 Best average: 211.36 Epsilon: 0.15 Steps: 511786
# Episode:  15255 Score:  -61.22526550292969  Average score: 118.69 Best average: 211.36 Epsilon: 0.15 Steps: 511798
# Episode:  15256 Score:  -37.942779541015625  Average score: 115.57 Best average: 211.36 Epsilon: 0.15 Steps: 511824
# Episode:  15257 Score:  57.13934326171875  Average score: 116.83 Best average: 211.36 Epsilon: 0.15 Steps: 511851
# Episode:  15258 Score:  -75.89768981933594  Average score: 113.89 Best average: 211.36 Epsilon: 0.15 Steps: 511863
# Episode:  15259 Score:  -115.97996520996094  Average score: 109.29 Best average: 211.36 Epsilon: 0.15 Steps: 511874
# Episode:  15260 Score:  17.774871826171875  Average score: 108.61 Best average: 211.36 Epsilon: 0.15 Steps: 511909
# Episode:  15261 Score:  300.2884063720703  Average score: 108.49 Best average: 211.36 Epsilon: 0.15 Steps: 511950
# Episode:  15262 Score:  127.90187072753906  Average score: 108.00 Best average: 211.36 Epsilon: 0.15 Steps: 511998
# Episode:  15263 Score:  -91.37200927734375  Average score: 104.96 Best average: 211.36 Epsilon: 0.15 Steps: 512018
# Episode:  15264 Score:  285.0897674560547  Average score: 104.87 Best average: 211.36 Epsilon: 0.15 Steps: 512073
# Episode:  15265 Score:  24.057662963867188  Average score: 103.52 Best average: 211.36 Epsilon: 0.15 Steps: 512100
# Episode:  15266 Score:  -77.46772766113281  Average score: 101.63 Best average: 211.36 Epsilon: 0.15 Steps: 512120
# Episode:  15267 Score:  -8.05181884765625  Average score: 98.27 Best average: 211.36 Epsilon: 0.15 Steps: 512140
# Episode:  15268 Score:  51.82147216796875  Average score: 96.09 Best average: 211.36 Epsilon: 0.15 Steps: 512173
# Episode:  15269 Score:  -61.48313903808594  Average score: 93.19 Best average: 211.36 Epsilon: 0.15 Steps: 512191
# Episode:  15270 Score:  -83.99539184570312  Average score: 90.70 Best average: 211.36 Epsilon: 0.15 Steps: 512202
# Episode:  15271 Score:  -58.369354248046875  Average score: 88.54 Best average: 211.36 Epsilon: 0.15 Steps: 512213
# Episode:  15272 Score:  79.20161437988281  Average score: 90.49 Best average: 211.36 Epsilon: 0.15 Steps: 512233
# Episode:  15273 Score:  176.48919677734375  Average score: 90.95 Best average: 211.36 Epsilon: 0.15 Steps: 512276
# Episode:  15274 Score:  279.2250518798828  Average score: 94.45 Best average: 211.36 Epsilon: 0.15 Steps: 512341
# Episode:  15275 Score:  218.33363342285156  Average score: 96.29 Best average: 211.36 Epsilon: 0.15 Steps: 512408
# Episode:  15276 Score:  -114.32487487792969  Average score: 95.23 Best average: 211.36 Epsilon: 0.15 Steps: 512413
# Episode:  15277 Score:  246.09524536132812  Average score: 94.93 Best average: 211.36 Epsilon: 0.15 Steps: 512462
# Episode:  15278 Score:  -77.33551025390625  Average score: 92.37 Best average: 211.36 Epsilon: 0.15 Steps: 512475
# Episode:  15279 Score:  -65.12687683105469  Average score: 89.03 Best average: 211.36 Epsilon: 0.15 Steps: 512494
# Episode:  15280 Score:  -115.99183654785156  Average score: 86.11 Best average: 211.36 Epsilon: 0.15 Steps: 512505
# Episode:  15281 Score:  -115.8814697265625  Average score: 82.58 Best average: 211.36 Epsilon: 0.15 Steps: 512518
# Episode:  15282 Score:  236.298828125  Average score: 83.26 Best average: 211.36 Epsilon: 0.15 Steps: 512558
# Episode:  15283 Score:  -95.71711730957031  Average score: 81.78 Best average: 211.36 Epsilon: 0.15 Steps: 512577
# Episode:  15284 Score:  306.43226623535156  Average score: 83.37 Best average: 211.36 Epsilon: 0.15 Steps: 512622
# Episode:  15285 Score:  46.31903076171875  Average score: 82.65 Best average: 211.36 Epsilon: 0.15 Steps: 512649
# Episode:  15286 Score:  169.61898803710938  Average score: 82.64 Best average: 211.36 Epsilon: 0.15 Steps: 512712
# Episode:  15287 Score:  32.10145568847656  Average score: 82.89 Best average: 211.36 Epsilon: 0.15 Steps: 512738
# Episode:  15288 Score:  -46.93254089355469  Average score: 81.85 Best average: 211.36 Epsilon: 0.15 Steps: 512764
# Episode:  15289 Score:  325.51670837402344  Average score: 82.99 Best average: 211.36 Epsilon: 0.15 Steps: 512811
# Episode:  15290 Score:  -115.22994995117188  Average score: 81.65 Best average: 211.36 Epsilon: 0.15 Steps: 512823
# Episode:  15291 Score:  262.32200622558594  Average score: 83.89 Best average: 211.36 Epsilon: 0.15 Steps: 512880
# Episode:  15292 Score:  124.7889404296875  Average score: 82.04 Best average: 211.36 Epsilon: 0.15 Steps: 512914
# Episode:  15293 Score:  7.6375885009765625  Average score: 81.78 Best average: 211.36 Epsilon: 0.15 Steps: 512940
# Episode:  15294 Score:  223.5703582763672  Average score: 83.79 Best average: 211.36 Epsilon: 0.15 Steps: 512997
# Episode:  15295 Score:  195.14920043945312  Average score: 84.21 Best average: 211.36 Epsilon: 0.15 Steps: 513060
# Episode:  15296 Score:  251.77252197265625  Average score: 87.19 Best average: 211.36 Epsilon: 0.15 Steps: 513125
# Episode:  15297 Score:  173.6761474609375  Average score: 88.79 Best average: 211.36 Epsilon: 0.15 Steps: 513150
# Episode:  15298 Score:  203.64378356933594  Average score: 87.19 Best average: 211.36 Epsilon: 0.15 Steps: 513214
# Episode:  15299 Score:  274.4388122558594  Average score: 87.25 Best average: 211.36 Epsilon: 0.15 Steps: 513249
# Episode:  15300 Score:  -10.120040893554688  Average score: 86.48 Best average: 211.36 Epsilon: 0.15 Steps: 513269
# Episode:  15301 Score:  165.65557861328125  Average score: 87.84 Best average: 211.36 Epsilon: 0.15 Steps: 513296
# Episode:  15302 Score:  -31.830657958984375  Average score: 85.07 Best average: 211.36 Epsilon: 0.15 Steps: 513316
# Episode:  15303 Score:  74.89384460449219  Average score: 84.25 Best average: 211.36 Epsilon: 0.15 Steps: 513337
# Episode:  15304 Score:  208.58172607421875  Average score: 83.13 Best average: 211.36 Epsilon: 0.15 Steps: 513371
# Episode:  15305 Score:  32.0789794921875  Average score: 83.55 Best average: 211.36 Epsilon: 0.15 Steps: 513405
# Episode:  15306 Score:  293.23167419433594  Average score: 87.06 Best average: 211.36 Epsilon: 0.15 Steps: 513438
# Episode:  15307 Score:  -15.715240478515625  Average score: 85.93 Best average: 211.36 Epsilon: 0.15 Steps: 513464
# Episode:  15308 Score:  -46.152435302734375  Average score: 82.88 Best average: 211.36 Epsilon: 0.15 Steps: 513476
# Episode:  15309 Score:  172.842041015625  Average score: 83.06 Best average: 211.36 Epsilon: 0.15 Steps: 513501
# Episode:  15310 Score:  123.34968566894531  Average score: 82.21 Best average: 211.36 Epsilon: 0.15 Steps: 513527
# Episode:  15311 Score:  -23.158126831054688  Average score: 82.64 Best average: 211.36 Epsilon: 0.15 Steps: 513548
# Episode:  15312 Score:  -115.94309997558594  Average score: 79.99 Best average: 211.36 Epsilon: 0.15 Steps: 513566
# Episode:  15313 Score:  0.1458282470703125  Average score: 80.72 Best average: 211.36 Epsilon: 0.15 Steps: 513591
# Episode:  15314 Score:  240.611083984375  Average score: 79.86 Best average: 211.36 Epsilon: 0.15 Steps: 513632
# Episode:  15315 Score:  -10.690658569335938  Average score: 77.76 Best average: 211.36 Epsilon: 0.15 Steps: 513651
# Episode:  15316 Score:  285.009033203125  Average score: 77.56 Best average: 211.36 Epsilon: 0.15 Steps: 513683
# Episode:  15317 Score:  254.22467041015625  Average score: 80.34 Best average: 211.36 Epsilon: 0.15 Steps: 513725
# Episode:  15318 Score:  19.5174560546875  Average score: 81.19 Best average: 211.36 Epsilon: 0.15 Steps: 513751
# Episode:  15319 Score:  308.82374572753906  Average score: 82.46 Best average: 211.36 Epsilon: 0.15 Steps: 513790
# Episode:  15320 Score:  301.4435577392578  Average score: 82.83 Best average: 211.36 Epsilon: 0.15 Steps: 513841
# Episode:  15321 Score:  128.47398376464844  Average score: 85.02 Best average: 211.36 Epsilon: 0.15 Steps: 513867
# Episode:  15322 Score:  -60.721923828125  Average score: 85.32 Best average: 211.36 Epsilon: 0.15 Steps: 513893
# Episode:  15323 Score:  -108.73420715332031  Average score: 81.54 Best average: 211.36 Epsilon: 0.15 Steps: 513906
# Episode:  15324 Score:  209.83738708496094  Average score: 81.15 Best average: 211.36 Epsilon: 0.15 Steps: 513948
# Episode:  15325 Score:  -81.67727661132812  Average score: 77.50 Best average: 211.36 Epsilon: 0.15 Steps: 513961
# Episode:  15326 Score:  206.91851806640625  Average score: 79.31 Best average: 211.36 Epsilon: 0.15 Steps: 513999
# Episode:  15327 Score:  109.71432495117188  Average score: 80.40 Best average: 211.36 Epsilon: 0.15 Steps: 514026
# Episode:  15328 Score:  236.50770568847656  Average score: 83.23 Best average: 211.36 Epsilon: 0.15 Steps: 514056
# Episode:  15329 Score:  -31.899520874023438  Average score: 81.62 Best average: 211.36 Epsilon: 0.15 Steps: 514069
# Episode:  15330 Score:  178.47018432617188  Average score: 81.30 Best average: 211.36 Epsilon: 0.15 Steps: 514102
# Episode:  15331 Score:  -62.52986145019531  Average score: 77.61 Best average: 211.36 Epsilon: 0.15 Steps: 514115
# Episode:  15332 Score:  694.4970855712891  Average score: 82.18 Best average: 211.36 Epsilon: 0.15 Steps: 514228
# Episode:  15333 Score:  316.0201721191406  Average score: 83.13 Best average: 211.36 Epsilon: 0.15 Steps: 514262
# Episode:  15334 Score:  96.45870971679688  Average score: 83.12 Best average: 211.36 Epsilon: 0.15 Steps: 514302
# Episode:  15335 Score:  -18.74359130859375  Average score: 82.92 Best average: 211.36 Epsilon: 0.15 Steps: 514321
# Episode:  15336 Score:  -31.832748413085938  Average score: 79.57 Best average: 211.36 Epsilon: 0.15 Steps: 514348
# Episode:  15337 Score:  127.22917175292969  Average score: 80.74 Best average: 211.36 Epsilon: 0.15 Steps: 514375
# Episode:  15338 Score:  175.39317321777344  Average score: 83.65 Best average: 211.36 Epsilon: 0.15 Steps: 514409
# Episode:  15339 Score:  215.57980346679688  Average score: 85.39 Best average: 211.36 Epsilon: 0.15 Steps: 514435
# Episode:  15340 Score:  50.52961730957031  Average score: 84.60 Best average: 211.36 Epsilon: 0.15 Steps: 514461
# Episode:  15341 Score:  268.0861358642578  Average score: 87.81 Best average: 211.36 Epsilon: 0.15 Steps: 514490
# Episode:  15342 Score:  208.10874938964844  Average score: 88.43 Best average: 211.36 Epsilon: 0.15 Steps: 514524
# Episode:  15343 Score:  -115.94613647460938  Average score: 84.47 Best average: 211.36 Epsilon: 0.15 Steps: 514552
# Episode:  15344 Score:  54.22407531738281  Average score: 85.85 Best average: 211.36 Epsilon: 0.15 Steps: 514579
# Episode:  15345 Score:  246.57643127441406  Average score: 88.06 Best average: 211.36 Epsilon: 0.15 Steps: 514622
# Episode:  15346 Score:  29.25738525390625  Average score: 88.56 Best average: 211.36 Epsilon: 0.15 Steps: 514648
# Episode:  15347 Score:  91.59684753417969  Average score: 89.70 Best average: 211.36 Epsilon: 0.15 Steps: 514690
# Episode:  15348 Score:  180.71337890625  Average score: 89.38 Best average: 211.36 Epsilon: 0.15 Steps: 514736
# Episode:  15349 Score:  -64.66973876953125  Average score: 86.41 Best average: 211.36 Epsilon: 0.15 Steps: 514770
# Episode:  15350 Score:  -67.09371948242188  Average score: 86.38 Best average: 211.36 Epsilon: 0.15 Steps: 514783
# Episode:  15351 Score:  282.2305908203125  Average score: 87.41 Best average: 211.36 Epsilon: 0.15 Steps: 514821
# Episode:  15352 Score:  117.22959899902344  Average score: 89.28 Best average: 211.36 Epsilon: 0.15 Steps: 514841
# Episode:  15353 Score:  94.66482543945312  Average score: 91.39 Best average: 211.36 Epsilon: 0.15 Steps: 514876
# Episode:  15354 Score:  -12.463882446289062  Average score: 91.67 Best average: 211.36 Epsilon: 0.15 Steps: 514911
# Episode:  15355 Score:  48.6492919921875  Average score: 92.77 Best average: 211.36 Epsilon: 0.15 Steps: 514945
# Episode:  15356 Score:  -55.20979309082031  Average score: 92.60 Best average: 211.36 Epsilon: 0.15 Steps: 514964
# Episode:  15357 Score:  29.800827026367188  Average score: 92.32 Best average: 211.36 Epsilon: 0.15 Steps: 514982
# Episode:  15358 Score:  308.103759765625  Average score: 96.16 Best average: 211.36 Epsilon: 0.15 Steps: 515024
# Episode:  15359 Score:  210.08995056152344  Average score: 99.43 Best average: 211.36 Epsilon: 0.15 Steps: 515069
# Episode:  15360 Score:  192.74314880371094  Average score: 101.17 Best average: 211.36 Epsilon: 0.15 Steps: 515104
# Episode:  15361 Score:  211.65762329101562  Average score: 100.29 Best average: 211.36 Epsilon: 0.15 Steps: 515137
# Episode:  15362 Score:  218.9833526611328  Average score: 101.20 Best average: 211.36 Epsilon: 0.15 Steps: 515185
# Episode:  15363 Score:  230.91209411621094  Average score: 104.42 Best average: 211.36 Epsilon: 0.15 Steps: 515228
# Episode:  15364 Score:  34.841644287109375  Average score: 101.92 Best average: 211.36 Epsilon: 0.15 Steps: 515254
# Episode:  15365 Score:  7.37322998046875  Average score: 101.75 Best average: 211.36 Epsilon: 0.15 Steps: 515287
# Episode:  15366 Score:  -50.18806457519531  Average score: 102.03 Best average: 211.36 Epsilon: 0.15 Steps: 515314
# Episode:  15367 Score:  -102.67913818359375  Average score: 101.08 Best average: 211.36 Epsilon: 0.15 Steps: 515325
# Episode:  15368 Score:  76.86976623535156  Average score: 101.33 Best average: 211.36 Epsilon: 0.15 Steps: 515367
# Episode:  15369 Score:  5.3230438232421875  Average score: 102.00 Best average: 211.36 Epsilon: 0.15 Steps: 515689
# Episode:  15370 Score:  192.10044860839844  Average score: 104.76 Best average: 211.36 Epsilon: 0.15 Steps: 515747
# Episode:  15371 Score:  151.60951232910156  Average score: 106.86 Best average: 211.36 Epsilon: 0.15 Steps: 515781
# Episode:  15372 Score:  175.94395446777344  Average score: 107.83 Best average: 211.36 Epsilon: 0.15 Steps: 515805
# Episode:  15373 Score:  -111.28688049316406  Average score: 104.95 Best average: 211.36 Epsilon: 0.15 Steps: 515817
# Episode:  15374 Score:  -58.61207580566406  Average score: 101.57 Best average: 211.36 Epsilon: 0.15 Steps: 515828
# Episode:  15375 Score:  224.5367889404297  Average score: 101.63 Best average: 211.36 Epsilon: 0.15 Steps: 515877
# Episode:  15376 Score:  127.73750305175781  Average score: 104.05 Best average: 211.36 Epsilon: 0.15 Steps: 515910
# Episode:  15377 Score:  -84.74270629882812  Average score: 100.74 Best average: 211.36 Epsilon: 0.15 Steps: 515930
# Episode:  15378 Score:  165.2706298828125  Average score: 103.17 Best average: 211.36 Epsilon: 0.15 Steps: 515972
# Episode:  15379 Score:  -46.42863464355469  Average score: 103.36 Best average: 211.36 Epsilon: 0.15 Steps: 515993
# Episode:  15380 Score:  84.004638671875  Average score: 105.36 Best average: 211.36 Epsilon: 0.15 Steps: 516026
# Episode:  15381 Score:  -88.24710083007812  Average score: 105.63 Best average: 211.36 Epsilon: 0.15 Steps: 516038
# Episode:  15382 Score:  -1.4151611328125  Average score: 103.26 Best average: 211.36 Epsilon: 0.15 Steps: 516071
# Episode:  15383 Score:  190.56756591796875  Average score: 106.12 Best average: 211.36 Epsilon: 0.15 Steps: 516106
# Episode:  15384 Score:  239.89068603515625  Average score: 105.45 Best average: 211.36 Epsilon: 0.15 Steps: 516141
# Episode:  15385 Score:  21.956451416015625  Average score: 105.21 Best average: 211.36 Epsilon: 0.15 Steps: 516153
# Episode:  15386 Score:  350.93653869628906  Average score: 107.02 Best average: 211.36 Epsilon: 0.15 Steps: 516241
# Episode:  15387 Score:  -55.52687072753906  Average score: 106.15 Best average: 211.36 Epsilon: 0.15 Steps: 516260
# Episode:  15388 Score:  -50.22413635253906  Average score: 106.11 Best average: 211.36 Epsilon: 0.15 Steps: 516279
# Episode:  15389 Score:  211.9363555908203  Average score: 104.98 Best average: 211.36 Epsilon: 0.15 Steps: 516329
# Episode:  15390 Score:  -85.49259948730469  Average score: 105.28 Best average: 211.36 Epsilon: 0.15 Steps: 516348
# Episode:  15391 Score:  -2.9730987548828125  Average score: 102.62 Best average: 211.36 Epsilon: 0.15 Steps: 516398
# Episode:  15392 Score:  9.821090698242188  Average score: 101.47 Best average: 211.36 Epsilon: 0.15 Steps: 516418
# Episode:  15393 Score:  105.59361267089844  Average score: 102.45 Best average: 211.36 Epsilon: 0.15 Steps: 516445
# Episode:  15394 Score:  180.20169067382812  Average score: 102.02 Best average: 211.36 Epsilon: 0.15 Steps: 516487
# Episode:  15395 Score:  -115.9820556640625  Average score: 98.91 Best average: 211.36 Epsilon: 0.15 Steps: 516516
# Episode:  15396 Score:  305.60186767578125  Average score: 99.45 Best average: 211.36 Epsilon: 0.15 Steps: 516549
# Episode:  15397 Score:  112.74505615234375  Average score: 98.84 Best average: 211.36 Epsilon: 0.15 Steps: 516585
# Episode:  15398 Score:  -9.223541259765625  Average score: 96.71 Best average: 211.36 Epsilon: 0.15 Steps: 516612
# Episode:  15399 Score:  162.091552734375  Average score: 95.58 Best average: 211.36 Epsilon: 0.15 Steps: 516646
# Episode:  15400 Score:  -45.10627746582031  Average score: 95.23 Best average: 211.36 Epsilon: 0.15 Steps: 516681
# Episode:  15401 Score:  41.96771240234375  Average score: 94.00 Best average: 211.36 Epsilon: 0.15 Steps: 516700
# Episode:  15402 Score:  298.01612854003906  Average score: 97.30 Best average: 211.36 Epsilon: 0.15 Steps: 516738
# Episode:  15403 Score:  -3.608001708984375  Average score: 96.51 Best average: 211.36 Epsilon: 0.15 Steps: 516773
# Episode:  15404 Score:  132.06173706054688  Average score: 95.75 Best average: 211.36 Epsilon: 0.15 Steps: 516816
# Episode:  15405 Score:  251.56333923339844  Average score: 97.94 Best average: 211.36 Epsilon: 0.15 Steps: 516856
# Episode:  15406 Score:  -22.678665161132812  Average score: 94.78 Best average: 211.36 Epsilon: 0.15 Steps: 516881
# Episode:  15407 Score:  140.33074951171875  Average score: 96.34 Best average: 211.36 Epsilon: 0.15 Steps: 516914
# Episode:  15408 Score:  247.1962890625  Average score: 99.28 Best average: 211.36 Epsilon: 0.15 Steps: 516948
# Episode:  15409 Score:  100.35934448242188  Average score: 98.55 Best average: 211.36 Epsilon: 0.15 Steps: 516990
# Episode:  15410 Score:  -72.04251098632812  Average score: 96.60 Best average: 211.36 Epsilon: 0.15 Steps: 517008
# Episode:  15411 Score:  60.08172607421875  Average score: 97.43 Best average: 211.36 Epsilon: 0.15 Steps: 517042
# Episode:  15412 Score:  -36.49244689941406  Average score: 98.22 Best average: 211.36 Epsilon: 0.15 Steps: 517061
# Episode:  15413 Score:  0.5816192626953125  Average score: 98.23 Best average: 211.36 Epsilon: 0.15 Steps: 517074
# Episode:  15414 Score:  256.3751678466797  Average score: 98.39 Best average: 211.36 Epsilon: 0.15 Steps: 517111
# Episode:  15415 Score:  256.20863342285156  Average score: 101.06 Best average: 211.36 Epsilon: 0.15 Steps: 517161
# Episode:  15416 Score:  337.0174560546875  Average score: 101.58 Best average: 211.36 Epsilon: 0.15 Steps: 517197
# Episode:  15417 Score:  209.25921630859375  Average score: 101.13 Best average: 211.36 Epsilon: 0.15 Steps: 517242
# Episode:  15418 Score:  150.5896759033203  Average score: 102.44 Best average: 211.36 Epsilon: 0.15 Steps: 517276
# Episode:  15419 Score:  75.33767700195312  Average score: 100.10 Best average: 211.36 Epsilon: 0.15 Steps: 517297
# Episode:  15420 Score:  261.43585205078125  Average score: 99.70 Best average: 211.36 Epsilon: 0.15 Steps: 517323
# Episode:  15421 Score:  -43.69334411621094  Average score: 97.98 Best average: 211.36 Epsilon: 0.15 Steps: 517334
# Episode:  15422 Score:  220.9608612060547  Average score: 100.80 Best average: 211.36 Epsilon: 0.15 Steps: 517369
# Episode:  15423 Score:  392.9352569580078  Average score: 105.81 Best average: 211.36 Epsilon: 0.15 Steps: 517410
# Episode:  15424 Score:  181.04745483398438  Average score: 105.53 Best average: 211.36 Epsilon: 0.15 Steps: 517438
# Episode:  15425 Score:  82.53874206542969  Average score: 107.17 Best average: 211.36 Epsilon: 0.15 Steps: 517471
# Episode:  15426 Score:  166.92555236816406  Average score: 106.77 Best average: 211.36 Epsilon: 0.15 Steps: 517497
# Episode:  15427 Score:  210.36952209472656  Average score: 107.77 Best average: 211.36 Epsilon: 0.15 Steps: 517527
# Episode:  15428 Score:  74.97337341308594  Average score: 106.16 Best average: 211.36 Epsilon: 0.15 Steps: 517548
# Episode:  15429 Score:  -47.73997497558594  Average score: 106.00 Best average: 211.36 Epsilon: 0.15 Steps: 517569
# Episode:  15430 Score:  97.78239440917969  Average score: 105.19 Best average: 211.36 Epsilon: 0.15 Steps: 517596
# Episode:  15431 Score:  138.7461395263672  Average score: 107.21 Best average: 211.36 Epsilon: 0.15 Steps: 517622
# ...
# Episode:  19861 Score:  -81.41546630859375  Average score: 126.41 Best average: 213.05 Epsilon: 0.15 Steps: 652808
# Episode:  19862 Score:  316.7401885986328  Average score: 130.47 Best average: 213.05 Epsilon: 0.15 Steps: 652837
# Episode:  19863 Score:  -29.570297241210938  Average score: 130.78 Best average: 213.05 Epsilon: 0.15 Steps: 652856
# Episode:  19864 Score:  293.1398010253906  Average score: 134.56 Best average: 213.05 Epsilon: 0.15 Steps: 652908
# Episode:  19865 Score:  223.8269805908203  Average score: 137.33 Best average: 213.05 Epsilon: 0.15 Steps: 652941
# Episode:  19866 Score:  -104.98796081542969  Average score: 135.88 Best average: 213.05 Epsilon: 0.15 Steps: 652953
# Episode:  19867 Score:  -4.190826416015625  Average score: 133.76 Best average: 213.05 Epsilon: 0.15 Steps: 652972
# Episode:  19868 Score:  -36.801116943359375  Average score: 134.55 Best average: 213.05 Epsilon: 0.15 Steps: 652990
# Episode:  19869 Score:  6.1110382080078125  Average score: 132.03 Best average: 213.05 Epsilon: 0.15 Steps: 653009
# Episode:  19870 Score:  27.042388916015625  Average score: 132.63 Best average: 213.05 Epsilon: 0.15 Steps: 653035
# Episode:  19871 Score:  253.3260040283203  Average score: 132.37 Best average: 213.05 Epsilon: 0.15 Steps: 653063
# Episode:  19872 Score:  100.56269836425781  Average score: 131.32 Best average: 213.05 Epsilon: 0.15 Steps: 653090
# Episode:  19873 Score:  314.44696044921875  Average score: 131.68 Best average: 213.05 Epsilon: 0.15 Steps: 653126
# Episode:  19874 Score:  100.20210266113281  Average score: 132.56 Best average: 213.05 Epsilon: 0.15 Steps: 653153
# Episode:  19875 Score:  345.3914489746094  Average score: 136.16 Best average: 213.05 Epsilon: 0.15 Steps: 653190
# Episode:  19876 Score:  182.4333953857422  Average score: 136.46 Best average: 213.05 Epsilon: 0.15 Steps: 653217
# Episode:  19877 Score:  263.8750457763672  Average score: 138.88 Best average: 213.05 Epsilon: 0.15 Steps: 653247
# Episode:  19878 Score:  273.81072998046875  Average score: 140.54 Best average: 213.05 Epsilon: 0.15 Steps: 653295
# Episode:  19879 Score:  95.92927551269531  Average score: 141.98 Best average: 213.05 Epsilon: 0.15 Steps: 653321
# Episode:  19880 Score:  158.38925170898438  Average score: 143.71 Best average: 213.05 Epsilon: 0.15 Steps: 653355
# Episode:  19881 Score:  -18.70916748046875  Average score: 144.34 Best average: 213.05 Epsilon: 0.15 Steps: 653396
# Episode:  19882 Score:  114.17388916015625  Average score: 141.83 Best average: 213.05 Epsilon: 0.15 Steps: 653422
# Episode:  19883 Score:  285.71092224121094  Average score: 141.79 Best average: 213.05 Epsilon: 0.15 Steps: 653462
# Episode:  19884 Score:  280.7903289794922  Average score: 144.53 Best average: 213.05 Epsilon: 0.15 Steps: 653491
# Episode:  19885 Score:  306.4641418457031  Average score: 145.36 Best average: 213.05 Epsilon: 0.15 Steps: 653533
# Episode:  19886 Score:  81.57902526855469  Average score: 142.70 Best average: 213.05 Epsilon: 0.15 Steps: 653561
# Episode:  19887 Score:  136.19680786132812  Average score: 141.47 Best average: 213.05 Epsilon: 0.15 Steps: 653596
# Episode:  19888 Score:  -28.7496337890625  Average score: 138.93 Best average: 213.05 Epsilon: 0.15 Steps: 653609
# Episode:  19889 Score:  185.98634338378906  Average score: 140.33 Best average: 213.05 Epsilon: 0.15 Steps: 653650
# Episode:  19890 Score:  309.1962432861328  Average score: 144.58 Best average: 213.05 Epsilon: 0.15 Steps: 653687
# Episode:  19891 Score:  219.6616973876953  Average score: 145.63 Best average: 213.05 Epsilon: 0.15 Steps: 653729
# Episode:  19892 Score:  233.14393615722656  Average score: 145.21 Best average: 213.05 Epsilon: 0.15 Steps: 653763
# Episode:  19893 Score:  222.09616088867188  Average score: 144.37 Best average: 213.05 Epsilon: 0.15 Steps: 653798
# Episode:  19894 Score:  230.62411499023438  Average score: 143.72 Best average: 213.05 Epsilon: 0.15 Steps: 653846
# Episode:  19895 Score:  288.74684143066406  Average score: 146.92 Best average: 213.05 Epsilon: 0.15 Steps: 653886
# Episode:  19896 Score:  -30.033065795898438  Average score: 147.36 Best average: 213.05 Epsilon: 0.15 Steps: 653899
# Episode:  19897 Score:  124.31399536132812  Average score: 146.11 Best average: 213.05 Epsilon: 0.15 Steps: 653925
# Episode:  19898 Score:  56.97425842285156  Average score: 146.88 Best average: 213.05 Epsilon: 0.15 Steps: 653944
# Episode:  19899 Score:  -71.24534606933594  Average score: 144.22 Best average: 213.05 Epsilon: 0.15 Steps: 653957
# Episode:  19900 Score:  -45.03459167480469  Average score: 141.01 Best average: 213.05 Epsilon: 0.15 Steps: 653976
# Episode:  19901 Score:  -67.5010986328125  Average score: 141.10 Best average: 213.05 Epsilon: 0.15 Steps: 653989
# Episode:  19902 Score:  -27.861343383789062  Average score: 141.70 Best average: 213.05 Epsilon: 0.15 Steps: 654008
# Episode:  19903 Score:  -53.00663757324219  Average score: 141.48 Best average: 213.05 Epsilon: 0.15 Steps: 654078
# Episode:  19904 Score:  290.6271514892578  Average score: 141.59 Best average: 213.05 Epsilon: 0.15 Steps: 654108
# Episode:  19905 Score:  -67.73222351074219  Average score: 139.15 Best average: 213.05 Epsilon: 0.15 Steps: 654121
# Episode:  19906 Score:  -112.04957580566406  Average score: 135.32 Best average: 213.05 Epsilon: 0.15 Steps: 654126
# Episode:  19907 Score:  213.31134033203125  Average score: 138.01 Best average: 213.05 Epsilon: 0.15 Steps: 654152
# Episode:  19908 Score:  218.16995239257812  Average score: 138.64 Best average: 213.05 Epsilon: 0.15 Steps: 654183
# Episode:  19909 Score:  -34.910797119140625  Average score: 137.81 Best average: 213.05 Epsilon: 0.15 Steps: 654203
# Episode:  19910 Score:  304.0994567871094  Average score: 140.77 Best average: 213.05 Epsilon: 0.15 Steps: 654243
# Episode:  19911 Score:  -115.95533752441406  Average score: 139.67 Best average: 213.05 Epsilon: 0.15 Steps: 654255
# Episode:  19912 Score:  174.06814575195312  Average score: 139.15 Best average: 213.05 Epsilon: 0.15 Steps: 654288
# Episode:  19913 Score:  198.31861877441406  Average score: 139.03 Best average: 213.05 Epsilon: 0.15 Steps: 654323
# Episode:  19914 Score:  260.0558776855469  Average score: 141.27 Best average: 213.05 Epsilon: 0.15 Steps: 654357
# Episode:  19915 Score:  -24.222183227539062  Average score: 141.45 Best average: 213.05 Epsilon: 0.15 Steps: 654384
# Episode:  19916 Score:  -58.03153991699219  Average score: 138.30 Best average: 213.05 Epsilon: 0.15 Steps: 654402
# Episode:  19917 Score:  144.81114196777344  Average score: 137.85 Best average: 213.05 Epsilon: 0.15 Steps: 654428
# Episode:  19918 Score:  268.4820556640625  Average score: 137.63 Best average: 213.05 Epsilon: 0.15 Steps: 654469
# Episode:  19919 Score:  -115.99476623535156  Average score: 133.84 Best average: 213.05 Epsilon: 0.15 Steps: 654507
# Episode:  19920 Score:  261.99351501464844  Average score: 136.73 Best average: 213.05 Epsilon: 0.15 Steps: 654537
# Episode:  19921 Score:  268.8977355957031  Average score: 136.21 Best average: 213.05 Epsilon: 0.15 Steps: 654574
# Episode:  19922 Score:  -82.43572998046875  Average score: 135.67 Best average: 213.05 Epsilon: 0.15 Steps: 654587
# Episode:  19923 Score:  -86.62875366210938  Average score: 134.40 Best average: 213.05 Epsilon: 0.15 Steps: 654598
# Episode:  19924 Score:  184.285888671875  Average score: 133.89 Best average: 213.05 Epsilon: 0.15 Steps: 654631
# Episode:  19925 Score:  -11.2506103515625  Average score: 130.93 Best average: 213.05 Epsilon: 0.15 Steps: 654652
# Episode:  19926 Score:  292.8350830078125  Average score: 130.76 Best average: 213.05 Epsilon: 0.15 Steps: 654696
# Episode:  19927 Score:  -115.97834777832031  Average score: 130.44 Best average: 213.05 Epsilon: 0.15 Steps: 654709
# Episode:  19928 Score:  332.3361358642578  Average score: 131.76 Best average: 213.05 Epsilon: 0.15 Steps: 654757
# Episode:  19929 Score:  -18.422164916992188  Average score: 131.17 Best average: 213.05 Epsilon: 0.15 Steps: 654779
# Episode:  19930 Score:  338.9242248535156  Average score: 130.70 Best average: 213.05 Epsilon: 0.15 Steps: 654825
# Episode:  19931 Score:  244.107177734375  Average score: 131.58 Best average: 213.05 Epsilon: 0.15 Steps: 654869
# Episode:  19932 Score:  209.43614196777344  Average score: 134.58 Best average: 213.05 Epsilon: 0.15 Steps: 654898
# Episode:  19933 Score:  164.9424285888672  Average score: 133.77 Best average: 213.05 Epsilon: 0.15 Steps: 654939
# Episode:  19934 Score:  -62.83685302734375  Average score: 133.03 Best average: 213.05 Epsilon: 0.15 Steps: 654949
# Episode:  19935 Score:  283.98402404785156  Average score: 132.92 Best average: 213.05 Epsilon: 0.15 Steps: 654983
# Episode:  19936 Score:  54.651611328125  Average score: 133.51 Best average: 213.05 Epsilon: 0.15 Steps: 655008
# Episode:  19937 Score:  360.52903747558594  Average score: 137.83 Best average: 213.05 Epsilon: 0.15 Steps: 655049
# Episode:  19938 Score:  -4.3992767333984375  Average score: 138.69 Best average: 213.05 Epsilon: 0.15 Steps: 655106
# Episode:  19939 Score:  195.54620361328125  Average score: 141.50 Best average: 213.05 Epsilon: 0.15 Steps: 655132
# Episode:  19940 Score:  170.57652282714844  Average score: 143.82 Best average: 213.05 Epsilon: 0.15 Steps: 655167
# Episode:  19941 Score:  74.388671875  Average score: 142.09 Best average: 213.05 Epsilon: 0.15 Steps: 655200
# Episode:  19942 Score:  123.944091796875  Average score: 140.44 Best average: 213.05 Epsilon: 0.15 Steps: 655225
# Episode:  19943 Score:  204.0116729736328  Average score: 139.86 Best average: 213.05 Epsilon: 0.15 Steps: 655258
# Episode:  19944 Score:  324.5280456542969  Average score: 142.56 Best average: 213.05 Epsilon: 0.15 Steps: 655301
# Episode:  19945 Score:  165.6206512451172  Average score: 140.84 Best average: 213.05 Epsilon: 0.15 Steps: 655335
# Episode:  19946 Score:  -49.87294006347656  Average score: 137.25 Best average: 213.05 Epsilon: 0.15 Steps: 655346
# Episode:  19947 Score:  212.10243225097656  Average score: 135.65 Best average: 213.05 Epsilon: 0.15 Steps: 655376
# Episode:  19948 Score:  -13.995437622070312  Average score: 132.29 Best average: 213.05 Epsilon: 0.15 Steps: 655401
# Episode:  19949 Score:  274.8944854736328  Average score: 132.75 Best average: 213.05 Epsilon: 0.15 Steps: 655435
# Episode:  19950 Score:  -75.68098449707031  Average score: 129.12 Best average: 213.05 Epsilon: 0.15 Steps: 655454
# Episode:  19951 Score:  274.10687255859375  Average score: 128.66 Best average: 213.05 Epsilon: 0.15 Steps: 655508
# Episode:  19952 Score:  262.9607238769531  Average score: 132.12 Best average: 213.05 Epsilon: 0.15 Steps: 655561
# Episode:  19953 Score:  -89.06202697753906  Average score: 131.65 Best average: 213.05 Epsilon: 0.15 Steps: 655573
# Episode:  19954 Score:  239.2476348876953  Average score: 131.24 Best average: 213.05 Epsilon: 0.15 Steps: 655602
# Episode:  19955 Score:  -14.53509521484375  Average score: 128.55 Best average: 213.05 Epsilon: 0.15 Steps: 655623
# Episode:  19956 Score:  278.87791442871094  Average score: 130.63 Best average: 213.05 Epsilon: 0.15 Steps: 655667
# Episode:  19957 Score:  -42.02583312988281  Average score: 127.68 Best average: 213.05 Epsilon: 0.15 Steps: 655680
# Episode:  19958 Score:  321.2986145019531  Average score: 128.87 Best average: 213.05 Epsilon: 0.15 Steps: 655723
# Episode:  19959 Score:  209.51368713378906  Average score: 127.83 Best average: 213.05 Epsilon: 0.15 Steps: 655752
# Episode:  19960 Score:  190.54693603515625  Average score: 128.27 Best average: 213.05 Epsilon: 0.15 Steps: 655787
# Episode:  19961 Score:  165.73094177246094  Average score: 130.74 Best average: 213.05 Epsilon: 0.15 Steps: 655836
# Episode:  19962 Score:  315.6310729980469  Average score: 130.73 Best average: 213.05 Epsilon: 0.15 Steps: 655876
# Episode:  19963 Score:  245.60350036621094  Average score: 133.48 Best average: 213.05 Epsilon: 0.15 Steps: 655913
# Episode:  19964 Score:  359.4622497558594  Average score: 134.14 Best average: 213.05 Epsilon: 0.15 Steps: 655957
# Episode:  19965 Score:  210.88099670410156  Average score: 134.01 Best average: 213.05 Epsilon: 0.15 Steps: 655987
# Episode:  19966 Score:  -31.425247192382812  Average score: 134.75 Best average: 213.05 Epsilon: 0.15 Steps: 655999
# Episode:  19967 Score:  -72.18583679199219  Average score: 134.07 Best average: 213.05 Epsilon: 0.15 Steps: 656018
# Episode:  19968 Score:  13.994857788085938  Average score: 134.58 Best average: 213.05 Epsilon: 0.15 Steps: 656038
# Episode:  19969 Score:  318.9822540283203  Average score: 137.71 Best average: 213.05 Epsilon: 0.15 Steps: 656133
# Episode:  19970 Score:  8.691116333007812  Average score: 137.52 Best average: 213.05 Epsilon: 0.15 Steps: 656160
# Episode:  19971 Score:  -61.81330871582031  Average score: 134.37 Best average: 213.05 Epsilon: 0.15 Steps: 656172
# Episode:  19972 Score:  -30.34991455078125  Average score: 133.06 Best average: 213.05 Epsilon: 0.15 Steps: 656191
# Episode:  19973 Score:  -57.6600341796875  Average score: 129.34 Best average: 213.05 Epsilon: 0.15 Steps: 656211
# Episode:  19974 Score:  313.05345153808594  Average score: 131.47 Best average: 213.05 Epsilon: 0.15 Steps: 656243
# Episode:  19975 Score:  156.11029052734375  Average score: 129.58 Best average: 213.05 Epsilon: 0.15 Steps: 656269
# Episode:  19976 Score:  112.61227416992188  Average score: 128.88 Best average: 213.05 Epsilon: 0.15 Steps: 656310
# Episode:  19977 Score:  285.3443603515625  Average score: 129.09 Best average: 213.05 Epsilon: 0.15 Steps: 656352
# Episode:  19978 Score:  -103.35444641113281  Average score: 125.32 Best average: 213.05 Epsilon: 0.15 Steps: 656363
# Episode:  19979 Score:  -37.58441162109375  Average score: 123.99 Best average: 213.05 Epsilon: 0.15 Steps: 656376
# Episode:  19980 Score:  288.85560607910156  Average score: 125.29 Best average: 213.05 Epsilon: 0.15 Steps: 656430
# Episode:  19981 Score:  270.4412078857422  Average score: 128.18 Best average: 213.05 Epsilon: 0.15 Steps: 656477
# Episode:  19982 Score:  -39.65412902832031  Average score: 126.64 Best average: 213.05 Epsilon: 0.15 Steps: 656496
# Episode:  19983 Score:  -75.86076354980469  Average score: 123.03 Best average: 213.05 Epsilon: 0.15 Steps: 656507
# Episode:  19984 Score:  214.0229949951172  Average score: 122.36 Best average: 213.05 Epsilon: 0.15 Steps: 656558
# Episode:  19985 Score:  20.170913696289062  Average score: 119.50 Best average: 213.05 Epsilon: 0.15 Steps: 656586
# Episode:  19986 Score:  -114.87814331054688  Average score: 117.53 Best average: 213.05 Epsilon: 0.15 Steps: 656599
# Episode:  19987 Score:  309.5931701660156  Average score: 119.27 Best average: 213.05 Epsilon: 0.15 Steps: 656651
# Episode:  19988 Score:  289.1707305908203  Average score: 122.45 Best average: 213.05 Epsilon: 0.15 Steps: 656694
# Episode:  19989 Score:  188.36643981933594  Average score: 122.47 Best average: 213.05 Epsilon: 0.15 Steps: 656733
# Episode:  19990 Score:  -61.179443359375  Average score: 118.77 Best average: 213.05 Epsilon: 0.15 Steps: 656774
# Episode:  19991 Score:  -100.24197387695312  Average score: 115.57 Best average: 213.05 Epsilon: 0.15 Steps: 656794
# Episode:  19992 Score:  229.185791015625  Average score: 115.53 Best average: 213.05 Epsilon: 0.15 Steps: 656856
# Episode:  19993 Score:  -81.310546875  Average score: 112.49 Best average: 213.05 Epsilon: 0.15 Steps: 656868
# Episode:  19994 Score:  396.4571838378906  Average score: 114.15 Best average: 213.05 Epsilon: 0.15 Steps: 656908
# Episode:  19995 Score:  183.22755432128906  Average score: 113.10 Best average: 213.05 Epsilon: 0.15 Steps: 656943
# Episode:  19996 Score:  214.3075714111328  Average score: 115.54 Best average: 213.05 Epsilon: 0.15 Steps: 656976
# Episode:  19997 Score:  5.12353515625  Average score: 114.35 Best average: 213.05 Epsilon: 0.15 Steps: 657003
# Episode:  19998 Score:  222.9107666015625  Average score: 116.01 Best average: 213.05 Epsilon: 0.15 Steps: 657043
# Episode:  19999 Score:  2.4932861328125  Average score: 116.75 Best average: 213.05 Epsilon: 0.15 Steps: 657084

# %%
x = [i+1 for i in range(len(scores))]
plot_learning_curve(x, scores, eps_history, figure_file)

# %% [markdown]
# ## Evaluation
#
# Finally, let's visualize our agent's performance, and play a game within the gym environment itself.

# %%
#Visualization cobe for running within Colab

# Install dependencies first for graphics visualization within Colaboratory

#remove " > /dev/null 2>&1" to see what is going on under the hood
"""
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1

"""
# Out:
# '\n!pip install gym pyvirtualdisplay > /dev/null 2>&1\n!apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1\n\n!apt-get update > /dev/null 2>&1\n!apt-get install cmake > /dev/null 2>&1\n!pip install --upgrade setuptools 2>&1\n!pip install ez_setup > /dev/null 2>&1\n\n'

# %%
#To Evaluate model on OpenAI gym, we will record a video via Ipython display



from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only

import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML

from IPython import display as ipythondisplay


from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
"""
shape = (84,84,1)
new_shape = (shape[2], shape[0], shape[1])
print(new_shape[1:])
#1,84,84

new_frame = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)
resized_screen = cv2.resize(new_frame, self.shape[1:],
                                    interpolation=cv2.INTER_AREA)
new_obs = np.array(resized_screen, dtype=np.uint8).reshape(self.shape)
new_obs = new_obs / 255.0
"""
# Out:
# '\nshape = (84,84,1)\nnew_shape = (shape[2], shape[0], shape[1])\nprint(new_shape[1:])\n#1,84,84\n\nnew_frame = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)\nresized_screen = cv2.resize(new_frame, self.shape[1:],\n                                    interpolation=cv2.INTER_AREA)\nnew_obs = np.array(resized_screen, dtype=np.uint8).reshape(self.shape)\nnew_obs = new_obs / 255.0\n'

# %%
class PreprocessFrameEval(gym.ObservationWrapper):
  #set shape by swapping channels axis
	#set observation space to new shape using gym.spaces.Box (0 to 1.0)
    def __init__(self, shape, env=None):
        super(PreprocessFrameEval, self).__init__(env)
        self.shape = (shape[2], shape[0], shape[1])
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0,
                                    shape=self.shape, dtype=np.float32)

    def observation(self, obs):
        img_array.append(obs)
        new_frame = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)
        resized_screen = cv2.resize(new_frame, self.shape[1:],
                                    interpolation=cv2.INTER_AREA)
        new_obs = np.array(resized_screen, dtype=np.uint8).reshape(self.shape)
        new_obs = new_obs / 255.0

        return new_obs



def make_envEVAL(env_name, shape=(84,84,1), repeat=4, clip_rewards=False,
             no_ops=0, fire_first=False):
    env = gym.make(env_name)
    env = PreprocessFrameEval(shape, env)
    env = RepeatActionAndMaxFrame(env, repeat, clip_rewards, no_ops, fire_first)
    
    env = StackFrames(env, repeat)

    return env

# %%
env = make_envEVAL('VizdoomCorridor-v0')

n_outputs = env.action_space.n
print(n_outputs)

img_array=[]

observation = env.reset()

#if load_checkpoint:
  #agent.load_models()


for i in range(2):
  done = False
  observation = env.reset()
  
  
  score = 0
  while not done:
    
    action = agent.choose_action(observation)
    observation_, reward, done, info = env.step(action)
    
    
    #img_array.append(observation)
# Out:
# 7

# %%
print(len(img_array))

for i in range(22):
  
  if i > 20:
    print(img_array[i].shape)
    plt.imshow(img_array[i])
    plt.show()
# Out:
# 164
# (240, 320, 3)

# %%
#!pip install sk-video

# %%
from random import choice
import cv2 
from google.colab.patches import cv2_imshow
from torchvision.io import write_video

import numpy as np


out_video =  np.empty([len(img_array), 240, 320, 3], dtype = np.uint8)
out_video =  out_video.astype(np.uint8)

for i in range(len(img_array)):
  frame = img_array[i]
  out_video[i] = frame
# Writes the the output image sequences in a video file

write_video("/content/doom.mp4", out_video, 25, video_codec='libx264', options=None)
#skvideo.io.vwrite("/content/doom.mp4", out_video)
