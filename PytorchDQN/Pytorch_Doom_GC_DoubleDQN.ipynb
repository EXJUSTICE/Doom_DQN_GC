# %% [markdown]
# # Automated Doom with Double Deep Q-learning, in Pytorch
#
# A Colaboratory notebook for GradientCrescent, by Adrian Yijie Xu.
#
# If you enjoyed this notebook, please consider leaving a star on the GradientCrescent Github (https://github.com/EXJUSTICE/GradientCrescent), and visting the publication for more articles on applied and theoretical aspects of AI (https://medium.com/@adrianitsaxu).

# %% [markdown]
# ## Setup
#
# First we import all the necessary libraries. This may take a significant time, but should only be done once per session. After execution, make sure to restart the runtime.
#
# If you wish rerun the notebook, make sure to comment it out. </font>

# %%
#Visualization cobe for running within Colab
# !sudo apt-get update
# !sudo apt-get install build-essential zlib1g-dev libsdl2-dev libjpeg-dev nasm tar libbz2-dev libgtk2.0-dev cmake git libfluidsynth-dev libgme-dev libopenal-dev timidity libwildmidi-dev unzip

# Boost libraries
# !sudo apt-get install libboost-all-dev

# Lua binding dependencies
# !apt-get install liblua5.1-dev
# !sudo apt-get install cmake libboost-all-dev libgtk2.0-dev libsdl2-dev python-numpy git
# !git clone https://github.com/shakenes/vizdoomgym.git
# !python3 -m pip install -e vizdoomgym/
# Out:
# Ign:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Hit:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:6 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:12 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:14 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [43.0 kB]
# Get:15 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [890 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [1,341 kB]
# Get:17 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,859 kB]
# Get:18 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,045 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,418 kB]
# Get:20 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [897 kB]
# Fetched 7,785 kB in 3s (2,725 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# unzip is already the newest version (6.0-21ubuntu1).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2).
# zlib1g-dev set to manually installed.
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# git is already the newest version (1:2.17.1-1ubuntu0.7).
# libbz2-dev is already the newest version (1.0.6-8.1ubuntu0.2).
# libbz2-dev set to manually installed.
# tar is already the newest version (1.29b-2ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file freepats gettext gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-2.0 gir1.2-ibus-1.0
#   gir1.2-pango-1.0 intltool-debian libarchive-cpio-perl libarchive-zip-perl
#   libatk1.0-dev libaudio2 libcairo-script-interpreter2 libcairo2-dev
#   libcapnp-0.6.1 libdbus-1-dev libfile-stripnondeterminism-perl libfluidsynth1
#   libgdk-pixbuf2.0-dev libibus-1.0-5 libibus-1.0-dev libmagic-mgc libmagic1
#   libmail-sendmail-perl libmirclient-dev libmirclient9 libmircommon-dev
#   libmircommon7 libmircookie-dev libmircookie2 libmircore-dev libmircore1
#   libmirprotobuf3 libpango1.0-dev libpangoxft-1.0-0 libpixman-1-dev
#   libprotobuf-dev libprotobuf-lite10 libpulse-dev libpulse-mainloop-glib0
#   libsigsegv2 libsndio-dev libsys-hostname-long-perl libtimedate-perl libtool
#   libudev-dev libwildmidi-config libwildmidi2 libxcb-shm0-dev
#   libxcomposite-dev libxcursor-dev libxinerama-dev libxkbcommon-dev
#   libxml2-utils libxrandr-dev libxv-dev m4 po-debconf timidity-daemon
#   x11proto-composite-dev x11proto-randr-dev x11proto-xinerama-dev
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc dh-make dwz gettext-doc
#   libasprintf-dev libgettextpo-dev nas libcairo2-doc fluidr3mono-gm-soundfont
#   | timgm6mb-soundfont | fluid-soundfont-gm libgtk2.0-doc imagemagick
#   libpango1.0-doc libtool-doc gcj-jdk m4-doc libmail-box-perl
#   fluid-soundfont-gm fluid-soundfont-gs pmidi
# The following NEW packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file freepats gettext gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-2.0 gir1.2-ibus-1.0
#   gir1.2-pango-1.0 intltool-debian libarchive-cpio-perl libarchive-zip-perl
#   libatk1.0-dev libaudio2 libcairo-script-interpreter2 libcairo2-dev
#   libcapnp-0.6.1 libdbus-1-dev libfile-stripnondeterminism-perl
#   libfluidsynth-dev libfluidsynth1 libgdk-pixbuf2.0-dev libgme-dev
#   libgtk2.0-dev libibus-1.0-5 libibus-1.0-dev libmagic-mgc libmagic1
#   libmail-sendmail-perl libmirclient-dev libmirclient9 libmircommon-dev
#   libmircommon7 libmircookie-dev libmircookie2 libmircore-dev libmircore1
#   libmirprotobuf3 libopenal-dev libpango1.0-dev libpangoxft-1.0-0
#   libpixman-1-dev libprotobuf-dev libprotobuf-lite10 libpulse-dev
#   libpulse-mainloop-glib0 libsdl2-dev libsigsegv2 libsndio-dev
#   libsys-hostname-long-perl libtimedate-perl libtool libudev-dev
#   libwildmidi-config libwildmidi-dev libwildmidi2 libxcb-shm0-dev
#   libxcomposite-dev libxcursor-dev libxinerama-dev libxkbcommon-dev
#   libxml2-utils libxrandr-dev libxv-dev m4 nasm po-debconf timidity
#   timidity-daemon x11proto-composite-dev x11proto-randr-dev
#   x11proto-xinerama-dev
# 0 upgraded, 80 newly installed, 0 to remove and 60 not upgraded.
# Need to get 43.2 MB of archives.
# After this operation, 114 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext-base amd64 0.19.8.1-6ubuntu0.3 [113 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 autopoint all 0.19.8.1-6ubuntu0.3 [426 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool all 2.4.6-2 [194 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-autoreconf all 17 [15.8 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libarchive-zip-perl all 1.60-1ubuntu0.1 [84.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-stripnondeterminism-perl all 0.040-1.1~build1 [13.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-strip-nondeterminism all 0.040-1.1~build1 [5,208 B]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext amd64 0.19.8.1-6ubuntu0.3 [1,293 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 intltool-debian all 0.35.0+20060710.4 [24.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 po-debconf all 1.0.20 [232 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 debhelper all 11.1.6ubuntu2 [902 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/universe amd64 freepats all 20060219-1 [29.0 MB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-atk-1.0 amd64 2.28.1-1 [17.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-freedesktop amd64 1.56.1-1 [9,080 B]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.36.11-2 [7,748 B]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangoxft-1.0-0 amd64 1.40.14-1ubuntu0.1 [15.0 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-pango-1.0 amd64 1.40.14-1ubuntu0.1 [21.6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gtk-2.0 amd64 2.24.32-1ubuntu1 [172 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libibus-1.0-5 amd64 1.5.17-3ubuntu5.3 [133 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-ibus-1.0 amd64 1.5.17-3ubuntu5.3 [66.5 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libarchive-cpio-perl all 0.10-1 [9,644 B]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk1.0-dev amd64 2.28.1-1 [79.9 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libaudio2 amd64 1.9.4-6 [50.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-script-interpreter2 amd64 1.15.10-2ubuntu0.1 [53.5 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shm0-dev amd64 1.13-2~ubuntu18.04 [6,684 B]
# Get:36 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo2-dev amd64 1.15.10-2ubuntu0.1 [626 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcapnp-0.6.1 amd64 0.6.1-1ubuntu1 [658 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdbus-1-dev amd64 1.12.2-1ubuntu1.2 [165 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfluidsynth1 amd64 1.1.9-1 [137 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfluidsynth-dev amd64 1.1.9-1 [19.7 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-dev amd64 2.36.11-2 [46.8 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgme-dev amd64 0.6.2-1 [5,796 B]
# Get:43 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpango1.0-dev amd64 1.40.14-1ubuntu0.1 [288 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xinerama-dev all 2018.4-4 [2,628 B]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama-dev amd64 2:1.1.3-1 [8,404 B]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-randr-dev all 2018.4-4 [2,620 B]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr-dev amd64 2:1.5.1-1 [24.0 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor-dev amd64 1:1.1.15-1 [26.5 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-composite-dev all 1:2018.4-4 [2,620 B]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcomposite-dev amd64 1:0.4.4-2 [9,136 B]
# Get:51 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxml2-utils amd64 2.9.4+dfsg1-6.1ubuntu1.3 [35.9 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-dev amd64 2.24.32-1ubuntu1 [2,652 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libibus-1.0-dev amd64 1.5.17-3ubuntu5.3 [145 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsys-hostname-long-perl all 1.5-1 [11.7 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmail-sendmail-perl all 0.80-1 [22.6 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore1 amd64 0.31.1-0ubuntu1 [26.5 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon7 amd64 0.31.1-0ubuntu1 [73.9 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-lite10 amd64 3.0.0-9.1ubuntu1 [97.7 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirprotobuf3 amd64 0.31.1-0ubuntu1 [127 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient9 amd64 0.31.1-0ubuntu1 [199 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore-dev amd64 0.31.1-0ubuntu1 [21.7 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-dev amd64 3.0.0-9.1ubuntu1 [959 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxkbcommon-dev amd64 0.8.2-1~ubuntu18.04.1 [150 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon-dev amd64 0.31.1-0ubuntu1 [13.9 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie2 amd64 0.31.1-0ubuntu1 [19.7 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie-dev amd64 0.31.1-0ubuntu1 [4,392 B]
# Get:67 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient-dev amd64 0.31.1-0ubuntu1 [47.8 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenal-dev amd64 1:1.18.2-2 [20.9 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse-mainloop-glib0 amd64 1:11.1-1ubuntu7.10 [22.1 kB]
# Get:70 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse-dev amd64 1:11.1-1ubuntu7.10 [81.5 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsndio-dev amd64 1.1.0-3 [13.3 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libudev-dev amd64 237-3ubuntu10.42 [19.1 kB]
# Get:73 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxv-dev amd64 2:1.0.11-1 [32.5 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsdl2-dev amd64 2.0.8+dfsg1-1ubuntu1.18.04.4 [683 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwildmidi-config all 0.4.2-1 [7,212 B]
# Get:76 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwildmidi2 amd64 0.4.2-1 [55.8 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwildmidi-dev amd64 0.4.2-1 [86.4 kB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic/universe amd64 nasm amd64 2.13.02-0.1 [359 kB]
# Get:79 http://archive.ubuntu.com/ubuntu bionic/universe amd64 timidity amd64 2.13.2-41 [585 kB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic/universe amd64 timidity-daemon all 2.13.2-41 [5,984 B]
# Fetched 43.2 MB in 3s (14.1 MB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 80.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 144579 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package gettext-base.
# Preparing to unpack .../03-gettext-base_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../04-libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../05-m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../06-autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../07-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../08-automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../09-autopoint_0.19.8.1-6ubuntu0.3_all.deb ...
# Unpacking autopoint (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../10-libtool_2.4.6-2_all.deb ...
# Unpacking libtool (2.4.6-2) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../11-dh-autoreconf_17_all.deb ...
# Unpacking dh-autoreconf (17) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../12-libarchive-zip-perl_1.60-1ubuntu0.1_all.deb ...
# Unpacking libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../13-libfile-stripnondeterminism-perl_0.040-1.1~build1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../14-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../15-dh-strip-nondeterminism_0.040-1.1~build1_all.deb ...
# Unpacking dh-strip-nondeterminism (0.040-1.1~build1) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../16-gettext_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../17-intltool-debian_0.35.0+20060710.4_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.4) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../18-po-debconf_1.0.20_all.deb ...
# Unpacking po-debconf (1.0.20) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../19-debhelper_11.1.6ubuntu2_all.deb ...
# Unpacking debhelper (11.1.6ubuntu2) ...
# Selecting previously unselected package freepats.
# Preparing to unpack .../20-freepats_20060219-1_all.deb ...
# Unpacking freepats (20060219-1) ...
# Selecting previously unselected package gir1.2-atk-1.0:amd64.
# Preparing to unpack .../21-gir1.2-atk-1.0_2.28.1-1_amd64.deb ...
# Unpacking gir1.2-atk-1.0:amd64 (2.28.1-1) ...
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# Preparing to unpack .../22-gir1.2-freedesktop_1.56.1-1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Selecting previously unselected package gir1.2-gdkpixbuf-2.0:amd64.
# Preparing to unpack .../23-gir1.2-gdkpixbuf-2.0_2.36.11-2_amd64.deb ...
# Unpacking gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../24-libpangoxft-1.0-0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../25-gir1.2-pango-1.0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-gtk-2.0.
# Preparing to unpack .../26-gir1.2-gtk-2.0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking gir1.2-gtk-2.0 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libibus-1.0-5:amd64.
# Preparing to unpack .../27-libibus-1.0-5_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking libibus-1.0-5:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package gir1.2-ibus-1.0:amd64.
# Preparing to unpack .../28-gir1.2-ibus-1.0_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking gir1.2-ibus-1.0:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../29-libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libatk1.0-dev:amd64.
# Preparing to unpack .../30-libatk1.0-dev_2.28.1-1_amd64.deb ...
# Unpacking libatk1.0-dev:amd64 (2.28.1-1) ...
# Selecting previously unselected package libaudio2:amd64.
# Preparing to unpack .../31-libaudio2_1.9.4-6_amd64.deb ...
# Unpacking libaudio2:amd64 (1.9.4-6) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../32-libcairo-script-interpreter2_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../33-libpixman-1-dev_0.34.0-2_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../34-libxcb-shm0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../35-libcairo2-dev_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libcapnp-0.6.1:amd64.
# Preparing to unpack .../36-libcapnp-0.6.1_0.6.1-1ubuntu1_amd64.deb ...
# Unpacking libcapnp-0.6.1:amd64 (0.6.1-1ubuntu1) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../37-libdbus-1-dev_1.12.2-1ubuntu1.2_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.2-1ubuntu1.2) ...
# Selecting previously unselected package libfluidsynth1:amd64.
# Preparing to unpack .../38-libfluidsynth1_1.1.9-1_amd64.deb ...
# Unpacking libfluidsynth1:amd64 (1.1.9-1) ...
# Selecting previously unselected package libfluidsynth-dev:amd64.
# Preparing to unpack .../39-libfluidsynth-dev_1.1.9-1_amd64.deb ...
# Unpacking libfluidsynth-dev:amd64 (1.1.9-1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-dev.
# Preparing to unpack .../40-libgdk-pixbuf2.0-dev_2.36.11-2_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Selecting previously unselected package libgme-dev:amd64.
# Preparing to unpack .../41-libgme-dev_0.6.2-1_amd64.deb ...
# Unpacking libgme-dev:amd64 (0.6.2-1) ...
# Selecting previously unselected package libpango1.0-dev.
# Preparing to unpack .../42-libpango1.0-dev_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../43-x11proto-xinerama-dev_2018.4-4_all.deb ...
# Unpacking x11proto-xinerama-dev (2018.4-4) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../44-libxinerama-dev_2%3a1.1.3-1_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.3-1) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../45-x11proto-randr-dev_2018.4-4_all.deb ...
# Unpacking x11proto-randr-dev (2018.4-4) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../46-libxrandr-dev_2%3a1.5.1-1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.1-1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../47-libxcursor-dev_1%3a1.1.15-1_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.1.15-1) ...
# Selecting previously unselected package x11proto-composite-dev.
# Preparing to unpack .../48-x11proto-composite-dev_1%3a2018.4-4_all.deb ...
# Unpacking x11proto-composite-dev (1:2018.4-4) ...
# Selecting previously unselected package libxcomposite-dev:amd64.
# Preparing to unpack .../49-libxcomposite-dev_1%3a0.4.4-2_amd64.deb ...
# Unpacking libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Selecting previously unselected package libxml2-utils.
# Preparing to unpack .../50-libxml2-utils_2.9.4+dfsg1-6.1ubuntu1.3_amd64.deb ...
# Unpacking libxml2-utils (2.9.4+dfsg1-6.1ubuntu1.3) ...
# Selecting previously unselected package libgtk2.0-dev.
# Preparing to unpack .../51-libgtk2.0-dev_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-dev (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libibus-1.0-dev:amd64.
# Preparing to unpack .../52-libibus-1.0-dev_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking libibus-1.0-dev:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../53-libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../54-libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Selecting previously unselected package libmircore1:amd64.
# Preparing to unpack .../55-libmircore1_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircore1:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircommon7:amd64.
# Preparing to unpack .../56-libmircommon7_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libprotobuf-lite10:amd64.
# Preparing to unpack .../57-libprotobuf-lite10_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libmirprotobuf3:amd64.
# Preparing to unpack .../58-libmirprotobuf3_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmirclient9:amd64.
# Preparing to unpack .../59-libmirclient9_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircore-dev:amd64.
# Preparing to unpack .../60-libmircore-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircore-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libprotobuf-dev:amd64.
# Preparing to unpack .../61-libprotobuf-dev_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../62-libxkbcommon-dev_0.8.2-1~ubuntu18.04.1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Selecting previously unselected package libmircommon-dev:amd64.
# Preparing to unpack .../63-libmircommon-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircookie2:amd64.
# Preparing to unpack .../64-libmircookie2_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircookie2:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircookie-dev:amd64.
# Preparing to unpack .../65-libmircookie-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmirclient-dev:amd64.
# Preparing to unpack .../66-libmirclient-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libopenal-dev:amd64.
# Preparing to unpack .../67-libopenal-dev_1%3a1.18.2-2_amd64.deb ...
# Unpacking libopenal-dev:amd64 (1:1.18.2-2) ...
# Selecting previously unselected package libpulse-mainloop-glib0:amd64.
# Preparing to unpack .../68-libpulse-mainloop-glib0_1%3a11.1-1ubuntu7.10_amd64.deb ...
# Unpacking libpulse-mainloop-glib0:amd64 (1:11.1-1ubuntu7.10) ...
# Selecting previously unselected package libpulse-dev:amd64.
# Preparing to unpack .../69-libpulse-dev_1%3a11.1-1ubuntu7.10_amd64.deb ...
# Unpacking libpulse-dev:amd64 (1:11.1-1ubuntu7.10) ...
# Selecting previously unselected package libsndio-dev:amd64.
# Preparing to unpack .../70-libsndio-dev_1.1.0-3_amd64.deb ...
# Unpacking libsndio-dev:amd64 (1.1.0-3) ...
# Selecting previously unselected package libudev-dev:amd64.
# Preparing to unpack .../71-libudev-dev_237-3ubuntu10.42_amd64.deb ...
# Unpacking libudev-dev:amd64 (237-3ubuntu10.42) ...
# Selecting previously unselected package libxv-dev:amd64.
# Preparing to unpack .../72-libxv-dev_2%3a1.0.11-1_amd64.deb ...
# Unpacking libxv-dev:amd64 (2:1.0.11-1) ...
# Selecting previously unselected package libsdl2-dev:amd64.
# Preparing to unpack .../73-libsdl2-dev_2.0.8+dfsg1-1ubuntu1.18.04.4_amd64.deb ...
# Unpacking libsdl2-dev:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# Selecting previously unselected package libwildmidi-config.
# Preparing to unpack .../74-libwildmidi-config_0.4.2-1_all.deb ...
# Unpacking libwildmidi-config (0.4.2-1) ...
# Selecting previously unselected package libwildmidi2:amd64.
# Preparing to unpack .../75-libwildmidi2_0.4.2-1_amd64.deb ...
# Unpacking libwildmidi2:amd64 (0.4.2-1) ...
# Selecting previously unselected package libwildmidi-dev.
# Preparing to unpack .../76-libwildmidi-dev_0.4.2-1_amd64.deb ...
# Unpacking libwildmidi-dev (0.4.2-1) ...
# Selecting previously unselected package nasm.
# Preparing to unpack .../77-nasm_2.13.02-0.1_amd64.deb ...
# Unpacking nasm (2.13.02-0.1) ...
# Selecting previously unselected package timidity.
# Preparing to unpack .../78-timidity_2.13.2-41_amd64.deb ...
# Unpacking timidity (2.13.2-41) ...
# Selecting previously unselected package timidity-daemon.
# Preparing to unpack .../79-timidity-daemon_2.13.2-41_all.deb ...
# Unpacking timidity-daemon (2.13.2-41) ...
# Setting up libdbus-1-dev:amd64 (1.12.2-1ubuntu1.2) ...
# Setting up libxcursor-dev:amd64 (1:1.1.15-1) ...
# Setting up gir1.2-atk-1.0:amd64 (2.28.1-1) ...
# Setting up libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Setting up libpulse-mainloop-glib0:amd64 (1:11.1-1ubuntu7.10) ...
# Setting up libpulse-dev:amd64 (1:11.1-1ubuntu7.10) ...
# Setting up libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Setting up libmircore-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up libgme-dev:amd64 (0.6.2-1) ...
# Setting up gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Setting up libsndio-dev:amd64 (1.1.0-3) ...
# Setting up libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libxml2-utils (2.9.4+dfsg1-6.1ubuntu1.3) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Setting up libatk1.0-dev:amd64 (2.28.1-1) ...
# Setting up gettext-base (0.19.8.1-6ubuntu0.3) ...
# Setting up m4 (1.4.18-1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libopenal-dev:amd64 (1:1.18.2-2) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up libwildmidi-config (0.4.2-1) ...
# Setting up libmircookie2:amd64 (0.31.1-0ubuntu1) ...
# Setting up libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Setting up x11proto-xinerama-dev (2018.4-4) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up libpixman-1-dev:amd64 (0.34.0-2) ...
# Setting up x11proto-randr-dev (2018.4-4) ...
# Setting up libxinerama-dev:amd64 (2:1.1.3-1) ...
# Setting up libxv-dev:amd64 (2:1.0.11-1) ...
# Setting up nasm (2.13.02-0.1) ...
# Setting up libcapnp-0.6.1:amd64 (0.6.1-1ubuntu1) ...
# Setting up libibus-1.0-5:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up libmircore1:amd64 (0.31.1-0ubuntu1) ...
# Setting up freepats (20060219-1) ...
# Setting up libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libudev-dev:amd64 (237-3ubuntu10.42) ...
# Setting up libfluidsynth1:amd64 (1.1.9-1) ...
# Setting up x11proto-composite-dev (1:2018.4-4) ...
# Setting up autopoint (0.19.8.1-6ubuntu0.3) ...
# Setting up libaudio2:amd64 (1.9.4-6) ...
# Setting up libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Setting up gir1.2-gtk-2.0 (2.24.32-1ubuntu1) ...
# Setting up gir1.2-ibus-1.0:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up libxrandr-dev:amd64 (2:1.5.1-1) ...
# Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up gettext (0.19.8.1-6ubuntu0.3) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Setting up libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Setting up libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up autoconf (2.69-11) ...
# Setting up libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libwildmidi2:amd64 (0.4.2-1) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up intltool-debian (0.35.0+20060710.4) ...
# Setting up libibus-1.0-dev:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Setting up libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Setting up libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Setting up libfluidsynth-dev:amd64 (1.1.9-1) ...
# Setting up timidity (2.13.2-41) ...
# Setting up libtool (2.4.6-2) ...
# Setting up po-debconf (1.0.20) ...
# Setting up libwildmidi-dev (0.4.2-1) ...
# Setting up libgtk2.0-dev (2.24.32-1ubuntu1) ...
# Setting up libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Setting up libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up timidity-daemon (2.13.2-41) ...
# Adding group timidity....done
# Adding system user timidity....done
# Adding user `timidity' to group `audio' ...
# Adding user timidity to group audio
# Done.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of stop.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libsdl2-dev:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# Setting up debhelper (11.1.6ubuntu2) ...
# Setting up dh-autoreconf (17) ...
# Setting up dh-strip-nondeterminism (0.040-1.1~build1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for systemd (237-3ubuntu10.42) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libboost-all-dev is already the newest version (1.65.1.0ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 60 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'liblua5.1-0-dev' instead of 'liblua5.1-dev'
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libtool-bin
# The following NEW packages will be installed:
#   liblua5.1-0-dev libtool-bin
# 0 upgraded, 2 newly installed, 0 to remove and 60 not upgraded.
# Need to get 198 kB of archives.
# After this operation, 1,188 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 liblua5.1-0-dev amd64 5.1.5-8.1build2 [119 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool-bin amd64 2.4.6-2 [79.5 kB]
# Fetched 198 kB in 1s (266 kB/s)
# Selecting previously unselected package liblua5.1-0-dev:amd64.
# (Reading database ... 147605 files and directories currently installed.)
# Preparing to unpack .../liblua5.1-0-dev_5.1.5-8.1build2_amd64.deb ...
# Unpacking liblua5.1-0-dev:amd64 (5.1.5-8.1build2) ...
# Selecting previously unselected package libtool-bin.
# Preparing to unpack .../libtool-bin_2.4.6-2_amd64.deb ...
# Unpacking libtool-bin (2.4.6-2) ...
# Setting up libtool-bin (2.4.6-2) ...
# Setting up liblua5.1-0-dev:amd64 (5.1.5-8.1build2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgtk2.0-dev is already the newest version (2.24.32-1ubuntu1).
# python-numpy is already the newest version (1:1.13.3-2ubuntu1).
# python-numpy set to manually installed.
# libboost-all-dev is already the newest version (1.65.1.0ubuntu1).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# git is already the newest version (1:2.17.1-1ubuntu0.7).
# libsdl2-dev is already the newest version (2.0.8+dfsg1-1ubuntu1.18.04.4).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 60 not upgraded.
# Cloning into 'vizdoomgym'...
# remote: Enumerating objects: 251, done.
# remote: Counting objects: 100% (251/251), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 558 (delta 129), reused 144 (delta 69), pack-reused 307
# Receiving objects: 100% (558/558), 179.04 KiB | 2.45 MiB/s, done.
# Resolving deltas: 100% (295/295), done.
# Obtaining file:///content/vizdoomgym
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (from vizdoomgym==1.0) (0.17.2)
# Collecting vizdoom@ https://github.com/mwydmuch/ViZDoom/tarball/1.1.8pre
#   Downloading https://github.com/mwydmuch/ViZDoom/tarball/1.1.8pre
#      / 6.1MB 1.4MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from vizdoomgym==1.0) (1.18.5)
# Collecting pre-commit
#   Downloading https://files.pythonhosted.org/packages/2c/88/966da62ec93566c221bf8bf0c1b7f04e70f002960a98da05d3fd8bc3b2e7/pre_commit-2.7.1-py2.py3-none-any.whl (171kB)
#      |████████████████████████████████| 174kB 3.5MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym->vizdoomgym==1.0) (1.4.1)
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym->vizdoomgym==1.0) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym->vizdoomgym==1.0) (1.5.0)
# Collecting virtualenv>=20.0.8
#   Downloading https://files.pythonhosted.org/packages/12/51/36c685ff2c1b2f7b4b5db29f3153159102ae0e0adaff3a26fd1448232e06/virtualenv-20.0.31-py2.py3-none-any.whl (4.9MB)
#      |████████████████████████████████| 4.9MB 15.3MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from pre-commit->vizdoomgym==1.0) (1.7.0)
# Collecting pyyaml>=5.1
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
#      |████████████████████████████████| 276kB 37.2MB/s
# Collecting identify>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/fd/e0/593fed766c1ddbf7dfb3bdbc997af3c5dcbf7862392f4ee5fef744128622/identify-1.4.29-py2.py3-none-any.whl (97kB)
#      |████████████████████████████████| 102kB 8.4MB/s
# Collecting cfgv>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/45/cd/3878c9248e59e5e2ebd0dc741ab984b18d86e7283ae9b127b05fc287d239/cfgv-3.2.0-py2.py3-none-any.whl
# Requirement already satisfied: toml in /usr/local/lib/python3.6/dist-packages (from pre-commit->vizdoomgym==1.0) (0.10.1)
# Collecting nodeenv>=0.11.1
#   Downloading https://files.pythonhosted.org/packages/ae/d0/efdf54539948315cc76e5a66b709212963101d002822c3b54369dbf9b5e0/nodeenv-1.5.0-py2.py3-none-any.whl
# Collecting importlib-resources; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/ba/03/0f9595c0c2ef12590877f3c47e5f579759ce5caf817f8256d5dcbd8a1177/importlib_resources-3.0.0-py2.py3-none-any.whl
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->vizdoomgym==1.0) (0.16.0)
# Requirement already satisfied: six<2,>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from virtualenv>=20.0.8->pre-commit->vizdoomgym==1.0) (1.15.0)
# Collecting distlib<1,>=0.3.1
#   Downloading https://files.pythonhosted.org/packages/f5/0a/490fa011d699bb5a5f3a0cf57de82237f52a6db9d40f33c53b2736c9a1f9/distlib-0.3.1-py2.py3-none-any.whl (335kB)
#      |████████████████████████████████| 337kB 34.5MB/s
# Requirement already satisfied: filelock<4,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from virtualenv>=20.0.8->pre-commit->vizdoomgym==1.0) (3.0.12)
# Collecting appdirs<2,>=1.4.3
#   Downloading https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->pre-commit->vizdoomgym==1.0) (3.1.0)
# Building wheels for collected packages: vizdoom, pyyaml
#   Building wheel for vizdoom (setup.py) ... done
#   Created wheel for vizdoom: filename=vizdoom-1.1.8-cp36-none-any.whl size=14293708 sha256=bdae797c8c7a6eecd688a3cf42120399b071138ead77fe96969e15b1f315e553
#   Stored in directory: /tmp/pip-ephem-wheel-cache-g4tnscmo/wheels/1b/e8/11/2c308b2447cf5421008b1de5216938fb990878fead56eb135d
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44619 sha256=5fee2ca4d451e1aac68136cbe51cad27f2373ba6026ee40a1c3e55a8a17017c5
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# Successfully built vizdoom pyyaml
# Installing collected packages: vizdoom, distlib, importlib-resources, appdirs, virtualenv, pyyaml, identify, cfgv, nodeenv, pre-commit, vizdoomgym
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Running setup.py develop for vizdoomgym
# Successfully installed appdirs-1.4.4 cfgv-3.2.0 distlib-0.3.1 identify-1.4.29 importlib-resources-3.0.0 nodeenv-1.5.0 pre-commit-2.7.1 pyyaml-5.3.1 virtualenv-20.0.31 vizdoom-1.1.8 vizdoomgym

# %%
# !pip install av
# Out:
# Collecting av
#   Downloading https://files.pythonhosted.org/packages/9e/62/9a992be76f8e13ce0e3a24a838191b546805545116f9fc869bd11bd21b5f/av-8.0.2-cp36-cp36m-manylinux2010_x86_64.whl (36.9MB)
#      |████████████████████████████████| 36.9MB 81kB/s
# Installing collected packages: av
# Successfully installed av-8.0.2

# %% [markdown]
# Inspect the environment. You'll need to restart the runtime for it to work

# %%
#Check the environment. You'll need to restart the runtime for it to work
import gym
import vizdoomgym
!
env = gym.make('VizdoomDefendLine-v0')

# use like a normal Gym environment
state = env.reset()
state, reward, done, info = env.step(env.action_space.sample())
print(state.shape)
# env.render()
env.close()
# Out:
# Cannot connect to "None"
# (240, 320, 3)

# %%
import gym
import vizdoomgym

env = gym.make('VizdoomDefendLine-v0')
n_outputs = env.action_space.n
print(n_outputs)


observation = env.reset()

import matplotlib.pyplot as plt


for i in range(22):
  
  if i > 20:
    print(observation.shape)
    plt.imshow(observation)
    plt.show()

  observation, _, _, _ = env.step(1)
# Out:
# 7
# (240, 320, 3)

# %%
import numpy as np


from collections import deque, Counter
import random
from datetime import datetime
from __future__ import division
from __future__ import print_function
from vizdoom import *
import itertools as it
from random import sample, randint, random
from time import time, sleep
import numpy as np
import skimage.color, skimage.transform
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from tqdm import trange

# %% [markdown]
# ## Preprocessing
#
# We'll define a set of wrappers to modify our gym environment to provide preprocessed observations.
#
# We’ll start defining a wrapper to repeat every action for a number of frames, and perform an element-wise maxima in order to increase the intensity of any actions.
#
# Next, we define the preprocessing function for our observations. We’ll make our environment symmetrical by converting it into the Box space, swapping the channel integer to the front of our tensor, and resizing it to an area of (84,84) from its original (320,480) resolution. We’ll also greyscale our environment, and normalize the entire image by dividing by a constant.
#
# Next, we create a wrapper to handle frame-stacking. The objective here is to help capture motion and direction from stacking frames, by stacking several frames together as a single batch. In this way, we can capture position, translation, velocity, and acceleration of the elements in the environment. With stacking, our input adopts a shape of (4,84,84,1).

# %%
#11072020 Utililities support class

import collections
import cv2
import numpy as np
import matplotlib.pyplot as plt
import gym

def plot_learning_curve(x, scores, epsilons, filename, lines=None):
    fig=plt.figure()
    ax=fig.add_subplot(111, label="1")
    ax2=fig.add_subplot(111, label="2", frame_on=False)

    ax.plot(x, epsilons, color="C0")
    ax.set_xlabel("Episodes", color="C0")
    ax.set_ylabel("Epsilon", color="C0")
    ax.tick_params(axis='x', colors="C0")
    ax.tick_params(axis='y', colors="C0")

    N = len(scores)
    running_avg = np.empty(N)
    for t in range(N):
	    running_avg[t] = np.mean(scores[max(0, t-20):(t+1)])

    ax2.scatter(x, running_avg, color="C1")
    ax2.axes.get_xaxis().set_visible(False)
    ax2.yaxis.tick_right()
    ax2.set_ylabel('Average Score', color="C1")
    ax2.yaxis.set_label_position('right')
    ax2.tick_params(axis='y', colors="C1")

    if lines is not None:
        for line in lines:
            plt.axvline(x=line)

    

class RepeatActionAndMaxFrame(gym.Wrapper):
  #input: environment, repeat
  #init frame buffer as an array of zeros in shape 2 x the obs space
    def __init__(self, env=None, repeat=4, clip_reward=False, no_ops=0,
                 fire_first=False):
        super(RepeatActionAndMaxFrame, self).__init__(env)
        self.repeat = repeat
        self.shape = env.observation_space.low.shape
        self.frame_buffer = np.zeros_like((2, self.shape))
        self.clip_reward = clip_reward
        self.no_ops = no_ops
        self.fire_first = fire_first

    def step(self, action):
        t_reward = 0.0
        done = False
        for i in range(self.repeat):
            obs, reward, done, info = self.env.step(action)
            if self.clip_reward:
                reward = np.clip(np.array([reward]), -1, 1)[0]
            t_reward += reward
            idx = i % 2
            self.frame_buffer[idx] = obs
            if done:
                break

        max_frame = np.maximum(self.frame_buffer[0], self.frame_buffer[1])
        return max_frame, t_reward, done, info

    def reset(self):
        obs = self.env.reset()
        no_ops = np.random.randint(self.no_ops)+1 if self.no_ops > 0 else 0
        for _ in range(no_ops):
            _, _, done, _ = self.env.step(0)
            if done:
                self.env.reset()
        #Fire first seems quite useless, probably meant for something like space invader
        if self.fire_first:
            assert self.env.unwrapped.get_action_meanings()[1] == 'FIRE'
            obs, _, _, _ = self.env.step(1)

        self.frame_buffer = np.zeros_like((2,self.shape))
        self.frame_buffer[0] = obs

        return obs

class PreprocessFrame(gym.ObservationWrapper):
  #set shape by swapping channels axis
	#set observation space to new shape using gym.spaces.Box (0 to 1.0)
    def __init__(self, shape, env=None):
        super(PreprocessFrame, self).__init__(env)
        self.shape = (shape[2], shape[0], shape[1])
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0,
                                    shape=self.shape, dtype=np.float32)

    def observation(self, obs):
        new_frame = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)
        resized_screen = cv2.resize(new_frame, self.shape[1:],
                                    interpolation=cv2.INTER_AREA)
        new_obs = np.array(resized_screen, dtype=np.uint8).reshape(self.shape)
        new_obs = new_obs / 255.0

        return new_obs

class StackFrames(gym.ObservationWrapper):
  #init the new obs space (gym.spaces.Box) low & high bounds as repeat of n_steps. These should have been defined for vizdooom
  #WE may not have to use boxes in ur final model. But we can keep it for now
  #Create a return a stack of observations
    def __init__(self, env, repeat):
        super(StackFrames, self).__init__(env)
        self.observation_space = gym.spaces.Box(
                            env.observation_space.low.repeat(repeat, axis=0),
                            env.observation_space.high.repeat(repeat, axis=0),
                            dtype=np.float32)
        self.stack = collections.deque(maxlen=repeat)

    def reset(self):
        self.stack.clear()
        observation = self.env.reset()
        for _ in range(self.stack.maxlen):
            self.stack.append(observation)

        return np.array(self.stack).reshape(self.observation_space.low.shape)

    def observation(self, observation):
        self.stack.append(observation)

        return np.array(self.stack).reshape(self.observation_space.low.shape)

#This shape command should not be 84,84,1 take a look at what we went with in our TF example
#Note how fire_first is false here, probably useless in the context of Pong
def make_env(env_name, shape=(84,84,1), repeat=4, clip_rewards=False,
             no_ops=0, fire_first=False):
    env = gym.make(env_name)
    env = PreprocessFrame(shape, env)
    env = RepeatActionAndMaxFrame(env, repeat, clip_rewards, no_ops, fire_first)
    
    env = StackFrames(env, repeat)

    return env

# %% [markdown]
# Next, let’s define our model, a deep Q-network. This is essentially a three layer convolutional network that takes preprocessed input obserations, with the generated flattened output fed to a fully-connected layer, generating probabilities of taking each action in the game space as an output.
#
# The output layer is a fully-connected linear layer with a single output for each valid action (between 4 and 18 in the Atari games)

# %%
##11072020 New DeepQNetwork class. Notice th number of filters, and the dimensions. This may work better
# Interesting note, the use of the name is needed for saving checkpoints, so it might not be necessary
import os
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

class DeepQNetwork(nn.Module):
    def __init__(self, lr, n_actions, name, input_dims, chkpt_dir):
        super(DeepQNetwork, self).__init__()
        self.checkpoint_dir = chkpt_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir, name)

        self.conv1 = nn.Conv2d(input_dims[0], 32, 8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, 4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, 3, stride=1)

        fc_input_dims = self.calculate_conv_output_dims(input_dims)

        self.fc1 = nn.Linear(fc_input_dims, 512)
        self.fc2 = nn.Linear(512, n_actions)

        self.optimizer = optim.RMSprop(self.parameters(), lr=lr)

        self.loss = nn.MSELoss()
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def calculate_conv_output_dims(self, input_dims):
        state = T.zeros(1, *input_dims)
        dims = self.conv1(state)
        dims = self.conv2(dims)
        dims = self.conv3(dims)
        return int(np.prod(dims.size()))

    def forward(self, state):
        conv1 = F.relu(self.conv1(state))
        conv2 = F.relu(self.conv2(conv1))
        conv3 = F.relu(self.conv3(conv2))
        # conv3 shape is BS x n_filters x H x W
        conv_state = conv3.view(conv3.size()[0], -1)
        # conv_state shape is BS x (n_filters * H * W)
        flat1 = F.relu(self.fc1(conv_state))
        actions = self.fc2(flat1)

        return actions

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_file))

# %% [markdown]
# ## Storing Replay Memories
#
# In this section we will create a mechanism for the agent to keep track of states, actions, rewards, new states, and the final state.
#
# All of these factors will be used in the calculation of the Target for the loss function of the DQN.
#
# For maximum flexibility of the agent the memory should accomodate states with an arbitrary shape.
#
# We should also sample from the memory uniformly, meaning each memory will have an equal probability of being sampled, and we should not repeat memories.

# %%
#11072020 New ReplayMemory Class

import numpy as np

class ReplayBuffer(object):
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_shape),
                                     dtype=np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_shape),
                                         dtype=np.float32)

        self.action_memory = np.zeros(self.mem_size, dtype=np.int64)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)

    #Identify index and store  the the current SARSA into batch memory
    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = done
        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)
        batch = np.random.choice(max_mem, batch_size, replace=False)
        #I believe batch here is creating a list limit that is acquired through max_mem, whihch we use to subselect memory
        states = self.state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        states_ = self.new_state_memory[batch]
        terminal = self.terminal_memory[batch]

        return states, actions, rewards, states_, terminal

# %% [markdown]
# ## Agent Class
#
# Our agent be using an epsilon greedy policy with a decaying exploration rate, in order to maximize exploitation over time. To learn to predict state-action-values that maximize our cumulative reward, our agent will be using the discounted future rewards obtained by sampling the memory.
#
# You’’ll notice that we initialize two copies of our DQN as part of our agent, with methods to copy weight parameters of our original network into a target network. This dual-network approach allows us to generate data during the training process using an existing policy while still optimizing our parameters for the next policy iteration, reducing loss oscillations. We will leverage this for our DDQN implementation.
#
# For reference, the original vanilla DQN update function is shown below:
#
# ![image.png](data:image/png;base64,...)

# %%
#11072020 New self-contained DQNAgent Class

import numpy as np
import torch as T
#from deep_q_network import DeepQNetwork
#from replay_memory import ReplayBuffer

class DDQNAgent(object):
    def __init__(self, gamma, epsilon, lr, n_actions, input_dims,
                 mem_size, batch_size, eps_min=0.01, eps_dec=5e-7,
                 replace=1000, algo=None, env_name=None, chkpt_dir='tmp/dqn'):
        self.gamma = gamma
        self.epsilon = epsilon
        self.lr = lr
        self.n_actions = n_actions
        self.input_dims = input_dims
        self.batch_size = batch_size
        self.eps_min = eps_min
        self.eps_dec = eps_dec
        self.replace_target_cnt = replace
        self.algo = algo
        self.env_name = env_name
        self.chkpt_dir = chkpt_dir
        self.action_space = [i for i in range(n_actions)]
        self.learn_step_counter = 0

        self.memory = ReplayBuffer(mem_size, input_dims, n_actions)

        self.q_eval = DeepQNetwork(self.lr, self.n_actions,
                                    input_dims=self.input_dims,
                                    name=self.env_name+'_'+self.algo+'_q_eval',
                                    chkpt_dir=self.chkpt_dir)

        self.q_next = DeepQNetwork(self.lr, self.n_actions,
                                    input_dims=self.input_dims,
                                    name=self.env_name+'_'+self.algo+'_q_next',
                                    chkpt_dir=self.chkpt_dir)

    #Epsilon greedy action selection
    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
          # Add dimension to observation to match input_dims x batch_size by placing in list, then converting to tensor
            state = T.tensor([observation],dtype=T.float).to(self.q_eval.device)
            actions = self.q_eval.forward(state)
            #Return tensor, but use item() to reutnr integer
            action = T.argmax(actions).item()
        else:
            action = np.random.choice(self.action_space)

        return action

    def store_transition(self, state, action, reward, state_, done):
        self.memory.store_transition(state, action, reward, state_, done)

    def sample_memory(self):
        state, action, reward, new_state, done = \
                                self.memory.sample_buffer(self.batch_size)

        states = T.tensor(state).to(self.q_eval.device)
        rewards = T.tensor(reward).to(self.q_eval.device)
        dones = T.tensor(done).to(self.q_eval.device)
        actions = T.tensor(action).to(self.q_eval.device)
        states_ = T.tensor(new_state).to(self.q_eval.device)

        return states, actions, rewards, states_, dones

    def replace_target_network(self):
        if self.learn_step_counter % self.replace_target_cnt == 0:
            self.q_next.load_state_dict(self.q_eval.state_dict())

    def decrement_epsilon(self):
        self.epsilon = self.epsilon - self.eps_dec \
                           if self.epsilon > self.eps_min else self.eps_min

    def save_models(self):
        self.q_eval.save_checkpoint()
        self.q_next.save_checkpoint()

    def load_models(self):
        self.q_eval.load_checkpoint()
        self.q_next.load_checkpoint()
    #Make sure you understand this line by line
    #For DDQN main difference is here - Consult the lecture to gain a stronger understanding of why things differe here
    def learn(self):

      #First check if memory is even big enough
        if self.memory.mem_cntr < self.batch_size:
            return

        self.q_eval.optimizer.zero_grad()

        #Replace target network if appropriate
        self.replace_target_network()

        states, actions, rewards, states_, dones = self.sample_memory()
        #Fetch indices for  matrix multiplication for q_pred
        indices = np.arange(self.batch_size)

        #Calculate the value of the states taken using the eval network
        # We use the indices here to make sure our output q_pred is of shape batch_size instead of batch_size x action_size 
        q_pred = self.q_eval.forward(states)[indices, actions]
        # calculate the state action value of the next state according to target network
        q_next = self.q_next.forward(states_)
        # calculate the state action value of the next state according to eval network
        q_eval = self.q_eval.forward(states_)

        #Calculate the maximum action value for the new states according to the eval network
        max_actions = T.argmax(q_eval, dim=1)
    
        #Set q_next to 0 for terminal states
        q_next[dones] = 0.0
        q_target = rewards + self.gamma*q_next[indices, max_actions]

        loss = self.q_eval.loss(q_target, q_pred).to(self.q_eval.device)
        loss.backward()
        self.q_eval.optimizer.step()
        self.learn_step_counter += 1

        self.decrement_epsilon()

# %% [markdown]
# # Main Training Loop
#
# 1. For every step of a training episode, we feed an input image stack into our network to generate a probability distribution of the available actions, before using an epsilon-greedy policy to select the next action.
#
# 2. We then input this into the network, and obtain information on the next state and accompanying rewards, and store this into our buffer. We update our stack and repeat this process over a number of pre-defined steps.
#
# 3. At the end of an episode, we feed the next states into our network in order to obtain the next action. We also calculate the next reward by discounting the current one.
#
# 4. We generate our target y-values through the Q-learning update function, and train our network.
#
# 5. By minimizing the training loss, we update the network weight parameters to output improved state-action values for the next policy.

# %%
# Main thread

env = make_env('VizdoomDefendLine-v0')
best_score = -np.inf
load_checkpoint = False
n_games = 5000
agent = DDQNAgent(gamma=0.99, epsilon=1.0, lr=0.0001,input_dims=(env.observation_space.shape),n_actions=env.action_space.n, mem_size=5000, eps_min=0.1,batch_size=32, replace=1000, eps_dec=1e-5,chkpt_dir='/content/', algo='DDQNAgent',env_name='vizdoogym')

if load_checkpoint:
  agent.load_models()

fname = agent.algo + '_' + agent.env_name + '_lr' + str(agent.lr) +'_'+ str(n_games) + 'games'
figure_file = 'plots/' + fname + '.png'

n_steps = 0
scores, eps_history, steps_array = [], [], []

for i in range(n_games):
  done = False
  observation = env.reset()

  score = 0
  while not done:
    action = agent.choose_action(observation)
    observation_, reward, done, info = env.step(action)
    score += reward

    if not load_checkpoint:
      agent.store_transition(observation, action,reward, observation_, int(done))
      agent.learn()
    observation = observation_
    n_steps += 1

  scores.append(score)
  steps_array.append(n_steps)

  avg_score = np.mean(scores[-100:])
 

  if avg_score > best_score:
    best_score = avg_score
      
    
    print('Checkpoint saved at episode ', i)
    agent.save_models()

  print('Episode: ', i,'Score: ', score,' Average score: %.2f' % avg_score, 'Best average: %.2f' % best_score,'Epsilon: %.2f' % agent.epsilon, 'Steps:', n_steps)  

  eps_history.append(agent.epsilon)
  if load_checkpoint and n_steps >= 18000:
    break

#x = [i+1 for i in range(len(scores))]
# Out:
# Streaming output truncated to the last 5000 lines.
# Episode:  790 Score:  -37.21037292480469  Average score: -43.07 Best average: -42.78 Epsilon: 0.78 Steps: 22063
# Episode:  791 Score:  5.9014739990234375  Average score: -43.03 Best average: -42.78 Epsilon: 0.78 Steps: 22084
# Episode:  792 Score:  -62.040374755859375  Average score: -42.96 Best average: -42.78 Epsilon: 0.78 Steps: 22096
# Episode:  793 Score:  -115.99723815917969  Average score: -43.03 Best average: -42.78 Epsilon: 0.78 Steps: 22116
# Episode:  794 Score:  -105.67634582519531  Average score: -44.63 Best average: -42.78 Epsilon: 0.78 Steps: 22128
# Episode:  795 Score:  -72.33169555664062  Average score: -44.99 Best average: -42.78 Epsilon: 0.78 Steps: 22139
# Episode:  796 Score:  -111.61308288574219  Average score: -45.27 Best average: -42.78 Epsilon: 0.78 Steps: 22161
# Episode:  797 Score:  -42.10101318359375  Average score: -44.99 Best average: -42.78 Epsilon: 0.78 Steps: 22181
# Episode:  798 Score:  -35.52143859863281  Average score: -45.16 Best average: -42.78 Epsilon: 0.78 Steps: 22203
# Episode:  799 Score:  -58.57350158691406  Average score: -45.06 Best average: -42.78 Epsilon: 0.78 Steps: 22252
# Episode:  800 Score:  -95.33903503417969  Average score: -45.28 Best average: -42.78 Epsilon: 0.78 Steps: 22289
# Episode:  801 Score:  -48.58062744140625  Average score: -44.61 Best average: -42.78 Epsilon: 0.78 Steps: 22308
# Episode:  802 Score:  -36.171630859375  Average score: -43.91 Best average: -42.78 Epsilon: 0.78 Steps: 22328
# Episode:  803 Score:  -8.3802490234375  Average score: -42.87 Best average: -42.78 Epsilon: 0.78 Steps: 22341
# Episode:  804 Score:  -80.69769287109375  Average score: -42.90 Best average: -42.78 Epsilon: 0.78 Steps: 22361
# Episode:  805 Score:  -58.415283203125  Average score: -43.94 Best average: -42.78 Epsilon: 0.78 Steps: 22382
# Episode:  806 Score:  -101.927001953125  Average score: -45.07 Best average: -42.78 Epsilon: 0.78 Steps: 22410
# Episode:  807 Score:  -16.2545166015625  Average score: -44.92 Best average: -42.78 Epsilon: 0.78 Steps: 22430
# Episode:  808 Score:  -1.5859222412109375  Average score: -44.59 Best average: -42.78 Epsilon: 0.78 Steps: 22451
# Episode:  809 Score:  -107.58674621582031  Average score: -46.12 Best average: -42.78 Epsilon: 0.78 Steps: 22480
# Episode:  810 Score:  -64.27351379394531  Average score: -47.38 Best average: -42.78 Epsilon: 0.78 Steps: 22500
# Episode:  811 Score:  -65.64533996582031  Average score: -48.11 Best average: -42.78 Epsilon: 0.77 Steps: 22556
# Episode:  812 Score:  -18.485794067382812  Average score: -47.59 Best average: -42.78 Epsilon: 0.77 Steps: 22576
# Episode:  813 Score:  -75.81584167480469  Average score: -48.86 Best average: -42.78 Epsilon: 0.77 Steps: 22588
# Episode:  814 Score:  -55.511322021484375  Average score: -49.14 Best average: -42.78 Epsilon: 0.77 Steps: 22606
# Episode:  815 Score:  60.862701416015625  Average score: -48.11 Best average: -42.78 Epsilon: 0.77 Steps: 22635
# Episode:  816 Score:  87.59626770019531  Average score: -46.89 Best average: -42.78 Epsilon: 0.77 Steps: 22677
# Episode:  817 Score:  -17.2198486328125  Average score: -46.37 Best average: -42.78 Epsilon: 0.77 Steps: 22696
# Episode:  818 Score:  -107.238525390625  Average score: -46.41 Best average: -42.78 Epsilon: 0.77 Steps: 22717
# Episode:  819 Score:  32.62213134765625  Average score: -45.97 Best average: -42.78 Epsilon: 0.77 Steps: 22735
# Episode:  820 Score:  89.07200622558594  Average score: -44.06 Best average: -42.78 Epsilon: 0.77 Steps: 22756
# Episode:  821 Score:  -22.143875122070312  Average score: -45.29 Best average: -42.78 Epsilon: 0.77 Steps: 22769
# Episode:  822 Score:  -30.4954833984375  Average score: -44.65 Best average: -42.78 Epsilon: 0.77 Steps: 22781
# Episode:  823 Score:  19.844757080078125  Average score: -43.87 Best average: -42.78 Epsilon: 0.77 Steps: 22815
# Episode:  824 Score:  -15.3663330078125  Average score: -43.39 Best average: -42.78 Epsilon: 0.77 Steps: 22835
# Checkpoint saved at episode  825
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  825 Score:  7.5913543701171875  Average score: -42.65 Best average: -42.65 Epsilon: 0.77 Steps: 22872
# Checkpoint saved at episode  826
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  826 Score:  -91.23863220214844  Average score: -42.61 Best average: -42.61 Epsilon: 0.77 Steps: 22885
# Episode:  827 Score:  -64.31593322753906  Average score: -42.74 Best average: -42.61 Epsilon: 0.77 Steps: 22914
# Episode:  828 Score:  -88.2584228515625  Average score: -42.75 Best average: -42.61 Epsilon: 0.77 Steps: 22936
# Episode:  829 Score:  -113.89694213867188  Average score: -44.12 Best average: -42.61 Epsilon: 0.77 Steps: 22948
# Episode:  830 Score:  -88.03590393066406  Average score: -44.90 Best average: -42.61 Epsilon: 0.77 Steps: 22959
# Episode:  831 Score:  -47.21736145019531  Average score: -46.09 Best average: -42.61 Epsilon: 0.77 Steps: 22977
# Episode:  832 Score:  17.128509521484375  Average score: -45.10 Best average: -42.61 Epsilon: 0.77 Steps: 22997
# Episode:  833 Score:  6.2563323974609375  Average score: -44.17 Best average: -42.61 Epsilon: 0.77 Steps: 23018
# Episode:  834 Score:  -20.160736083984375  Average score: -43.77 Best average: -42.61 Epsilon: 0.77 Steps: 23031
# Episode:  835 Score:  25.33740234375  Average score: -43.45 Best average: -42.61 Epsilon: 0.77 Steps: 23052
# Episode:  836 Score:  -22.192031860351562  Average score: -42.91 Best average: -42.61 Epsilon: 0.77 Steps: 23080
# Episode:  837 Score:  -47.68986511230469  Average score: -43.47 Best average: -42.61 Epsilon: 0.77 Steps: 23101
# Episode:  838 Score:  -62.064361572265625  Average score: -43.29 Best average: -42.61 Epsilon: 0.77 Steps: 23121
# Episode:  839 Score:  -45.07319641113281  Average score: -44.74 Best average: -42.61 Epsilon: 0.77 Steps: 23149
# Episode:  840 Score:  49.87788391113281  Average score: -44.14 Best average: -42.61 Epsilon: 0.77 Steps: 23169
# Episode:  841 Score:  -40.80369567871094  Average score: -44.34 Best average: -42.61 Epsilon: 0.77 Steps: 23189
# Episode:  842 Score:  -15.925796508789062  Average score: -44.14 Best average: -42.61 Epsilon: 0.77 Steps: 23202
# Episode:  843 Score:  -5.85302734375  Average score: -44.76 Best average: -42.61 Epsilon: 0.77 Steps: 23229
# Episode:  844 Score:  -8.292007446289062  Average score: -44.15 Best average: -42.61 Epsilon: 0.77 Steps: 23257
# Episode:  845 Score:  57.49305725097656  Average score: -42.96 Best average: -42.61 Epsilon: 0.77 Steps: 23283
# Episode:  846 Score:  -88.43853759765625  Average score: -42.80 Best average: -42.61 Epsilon: 0.77 Steps: 23296
# Checkpoint saved at episode  847
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  847 Score:  -14.132431030273438  Average score: -42.03 Best average: -42.03 Epsilon: 0.77 Steps: 23326
# Checkpoint saved at episode  848
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  848 Score:  -72.666259765625  Average score: -41.87 Best average: -41.87 Epsilon: 0.77 Steps: 23346
# Checkpoint saved at episode  849
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  849 Score:  -28.038711547851562  Average score: -41.85 Best average: -41.85 Epsilon: 0.77 Steps: 23375
# Episode:  850 Score:  -46.73223876953125  Average score: -42.64 Best average: -41.85 Epsilon: 0.77 Steps: 23395
# Episode:  851 Score:  -100.34945678710938  Average score: -42.54 Best average: -41.85 Epsilon: 0.77 Steps: 23406
# Episode:  852 Score:  -72.12063598632812  Average score: -42.10 Best average: -41.85 Epsilon: 0.77 Steps: 23427
# Checkpoint saved at episode  853
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  853 Score:  6.538482666015625  Average score: -41.28 Best average: -41.28 Epsilon: 0.77 Steps: 23446
# Checkpoint saved at episode  854
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  854 Score:  -9.096572875976562  Average score: -40.44 Best average: -40.44 Epsilon: 0.77 Steps: 23468
# Checkpoint saved at episode  855
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  855 Score:  122.24752807617188  Average score: -39.20 Best average: -39.20 Epsilon: 0.77 Steps: 23495
# Episode:  856 Score:  -78.26765441894531  Average score: -39.66 Best average: -39.20 Epsilon: 0.77 Steps: 23515
# Checkpoint saved at episode  857
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  857 Score:  -11.175384521484375  Average score: -38.87 Best average: -38.87 Epsilon: 0.76 Steps: 23534
# Episode:  858 Score:  -65.27352905273438  Average score: -38.95 Best average: -38.87 Epsilon: 0.76 Steps: 23545
# Checkpoint saved at episode  859
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  859 Score:  5.4306640625  Average score: -37.87 Best average: -37.87 Epsilon: 0.76 Steps: 23566
# Checkpoint saved at episode  860
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  860 Score:  -65.49296569824219  Average score: -37.59 Best average: -37.59 Epsilon: 0.76 Steps: 23594
# Checkpoint saved at episode  861
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  861 Score:  -26.497528076171875  Average score: -36.88 Best average: -36.88 Epsilon: 0.76 Steps: 23622
# Episode:  862 Score:  -78.14518737792969  Average score: -36.95 Best average: -36.88 Epsilon: 0.76 Steps: 23642
# Episode:  863 Score:  -115.937744140625  Average score: -37.49 Best average: -36.88 Epsilon: 0.76 Steps: 23661
# Episode:  864 Score:  -82.9468994140625  Average score: -38.12 Best average: -36.88 Epsilon: 0.76 Steps: 23681
# Episode:  865 Score:  -59.66650390625  Average score: -39.08 Best average: -36.88 Epsilon: 0.76 Steps: 23693
# Episode:  866 Score:  -45.07872009277344  Average score: -39.15 Best average: -36.88 Epsilon: 0.76 Steps: 23729
# Episode:  867 Score:  -27.779129028320312  Average score: -39.54 Best average: -36.88 Epsilon: 0.76 Steps: 23742
# Episode:  868 Score:  0.88671875  Average score: -38.92 Best average: -36.88 Epsilon: 0.76 Steps: 23763
# Episode:  869 Score:  -86.63243103027344  Average score: -39.21 Best average: -36.88 Epsilon: 0.76 Steps: 23774
# Episode:  870 Score:  -92.45254516601562  Average score: -39.03 Best average: -36.88 Epsilon: 0.76 Steps: 23786
# Episode:  871 Score:  60.68733215332031  Average score: -37.65 Best average: -36.88 Epsilon: 0.76 Steps: 23820
# Episode:  872 Score:  -81.35171508789062  Average score: -37.41 Best average: -36.88 Epsilon: 0.76 Steps: 23832
# Episode:  873 Score:  -106.40452575683594  Average score: -37.98 Best average: -36.88 Epsilon: 0.76 Steps: 23851
# Episode:  874 Score:  -82.81442260742188  Average score: -38.36 Best average: -36.88 Epsilon: 0.76 Steps: 23879
# Episode:  875 Score:  -115.870849609375  Average score: -38.50 Best average: -36.88 Epsilon: 0.76 Steps: 23890
# Episode:  876 Score:  -71.48719787597656  Average score: -38.06 Best average: -36.88 Epsilon: 0.76 Steps: 23909
# Episode:  877 Score:  17.5023193359375  Average score: -38.23 Best average: -36.88 Epsilon: 0.76 Steps: 23930
# Episode:  878 Score:  -26.234542846679688  Average score: -37.33 Best average: -36.88 Epsilon: 0.76 Steps: 23951
# Checkpoint saved at episode  879
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  879 Score:  -25.732421875  Average score: -36.57 Best average: -36.57 Epsilon: 0.76 Steps: 23962
# Checkpoint saved at episode  880
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  880 Score:  -3.2662353515625  Average score: -35.79 Best average: -35.79 Epsilon: 0.76 Steps: 23974
# Episode:  881 Score:  -47.97486877441406  Average score: -37.01 Best average: -35.79 Epsilon: 0.76 Steps: 23986
# Episode:  882 Score:  -39.284027099609375  Average score: -36.97 Best average: -35.79 Epsilon: 0.76 Steps: 23997
# Episode:  883 Score:  -57.27644348144531  Average score: -36.97 Best average: -35.79 Epsilon: 0.76 Steps: 24018
# Episode:  884 Score:  -70.03765869140625  Average score: -37.35 Best average: -35.79 Epsilon: 0.76 Steps: 24031
# Episode:  885 Score:  28.767425537109375  Average score: -39.05 Best average: -35.79 Epsilon: 0.76 Steps: 24043
# Episode:  886 Score:  -67.64134216308594  Average score: -38.86 Best average: -35.79 Epsilon: 0.76 Steps: 24064
# Episode:  887 Score:  -69.01292419433594  Average score: -38.84 Best average: -35.79 Epsilon: 0.76 Steps: 24084
# Episode:  888 Score:  -65.49058532714844  Average score: -39.47 Best average: -35.79 Epsilon: 0.76 Steps: 24096
# Episode:  889 Score:  -50.015106201171875  Average score: -39.74 Best average: -35.79 Epsilon: 0.76 Steps: 24114
# Episode:  890 Score:  -26.630889892578125  Average score: -39.64 Best average: -35.79 Epsilon: 0.76 Steps: 24126
# Episode:  891 Score:  -9.43878173828125  Average score: -39.79 Best average: -35.79 Epsilon: 0.76 Steps: 24153
# Episode:  892 Score:  17.709487915039062  Average score: -38.99 Best average: -35.79 Epsilon: 0.76 Steps: 24172
# Episode:  893 Score:  -108.94926452636719  Average score: -38.92 Best average: -35.79 Epsilon: 0.76 Steps: 24194
# Episode:  894 Score:  19.728561401367188  Average score: -37.67 Best average: -35.79 Epsilon: 0.76 Steps: 24237
# Episode:  895 Score:  -94.57171630859375  Average score: -37.89 Best average: -35.79 Epsilon: 0.76 Steps: 24248
# Episode:  896 Score:  24.939605712890625  Average score: -36.53 Best average: -35.79 Epsilon: 0.76 Steps: 24296
# Checkpoint saved at episode  897
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  897 Score:  96.36492919921875  Average score: -35.14 Best average: -35.14 Epsilon: 0.76 Steps: 24316
# Checkpoint saved at episode  898
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  898 Score:  85.42021179199219  Average score: -33.93 Best average: -33.93 Epsilon: 0.76 Steps: 24343
# Episode:  899 Score:  -104.03129577636719  Average score: -34.39 Best average: -33.93 Epsilon: 0.76 Steps: 24364
# Checkpoint saved at episode  900
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  900 Score:  9.674911499023438  Average score: -33.34 Best average: -33.34 Epsilon: 0.76 Steps: 24392
# Checkpoint saved at episode  901
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  901 Score:  -16.561141967773438  Average score: -33.02 Best average: -33.02 Epsilon: 0.76 Steps: 24404
# Checkpoint saved at episode  902
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  902 Score:  -4.82257080078125  Average score: -32.70 Best average: -32.70 Epsilon: 0.76 Steps: 24416
# Episode:  903 Score:  -18.199539184570312  Average score: -32.80 Best average: -32.70 Epsilon: 0.76 Steps: 24438
# Checkpoint saved at episode  904
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  904 Score:  -18.821762084960938  Average score: -32.18 Best average: -32.18 Epsilon: 0.76 Steps: 24467
# Checkpoint saved at episode  905
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  905 Score:  -26.805282592773438  Average score: -31.87 Best average: -31.87 Epsilon: 0.76 Steps: 24489
# Episode:  906 Score:  -112.07478332519531  Average score: -31.97 Best average: -31.87 Epsilon: 0.76 Steps: 24501
# Episode:  907 Score:  -76.47785949707031  Average score: -32.57 Best average: -31.87 Epsilon: 0.76 Steps: 24523
# Episode:  908 Score:  -109.205322265625  Average score: -33.65 Best average: -31.87 Epsilon: 0.75 Steps: 24544
# Episode:  909 Score:  -19.272613525390625  Average score: -32.76 Best average: -31.87 Epsilon: 0.75 Steps: 24572
# Episode:  910 Score:  -77.3946533203125  Average score: -32.89 Best average: -31.87 Epsilon: 0.75 Steps: 24591
# Episode:  911 Score:  -9.099395751953125  Average score: -32.33 Best average: -31.87 Epsilon: 0.75 Steps: 24613
# Episode:  912 Score:  -29.054306030273438  Average score: -32.43 Best average: -31.87 Epsilon: 0.75 Steps: 24633
# Checkpoint saved at episode  913
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  913 Score:  -9.592758178710938  Average score: -31.77 Best average: -31.77 Epsilon: 0.75 Steps: 24670
# Episode:  914 Score:  -114.9913330078125  Average score: -32.37 Best average: -31.77 Epsilon: 0.75 Steps: 24691
# Episode:  915 Score:  -87.49479675292969  Average score: -33.85 Best average: -31.77 Epsilon: 0.75 Steps: 24702
# Episode:  916 Score:  -89.63528442382812  Average score: -35.62 Best average: -31.77 Epsilon: 0.75 Steps: 24713
# Episode:  917 Score:  -27.374496459960938  Average score: -35.72 Best average: -31.77 Epsilon: 0.75 Steps: 24726
# Episode:  918 Score:  28.762359619140625  Average score: -34.36 Best average: -31.77 Epsilon: 0.75 Steps: 24745
# Episode:  919 Score:  -57.43865966796875  Average score: -35.27 Best average: -31.77 Epsilon: 0.75 Steps: 24773
# Episode:  920 Score:  -18.674026489257812  Average score: -36.34 Best average: -31.77 Epsilon: 0.75 Steps: 24791
# Episode:  921 Score:  -54.70613098144531  Average score: -36.67 Best average: -31.77 Epsilon: 0.75 Steps: 24816
# Episode:  922 Score:  -60.651611328125  Average score: -36.97 Best average: -31.77 Epsilon: 0.75 Steps: 24827
# Episode:  923 Score:  -112.3719482421875  Average score: -38.29 Best average: -31.77 Epsilon: 0.75 Steps: 24857
# Episode:  924 Score:  -3.2227783203125  Average score: -38.17 Best average: -31.77 Epsilon: 0.75 Steps: 24875
# Episode:  925 Score:  -32.340667724609375  Average score: -38.57 Best average: -31.77 Epsilon: 0.75 Steps: 24894
# Episode:  926 Score:  -64.19761657714844  Average score: -38.30 Best average: -31.77 Epsilon: 0.75 Steps: 24923
# Episode:  927 Score:  -4.338287353515625  Average score: -37.70 Best average: -31.77 Epsilon: 0.75 Steps: 24941
# Episode:  928 Score:  54.47181701660156  Average score: -36.27 Best average: -31.77 Epsilon: 0.75 Steps: 24960
# Episode:  929 Score:  -20.169815063476562  Average score: -35.34 Best average: -31.77 Epsilon: 0.75 Steps: 24972
# Episode:  930 Score:  -107.89787292480469  Average score: -35.53 Best average: -31.77 Epsilon: 0.75 Steps: 24985
# Episode:  931 Score:  -9.230880737304688  Average score: -35.15 Best average: -31.77 Epsilon: 0.75 Steps: 24998
# Episode:  932 Score:  -17.447189331054688  Average score: -35.50 Best average: -31.77 Epsilon: 0.75 Steps: 25010
# Episode:  933 Score:  -109.89253234863281  Average score: -36.66 Best average: -31.77 Epsilon: 0.75 Steps: 25022
# Episode:  934 Score:  -30.614456176757812  Average score: -36.77 Best average: -31.77 Epsilon: 0.75 Steps: 25043
# Episode:  935 Score:  11.248046875  Average score: -36.91 Best average: -31.77 Epsilon: 0.75 Steps: 25055
# Episode:  936 Score:  95.37237548828125  Average score: -35.73 Best average: -31.77 Epsilon: 0.75 Steps: 25103
# Episode:  937 Score:  -115.99226379394531  Average score: -36.41 Best average: -31.77 Epsilon: 0.75 Steps: 25114
# Episode:  938 Score:  -44.71063232421875  Average score: -36.24 Best average: -31.77 Epsilon: 0.75 Steps: 25135
# Episode:  939 Score:  -66.11210632324219  Average score: -36.45 Best average: -31.77 Epsilon: 0.75 Steps: 25155
# Episode:  940 Score:  28.74298095703125  Average score: -36.66 Best average: -31.77 Epsilon: 0.75 Steps: 25175
# Episode:  941 Score:  7.5374298095703125  Average score: -36.18 Best average: -31.77 Epsilon: 0.75 Steps: 25194
# Episode:  942 Score:  -105.96092224121094  Average score: -37.08 Best average: -31.77 Epsilon: 0.75 Steps: 25207
# Episode:  943 Score:  -33.05242919921875  Average score: -37.35 Best average: -31.77 Epsilon: 0.75 Steps: 25236
# Episode:  944 Score:  6.279937744140625  Average score: -37.21 Best average: -31.77 Epsilon: 0.75 Steps: 25249
# Episode:  945 Score:  -14.884078979492188  Average score: -37.93 Best average: -31.77 Epsilon: 0.75 Steps: 25270
# Episode:  946 Score:  -34.62184143066406  Average score: -37.39 Best average: -31.77 Epsilon: 0.75 Steps: 25290
# Episode:  947 Score:  -84.77091979980469  Average score: -38.10 Best average: -31.77 Epsilon: 0.75 Steps: 25323
# Episode:  948 Score:  -91.94197082519531  Average score: -38.29 Best average: -31.77 Epsilon: 0.75 Steps: 25356
# Episode:  949 Score:  -1.1082000732421875  Average score: -38.02 Best average: -31.77 Epsilon: 0.75 Steps: 25378
# Episode:  950 Score:  -35.21473693847656  Average score: -37.91 Best average: -31.77 Epsilon: 0.75 Steps: 25390
# Episode:  951 Score:  -61.75654602050781  Average score: -37.52 Best average: -31.77 Epsilon: 0.75 Steps: 25401
# Episode:  952 Score:  -7.470245361328125  Average score: -36.87 Best average: -31.77 Epsilon: 0.75 Steps: 25414
# Episode:  953 Score:  -100.06661987304688  Average score: -37.94 Best average: -31.77 Epsilon: 0.75 Steps: 25434
# Episode:  954 Score:  -50.78724670410156  Average score: -38.36 Best average: -31.77 Epsilon: 0.75 Steps: 25463
# Episode:  955 Score:  -32.26878356933594  Average score: -39.90 Best average: -31.77 Epsilon: 0.75 Steps: 25483
# Episode:  956 Score:  -115.33212280273438  Average score: -40.27 Best average: -31.77 Epsilon: 0.75 Steps: 25513
# Episode:  957 Score:  -56.24067687988281  Average score: -40.72 Best average: -31.77 Epsilon: 0.75 Steps: 25526
# Episode:  958 Score:  1.732513427734375  Average score: -40.05 Best average: -31.77 Epsilon: 0.74 Steps: 25553
# Episode:  959 Score:  -11.932327270507812  Average score: -40.23 Best average: -31.77 Epsilon: 0.74 Steps: 25573
# Episode:  960 Score:  -24.988433837890625  Average score: -39.82 Best average: -31.77 Epsilon: 0.74 Steps: 25593
# Episode:  961 Score:  -67.11671447753906  Average score: -40.23 Best average: -31.77 Epsilon: 0.74 Steps: 25614
# Episode:  962 Score:  -102.58363342285156  Average score: -40.47 Best average: -31.77 Epsilon: 0.74 Steps: 25632
# Episode:  963 Score:  -82.8248291015625  Average score: -40.14 Best average: -31.77 Epsilon: 0.74 Steps: 25670
# Episode:  964 Score:  -103.37037658691406  Average score: -40.34 Best average: -31.77 Epsilon: 0.74 Steps: 25690
# Episode:  965 Score:  45.62779235839844  Average score: -39.29 Best average: -31.77 Epsilon: 0.74 Steps: 25728
# Episode:  966 Score:  -45.576324462890625  Average score: -39.30 Best average: -31.77 Epsilon: 0.74 Steps: 25748
# Episode:  967 Score:  -84.89022827148438  Average score: -39.87 Best average: -31.77 Epsilon: 0.74 Steps: 25774
# Episode:  968 Score:  -43.27391052246094  Average score: -40.31 Best average: -31.77 Epsilon: 0.74 Steps: 25794
# Episode:  969 Score:  -115.94548034667969  Average score: -40.60 Best average: -31.77 Epsilon: 0.74 Steps: 25806
# Episode:  970 Score:  -108.07771301269531  Average score: -40.76 Best average: -31.77 Epsilon: 0.74 Steps: 25818
# Episode:  971 Score:  -31.874481201171875  Average score: -41.68 Best average: -31.77 Epsilon: 0.74 Steps: 25846
# Episode:  972 Score:  -85.68135070800781  Average score: -41.73 Best average: -31.77 Epsilon: 0.74 Steps: 25875
# Episode:  973 Score:  156.89633178710938  Average score: -39.09 Best average: -31.77 Epsilon: 0.74 Steps: 25927
# Episode:  974 Score:  -48.83244323730469  Average score: -38.76 Best average: -31.77 Epsilon: 0.74 Steps: 25962
# Episode:  975 Score:  6.317779541015625  Average score: -37.53 Best average: -31.77 Epsilon: 0.74 Steps: 25982
# Episode:  976 Score:  -97.865966796875  Average score: -37.80 Best average: -31.77 Epsilon: 0.74 Steps: 25995
# Episode:  977 Score:  -89.36305236816406  Average score: -38.87 Best average: -31.77 Epsilon: 0.74 Steps: 26006
# Episode:  978 Score:  -45.16554260253906  Average score: -39.05 Best average: -31.77 Epsilon: 0.74 Steps: 26039
# Episode:  979 Score:  3.59234619140625  Average score: -38.76 Best average: -31.77 Epsilon: 0.74 Steps: 26051
# Episode:  980 Score:  -6.1578369140625  Average score: -38.79 Best average: -31.77 Epsilon: 0.74 Steps: 26085
# Episode:  981 Score:  -37.75514221191406  Average score: -38.69 Best average: -31.77 Epsilon: 0.74 Steps: 26105
# Episode:  982 Score:  -63.57756042480469  Average score: -38.93 Best average: -31.77 Epsilon: 0.74 Steps: 26118
# Episode:  983 Score:  82.21600341796875  Average score: -37.54 Best average: -31.77 Epsilon: 0.74 Steps: 26182
# Episode:  984 Score:  -12.220458984375  Average score: -36.96 Best average: -31.77 Epsilon: 0.74 Steps: 26195
# Episode:  985 Score:  -53.06208801269531  Average score: -37.78 Best average: -31.77 Epsilon: 0.74 Steps: 26216
# Episode:  986 Score:  -38.452606201171875  Average score: -37.48 Best average: -31.77 Epsilon: 0.74 Steps: 26229
# Episode:  987 Score:  2.9089202880859375  Average score: -36.77 Best average: -31.77 Epsilon: 0.74 Steps: 26242
# Episode:  988 Score:  -44.72914123535156  Average score: -36.56 Best average: -31.77 Epsilon: 0.74 Steps: 26270
# Episode:  989 Score:  -88.95329284667969  Average score: -36.95 Best average: -31.77 Epsilon: 0.74 Steps: 26283
# Episode:  990 Score:  -33.72102355957031  Average score: -37.02 Best average: -31.77 Epsilon: 0.74 Steps: 26320
# Episode:  991 Score:  62.09101867675781  Average score: -36.30 Best average: -31.77 Epsilon: 0.74 Steps: 26340
# Episode:  992 Score:  -48.03765869140625  Average score: -36.96 Best average: -31.77 Epsilon: 0.74 Steps: 26358
# Episode:  993 Score:  -38.11125183105469  Average score: -36.25 Best average: -31.77 Epsilon: 0.74 Steps: 26378
# Episode:  994 Score:  -24.913009643554688  Average score: -36.70 Best average: -31.77 Epsilon: 0.74 Steps: 26399
# Episode:  995 Score:  11.441680908203125  Average score: -35.64 Best average: -31.77 Epsilon: 0.74 Steps: 26411
# Episode:  996 Score:  -22.389175415039062  Average score: -36.11 Best average: -31.77 Epsilon: 0.74 Steps: 26432
# Episode:  997 Score:  245.3866729736328  Average score: -34.62 Best average: -31.77 Epsilon: 0.74 Steps: 26481
# Episode:  998 Score:  -19.642898559570312  Average score: -35.67 Best average: -31.77 Epsilon: 0.74 Steps: 26503
# Episode:  999 Score:  -69.66336059570312  Average score: -35.33 Best average: -31.77 Epsilon: 0.74 Steps: 26516
# Episode:  1000 Score:  -0.951904296875  Average score: -35.43 Best average: -31.77 Epsilon: 0.73 Steps: 26544
# Episode:  1001 Score:  130.01217651367188  Average score: -33.97 Best average: -31.77 Epsilon: 0.73 Steps: 26570
# Episode:  1002 Score:  -55.617156982421875  Average score: -34.48 Best average: -31.77 Epsilon: 0.73 Steps: 26583
# Episode:  1003 Score:  -48.53904724121094  Average score: -34.78 Best average: -31.77 Epsilon: 0.73 Steps: 26596
# Episode:  1004 Score:  163.33909606933594  Average score: -32.96 Best average: -31.77 Epsilon: 0.73 Steps: 26632
# Episode:  1005 Score:  -63.759796142578125  Average score: -33.33 Best average: -31.77 Epsilon: 0.73 Steps: 26661
# Episode:  1006 Score:  -58.533843994140625  Average score: -32.79 Best average: -31.77 Epsilon: 0.73 Steps: 26673
# Episode:  1007 Score:  -55.971923828125  Average score: -32.59 Best average: -31.77 Epsilon: 0.73 Steps: 26701
# Episode:  1008 Score:  -32.83203125  Average score: -31.82 Best average: -31.77 Epsilon: 0.73 Steps: 26729
# Episode:  1009 Score:  -26.9298095703125  Average score: -31.90 Best average: -31.77 Epsilon: 0.73 Steps: 26748
# Episode:  1010 Score:  -111.95771789550781  Average score: -32.25 Best average: -31.77 Epsilon: 0.73 Steps: 26759
# Episode:  1011 Score:  -0.817901611328125  Average score: -32.16 Best average: -31.77 Epsilon: 0.73 Steps: 26772
# Checkpoint saved at episode  1012
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1012 Score:  57.481842041015625  Average score: -31.30 Best average: -31.30 Epsilon: 0.73 Steps: 26790
# Episode:  1013 Score:  -88.49391174316406  Average score: -32.09 Best average: -31.30 Epsilon: 0.73 Steps: 26819
# Episode:  1014 Score:  -70.72340393066406  Average score: -31.64 Best average: -31.30 Epsilon: 0.73 Steps: 26841
# Episode:  1015 Score:  -79.6072998046875  Average score: -31.57 Best average: -31.30 Epsilon: 0.73 Steps: 26852
# Episode:  1016 Score:  -105.77426147460938  Average score: -31.73 Best average: -31.30 Epsilon: 0.73 Steps: 26872
# Episode:  1017 Score:  -26.78594970703125  Average score: -31.72 Best average: -31.30 Epsilon: 0.73 Steps: 26885
# Episode:  1018 Score:  -58.73310852050781  Average score: -32.60 Best average: -31.30 Epsilon: 0.73 Steps: 26904
# Episode:  1019 Score:  -31.756118774414062  Average score: -32.34 Best average: -31.30 Epsilon: 0.73 Steps: 26916
# Episode:  1020 Score:  -106.68572998046875  Average score: -33.22 Best average: -31.30 Epsilon: 0.73 Steps: 26934
# Episode:  1021 Score:  -38.91398620605469  Average score: -33.06 Best average: -31.30 Epsilon: 0.73 Steps: 26954
# Episode:  1022 Score:  -43.22869873046875  Average score: -32.89 Best average: -31.30 Epsilon: 0.73 Steps: 26974
# Episode:  1023 Score:  -44.99485778808594  Average score: -32.21 Best average: -31.30 Epsilon: 0.73 Steps: 26985
# Episode:  1024 Score:  -87.03973388671875  Average score: -33.05 Best average: -31.30 Epsilon: 0.73 Steps: 27004
# Episode:  1025 Score:  9.325759887695312  Average score: -32.63 Best average: -31.30 Epsilon: 0.73 Steps: 27031
# Episode:  1026 Score:  37.62565612792969  Average score: -31.62 Best average: -31.30 Epsilon: 0.73 Steps: 27051
# Episode:  1027 Score:  -72.45497131347656  Average score: -32.30 Best average: -31.30 Epsilon: 0.73 Steps: 27073
# Episode:  1028 Score:  -42.07945251464844  Average score: -33.26 Best average: -31.30 Epsilon: 0.73 Steps: 27093
# Episode:  1029 Score:  -81.97340393066406  Average score: -33.88 Best average: -31.30 Epsilon: 0.73 Steps: 27106
# Episode:  1030 Score:  -47.324737548828125  Average score: -33.28 Best average: -31.30 Epsilon: 0.73 Steps: 27117
# Episode:  1031 Score:  53.68428039550781  Average score: -32.65 Best average: -31.30 Epsilon: 0.73 Steps: 27142
# Episode:  1032 Score:  -56.308441162109375  Average score: -33.03 Best average: -31.30 Epsilon: 0.73 Steps: 27162
# Episode:  1033 Score:  -6.903533935546875  Average score: -32.00 Best average: -31.30 Epsilon: 0.73 Steps: 27174
# Episode:  1034 Score:  -59.86199951171875  Average score: -32.30 Best average: -31.30 Epsilon: 0.73 Steps: 27196
# Episode:  1035 Score:  -20.594375610351562  Average score: -32.62 Best average: -31.30 Epsilon: 0.73 Steps: 27216
# Episode:  1036 Score:  181.1649932861328  Average score: -31.76 Best average: -31.30 Epsilon: 0.73 Steps: 27236
# Episode:  1037 Score:  -75.64633178710938  Average score: -31.35 Best average: -31.30 Epsilon: 0.73 Steps: 27264
# Checkpoint saved at episode  1038
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1038 Score:  -36.90556335449219  Average score: -31.28 Best average: -31.28 Epsilon: 0.73 Steps: 27285
# Checkpoint saved at episode  1039
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1039 Score:  -8.951644897460938  Average score: -30.70 Best average: -30.70 Epsilon: 0.73 Steps: 27306
# Episode:  1040 Score:  -96.65748596191406  Average score: -31.96 Best average: -30.70 Epsilon: 0.73 Steps: 27336
# Episode:  1041 Score:  -58.22552490234375  Average score: -32.62 Best average: -30.70 Epsilon: 0.73 Steps: 27348
# Episode:  1042 Score:  -4.4728851318359375  Average score: -31.60 Best average: -30.70 Epsilon: 0.73 Steps: 27376
# Episode:  1043 Score:  -73.35296630859375  Average score: -32.00 Best average: -30.70 Epsilon: 0.73 Steps: 27398
# Episode:  1044 Score:  -11.750335693359375  Average score: -32.18 Best average: -30.70 Epsilon: 0.73 Steps: 27418
# Episode:  1045 Score:  117.50038146972656  Average score: -30.86 Best average: -30.70 Epsilon: 0.73 Steps: 27467
# Checkpoint saved at episode  1046
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1046 Score:  41.26329040527344  Average score: -30.10 Best average: -30.10 Epsilon: 0.73 Steps: 27531
# Episode:  1047 Score:  -94.50340270996094  Average score: -30.20 Best average: -30.10 Epsilon: 0.72 Steps: 27560
# Checkpoint saved at episode  1048
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1048 Score:  -67.83784484863281  Average score: -29.96 Best average: -29.96 Epsilon: 0.72 Steps: 27573
# Episode:  1049 Score:  -52.290863037109375  Average score: -30.47 Best average: -29.96 Epsilon: 0.72 Steps: 27594
# Episode:  1050 Score:  7.6139678955078125  Average score: -30.04 Best average: -29.96 Epsilon: 0.72 Steps: 27605
# Checkpoint saved at episode  1051
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1051 Score:  21.432174682617188  Average score: -29.21 Best average: -29.21 Epsilon: 0.72 Steps: 27625
# Checkpoint saved at episode  1052
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1052 Score:  131.7648162841797  Average score: -27.82 Best average: -27.82 Epsilon: 0.72 Steps: 27647
# Checkpoint saved at episode  1053
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1053 Score:  -87.58833312988281  Average score: -27.69 Best average: -27.69 Epsilon: 0.72 Steps: 27659
# Episode:  1054 Score:  -98.66171264648438  Average score: -28.17 Best average: -27.69 Epsilon: 0.72 Steps: 27685
# Episode:  1055 Score:  10.302566528320312  Average score: -27.75 Best average: -27.69 Epsilon: 0.72 Steps: 27707
# Checkpoint saved at episode  1056
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1056 Score:  -33.761444091796875  Average score: -26.93 Best average: -26.93 Epsilon: 0.72 Steps: 27743
# Checkpoint saved at episode  1057
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1057 Score:  -44.69401550292969  Average score: -26.81 Best average: -26.81 Epsilon: 0.72 Steps: 27764
# Episode:  1058 Score:  -18.276824951171875  Average score: -27.01 Best average: -26.81 Epsilon: 0.72 Steps: 27783
# Episode:  1059 Score:  -84.66789245605469  Average score: -27.74 Best average: -26.81 Epsilon: 0.72 Steps: 27804
# Episode:  1060 Score:  -52.00932312011719  Average score: -28.01 Best average: -26.81 Epsilon: 0.72 Steps: 27815
# Episode:  1061 Score:  19.324844360351562  Average score: -27.15 Best average: -26.81 Epsilon: 0.72 Steps: 27841
# Episode:  1062 Score:  -81.28999328613281  Average score: -26.94 Best average: -26.81 Epsilon: 0.72 Steps: 27854
# Checkpoint saved at episode  1063
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1063 Score:  -25.185256958007812  Average score: -26.36 Best average: -26.36 Epsilon: 0.72 Steps: 27867
# Checkpoint saved at episode  1064
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1064 Score:  52.13517761230469  Average score: -24.80 Best average: -24.80 Epsilon: 0.72 Steps: 27909
# Episode:  1065 Score:  -21.289047241210938  Average score: -25.47 Best average: -24.80 Epsilon: 0.72 Steps: 27921
# Episode:  1066 Score:  9.64068603515625  Average score: -24.92 Best average: -24.80 Epsilon: 0.72 Steps: 27970
# Episode:  1067 Score:  -115.68116760253906  Average score: -25.23 Best average: -24.80 Epsilon: 0.72 Steps: 27990
# Episode:  1068 Score:  -96.42170715332031  Average score: -25.76 Best average: -24.80 Epsilon: 0.72 Steps: 28018
# Checkpoint saved at episode  1069
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1069 Score:  20.898101806640625  Average score: -24.39 Best average: -24.39 Epsilon: 0.72 Steps: 28059
# Checkpoint saved at episode  1070
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1070 Score:  -106.74758911132812  Average score: -24.38 Best average: -24.38 Epsilon: 0.72 Steps: 28080
# Episode:  1071 Score:  -36.15019226074219  Average score: -24.42 Best average: -24.38 Epsilon: 0.72 Steps: 28100
# Checkpoint saved at episode  1072
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1072 Score:  102.58291625976562  Average score: -22.54 Best average: -22.54 Epsilon: 0.72 Steps: 28120
# Episode:  1073 Score:  -8.415023803710938  Average score: -24.19 Best average: -22.54 Epsilon: 0.72 Steps: 28147
# Episode:  1074 Score:  -107.45510864257812  Average score: -24.78 Best average: -22.54 Epsilon: 0.72 Steps: 28167
# Episode:  1075 Score:  -13.303024291992188  Average score: -24.97 Best average: -22.54 Epsilon: 0.72 Steps: 28195
# Episode:  1076 Score:  -63.75617980957031  Average score: -24.63 Best average: -22.54 Epsilon: 0.72 Steps: 28217
# Episode:  1077 Score:  -70.91558837890625  Average score: -24.45 Best average: -22.54 Epsilon: 0.72 Steps: 28244
# Episode:  1078 Score:  -16.05712890625  Average score: -24.16 Best average: -22.54 Epsilon: 0.72 Steps: 28257
# Episode:  1079 Score:  -26.606292724609375  Average score: -24.46 Best average: -22.54 Epsilon: 0.72 Steps: 28284
# Episode:  1080 Score:  -56.94856262207031  Average score: -24.97 Best average: -22.54 Epsilon: 0.72 Steps: 28305
# Episode:  1081 Score:  -13.335052490234375  Average score: -24.72 Best average: -22.54 Epsilon: 0.72 Steps: 28325
# Episode:  1082 Score:  91.25099182128906  Average score: -23.17 Best average: -22.54 Epsilon: 0.72 Steps: 28353
# Episode:  1083 Score:  -83.732177734375  Average score: -24.83 Best average: -22.54 Epsilon: 0.72 Steps: 28372
# Episode:  1084 Score:  -23.361495971679688  Average score: -24.95 Best average: -22.54 Epsilon: 0.72 Steps: 28384
# Episode:  1085 Score:  -74.7872314453125  Average score: -25.16 Best average: -22.54 Epsilon: 0.72 Steps: 28404
# Episode:  1086 Score:  -91.84843444824219  Average score: -25.70 Best average: -22.54 Epsilon: 0.72 Steps: 28417
# Episode:  1087 Score:  -64.49919128417969  Average score: -26.37 Best average: -22.54 Epsilon: 0.72 Steps: 28429
# Episode:  1088 Score:  -54.63813781738281  Average score: -26.47 Best average: -22.54 Epsilon: 0.72 Steps: 28447
# Episode:  1089 Score:  51.69818115234375  Average score: -25.06 Best average: -22.54 Epsilon: 0.72 Steps: 28476
# Episode:  1090 Score:  -57.22718811035156  Average score: -25.30 Best average: -22.54 Epsilon: 0.72 Steps: 28496
# Episode:  1091 Score:  -23.73809814453125  Average score: -26.16 Best average: -22.54 Epsilon: 0.72 Steps: 28516
# Episode:  1092 Score:  -32.3143310546875  Average score: -26.00 Best average: -22.54 Epsilon: 0.71 Steps: 28537
# Episode:  1093 Score:  -97.98152160644531  Average score: -26.60 Best average: -22.54 Epsilon: 0.71 Steps: 28556
# Episode:  1094 Score:  -14.371780395507812  Average score: -26.49 Best average: -22.54 Epsilon: 0.71 Steps: 28575
# Episode:  1095 Score:  -94.86595153808594  Average score: -27.56 Best average: -22.54 Epsilon: 0.71 Steps: 28588
# Episode:  1096 Score:  -34.56269836425781  Average score: -27.68 Best average: -22.54 Epsilon: 0.71 Steps: 28609
# Episode:  1097 Score:  -13.149444580078125  Average score: -30.26 Best average: -22.54 Epsilon: 0.71 Steps: 28628
# Episode:  1098 Score:  -95.67774963378906  Average score: -31.02 Best average: -22.54 Epsilon: 0.71 Steps: 28640
# Episode:  1099 Score:  -89.56594848632812  Average score: -31.22 Best average: -22.54 Epsilon: 0.71 Steps: 28652
# Episode:  1100 Score:  -83.569091796875  Average score: -32.05 Best average: -22.54 Epsilon: 0.71 Steps: 28664
# Episode:  1101 Score:  -22.295639038085938  Average score: -33.57 Best average: -22.54 Epsilon: 0.71 Steps: 28677
# Episode:  1102 Score:  -40.22520446777344  Average score: -33.42 Best average: -22.54 Epsilon: 0.71 Steps: 28705
# Episode:  1103 Score:  -107.45797729492188  Average score: -34.01 Best average: -22.54 Epsilon: 0.71 Steps: 28717
# Episode:  1104 Score:  -106.58952331542969  Average score: -36.71 Best average: -22.54 Epsilon: 0.71 Steps: 28737
# Episode:  1105 Score:  101.74716186523438  Average score: -35.05 Best average: -22.54 Epsilon: 0.71 Steps: 28767
# Episode:  1106 Score:  -52.91795349121094  Average score: -34.99 Best average: -22.54 Epsilon: 0.71 Steps: 28778
# Episode:  1107 Score:  -51.26652526855469  Average score: -34.95 Best average: -22.54 Epsilon: 0.71 Steps: 28799
# Episode:  1108 Score:  -29.51556396484375  Average score: -34.91 Best average: -22.54 Epsilon: 0.71 Steps: 28819
# Episode:  1109 Score:  -34.94407653808594  Average score: -34.99 Best average: -22.54 Epsilon: 0.71 Steps: 28831
# Episode:  1110 Score:  -83.9659423828125  Average score: -34.71 Best average: -22.54 Epsilon: 0.71 Steps: 28851
# Episode:  1111 Score:  -36.58235168457031  Average score: -35.07 Best average: -22.54 Epsilon: 0.71 Steps: 28872
# Episode:  1112 Score:  -34.14360046386719  Average score: -35.99 Best average: -22.54 Epsilon: 0.71 Steps: 28885
# Episode:  1113 Score:  -67.73258972167969  Average score: -35.78 Best average: -22.54 Epsilon: 0.71 Steps: 28898
# Episode:  1114 Score:  -29.46923828125  Average score: -35.37 Best average: -22.54 Epsilon: 0.71 Steps: 28911
# Episode:  1115 Score:  15.488571166992188  Average score: -34.42 Best average: -22.54 Epsilon: 0.71 Steps: 28939
# Episode:  1116 Score:  -17.662200927734375  Average score: -33.54 Best average: -22.54 Epsilon: 0.71 Steps: 28975
# Episode:  1117 Score:  -105.25656127929688  Average score: -34.32 Best average: -22.54 Epsilon: 0.71 Steps: 29005
# Episode:  1118 Score:  -108.77999877929688  Average score: -34.82 Best average: -22.54 Epsilon: 0.71 Steps: 29018
# Episode:  1119 Score:  65.66526794433594  Average score: -33.85 Best average: -22.54 Epsilon: 0.71 Steps: 29036
# Episode:  1120 Score:  -105.30313110351562  Average score: -33.83 Best average: -22.54 Epsilon: 0.71 Steps: 29049
# Episode:  1121 Score:  -115.99713134765625  Average score: -34.60 Best average: -22.54 Epsilon: 0.71 Steps: 29061
# Episode:  1122 Score:  -38.092681884765625  Average score: -34.55 Best average: -22.54 Epsilon: 0.71 Steps: 29082
# Episode:  1123 Score:  -101.92770385742188  Average score: -35.12 Best average: -22.54 Epsilon: 0.71 Steps: 29095
# Episode:  1124 Score:  -28.147308349609375  Average score: -34.53 Best average: -22.54 Epsilon: 0.71 Steps: 29129
# Episode:  1125 Score:  -83.52810668945312  Average score: -35.46 Best average: -22.54 Epsilon: 0.71 Steps: 29141
# Episode:  1126 Score:  -33.66624450683594  Average score: -36.18 Best average: -22.54 Epsilon: 0.71 Steps: 29152
# Episode:  1127 Score:  36.4903564453125  Average score: -35.09 Best average: -22.54 Epsilon: 0.71 Steps: 29165
# Episode:  1128 Score:  -64.9451904296875  Average score: -35.31 Best average: -22.54 Epsilon: 0.71 Steps: 29191
# Episode:  1129 Score:  -102.45030212402344  Average score: -35.52 Best average: -22.54 Epsilon: 0.71 Steps: 29219
# Episode:  1130 Score:  -17.33349609375  Average score: -35.22 Best average: -22.54 Epsilon: 0.71 Steps: 29232
# Episode:  1131 Score:  -62.42071533203125  Average score: -36.38 Best average: -22.54 Epsilon: 0.71 Steps: 29245
# Episode:  1132 Score:  -77.799560546875  Average score: -36.60 Best average: -22.54 Epsilon: 0.71 Steps: 29266
# Episode:  1133 Score:  -115.98707580566406  Average score: -37.69 Best average: -22.54 Epsilon: 0.71 Steps: 29287
# Episode:  1134 Score:  -100.75093078613281  Average score: -38.09 Best average: -22.54 Epsilon: 0.71 Steps: 29307
# Episode:  1135 Score:  -31.4788818359375  Average score: -38.20 Best average: -22.54 Epsilon: 0.71 Steps: 29326
# Episode:  1136 Score:  -3.52117919921875  Average score: -40.05 Best average: -22.54 Epsilon: 0.71 Steps: 29344
# Episode:  1137 Score:  -51.838897705078125  Average score: -39.81 Best average: -22.54 Epsilon: 0.71 Steps: 29374
# Episode:  1138 Score:  56.157684326171875  Average score: -38.88 Best average: -22.54 Epsilon: 0.71 Steps: 29394
# Episode:  1139 Score:  -22.945480346679688  Average score: -39.02 Best average: -22.54 Epsilon: 0.71 Steps: 29407
# Episode:  1140 Score:  -35.88981628417969  Average score: -38.41 Best average: -22.54 Epsilon: 0.71 Steps: 29428
# Episode:  1141 Score:  -49.60894775390625  Average score: -38.33 Best average: -22.54 Epsilon: 0.71 Steps: 29447
# Episode:  1142 Score:  -41.77783203125  Average score: -38.70 Best average: -22.54 Epsilon: 0.71 Steps: 29458
# Episode:  1143 Score:  -19.60113525390625  Average score: -38.16 Best average: -22.54 Epsilon: 0.71 Steps: 29486
# Episode:  1144 Score:  -13.83502197265625  Average score: -38.18 Best average: -22.54 Epsilon: 0.71 Steps: 29505
# Episode:  1145 Score:  -49.09539794921875  Average score: -39.85 Best average: -22.54 Epsilon: 0.71 Steps: 29525
# Episode:  1146 Score:  -19.443206787109375  Average score: -40.46 Best average: -22.54 Epsilon: 0.70 Steps: 29545
# Episode:  1147 Score:  28.017608642578125  Average score: -39.23 Best average: -22.54 Epsilon: 0.70 Steps: 29578
# Episode:  1148 Score:  -58.84849548339844  Average score: -39.14 Best average: -22.54 Epsilon: 0.70 Steps: 29599
# Episode:  1149 Score:  68.553466796875  Average score: -37.93 Best average: -22.54 Epsilon: 0.70 Steps: 29618
# Episode:  1150 Score:  -29.3359375  Average score: -38.30 Best average: -22.54 Epsilon: 0.70 Steps: 29630
# Episode:  1151 Score:  -33.563995361328125  Average score: -38.85 Best average: -22.54 Epsilon: 0.70 Steps: 29643
# Episode:  1152 Score:  -34.73838806152344  Average score: -40.52 Best average: -22.54 Epsilon: 0.70 Steps: 29656
# Episode:  1153 Score:  -14.333465576171875  Average score: -39.79 Best average: -22.54 Epsilon: 0.70 Steps: 29676
# Episode:  1154 Score:  29.661956787109375  Average score: -38.50 Best average: -22.54 Epsilon: 0.70 Steps: 29706
# Episode:  1155 Score:  -97.971923828125  Average score: -39.59 Best average: -22.54 Epsilon: 0.70 Steps: 29725
# Episode:  1156 Score:  -60.345947265625  Average score: -39.85 Best average: -22.54 Epsilon: 0.70 Steps: 29736
# Episode:  1157 Score:  -100.29991149902344  Average score: -40.41 Best average: -22.54 Epsilon: 0.70 Steps: 29758
# Episode:  1158 Score:  -65.31973266601562  Average score: -40.88 Best average: -22.54 Epsilon: 0.70 Steps: 29788
# Episode:  1159 Score:  -16.823806762695312  Average score: -40.20 Best average: -22.54 Epsilon: 0.70 Steps: 29808
# Episode:  1160 Score:  -35.94392395019531  Average score: -40.04 Best average: -22.54 Epsilon: 0.70 Steps: 29827
# Episode:  1161 Score:  -93.18740844726562  Average score: -41.16 Best average: -22.54 Epsilon: 0.70 Steps: 29853
# Episode:  1162 Score:  -44.51325988769531  Average score: -40.80 Best average: -22.54 Epsilon: 0.70 Steps: 29880
# Episode:  1163 Score:  -30.376968383789062  Average score: -40.85 Best average: -22.54 Epsilon: 0.70 Steps: 29902
# Episode:  1164 Score:  -19.273391723632812  Average score: -41.56 Best average: -22.54 Epsilon: 0.70 Steps: 29914
# Episode:  1165 Score:  -98.96661376953125  Average score: -42.34 Best average: -22.54 Epsilon: 0.70 Steps: 29935
# Episode:  1166 Score:  -41.85345458984375  Average score: -42.85 Best average: -22.54 Epsilon: 0.70 Steps: 29964
# Episode:  1167 Score:  -33.00494384765625  Average score: -42.03 Best average: -22.54 Epsilon: 0.70 Steps: 29983
# Episode:  1168 Score:  -77.71168518066406  Average score: -41.84 Best average: -22.54 Epsilon: 0.70 Steps: 30011
# Episode:  1169 Score:  1.86566162109375  Average score: -42.03 Best average: -22.54 Epsilon: 0.70 Steps: 30032
# Episode:  1170 Score:  -36.23970031738281  Average score: -41.32 Best average: -22.54 Epsilon: 0.70 Steps: 30052
# Episode:  1171 Score:  -87.42897033691406  Average score: -41.84 Best average: -22.54 Epsilon: 0.70 Steps: 30064
# Episode:  1172 Score:  -74.47624206542969  Average score: -43.61 Best average: -22.54 Epsilon: 0.70 Steps: 30084
# Episode:  1173 Score:  -69.67434692382812  Average score: -44.22 Best average: -22.54 Epsilon: 0.70 Steps: 30095
# Episode:  1174 Score:  100.57760620117188  Average score: -42.14 Best average: -22.54 Epsilon: 0.70 Steps: 30149
# Episode:  1175 Score:  -70.23411560058594  Average score: -42.71 Best average: -22.54 Epsilon: 0.70 Steps: 30161
# Episode:  1176 Score:  -11.270660400390625  Average score: -42.19 Best average: -22.54 Epsilon: 0.70 Steps: 30191
# Episode:  1177 Score:  -91.12294006347656  Average score: -42.39 Best average: -22.54 Epsilon: 0.70 Steps: 30211
# Episode:  1178 Score:  -39.143035888671875  Average score: -42.62 Best average: -22.54 Epsilon: 0.70 Steps: 30229
# Episode:  1179 Score:  -14.0054931640625  Average score: -42.49 Best average: -22.54 Epsilon: 0.70 Steps: 30242
# Episode:  1180 Score:  -38.441986083984375  Average score: -42.31 Best average: -22.54 Epsilon: 0.70 Steps: 30254
# Episode:  1181 Score:  -9.65252685546875  Average score: -42.27 Best average: -22.54 Epsilon: 0.70 Steps: 30267
# Episode:  1182 Score:  -98.54403686523438  Average score: -44.17 Best average: -22.54 Epsilon: 0.70 Steps: 30304
# Episode:  1183 Score:  -37.91778564453125  Average score: -43.71 Best average: -22.54 Epsilon: 0.70 Steps: 30334
# Episode:  1184 Score:  -73.96617126464844  Average score: -44.22 Best average: -22.54 Epsilon: 0.70 Steps: 30345
# Episode:  1185 Score:  -10.169906616210938  Average score: -43.57 Best average: -22.54 Epsilon: 0.70 Steps: 30358
# Episode:  1186 Score:  -89.771728515625  Average score: -43.55 Best average: -22.54 Epsilon: 0.70 Steps: 30377
# Episode:  1187 Score:  -23.043716430664062  Average score: -43.13 Best average: -22.54 Epsilon: 0.70 Steps: 30396
# ...
# Episode:  4860 Score:  268.96925354003906  Average score: 205.31 Best average: 263.45 Epsilon: 0.10 Steps: 140972
# Episode:  4861 Score:  217.34912109375  Average score: 205.41 Best average: 263.45 Epsilon: 0.10 Steps: 141013
# Episode:  4862 Score:  -33.65220642089844  Average score: 200.61 Best average: 263.45 Epsilon: 0.10 Steps: 141034
# Episode:  4863 Score:  360.8188781738281  Average score: 204.49 Best average: 263.45 Epsilon: 0.10 Steps: 141078
# Episode:  4864 Score:  -69.7833251953125  Average score: 200.50 Best average: 263.45 Epsilon: 0.10 Steps: 141091
# Episode:  4865 Score:  297.8742370605469  Average score: 202.15 Best average: 263.45 Epsilon: 0.10 Steps: 141137
# Episode:  4866 Score:  242.1970977783203  Average score: 201.55 Best average: 263.45 Epsilon: 0.10 Steps: 141175
# Episode:  4867 Score:  305.67236328125  Average score: 201.38 Best average: 263.45 Epsilon: 0.10 Steps: 141210
# Episode:  4868 Score:  327.9101104736328  Average score: 203.09 Best average: 263.45 Epsilon: 0.10 Steps: 141251
# Episode:  4869 Score:  349.29127502441406  Average score: 206.60 Best average: 263.45 Epsilon: 0.10 Steps: 141293
# Episode:  4870 Score:  187.78123474121094  Average score: 207.91 Best average: 263.45 Epsilon: 0.10 Steps: 141320
# Episode:  4871 Score:  391.0816955566406  Average score: 209.96 Best average: 263.45 Epsilon: 0.10 Steps: 141374
# Episode:  4872 Score:  141.81092834472656  Average score: 208.68 Best average: 263.45 Epsilon: 0.10 Steps: 141402
# Episode:  4873 Score:  36.54066467285156  Average score: 206.88 Best average: 263.45 Epsilon: 0.10 Steps: 141421
# Episode:  4874 Score:  305.28065490722656  Average score: 208.06 Best average: 263.45 Epsilon: 0.10 Steps: 141455
# Episode:  4875 Score:  277.9191131591797  Average score: 207.93 Best average: 263.45 Epsilon: 0.10 Steps: 141491
# Episode:  4876 Score:  -63.401214599609375  Average score: 204.65 Best average: 263.45 Epsilon: 0.10 Steps: 141503
# Episode:  4877 Score:  244.5550537109375  Average score: 203.95 Best average: 263.45 Epsilon: 0.10 Steps: 141538
# Episode:  4878 Score:  243.41012573242188  Average score: 204.15 Best average: 263.45 Epsilon: 0.10 Steps: 141574
# Episode:  4879 Score:  217.4812774658203  Average score: 206.67 Best average: 263.45 Epsilon: 0.10 Steps: 141601
# Episode:  4880 Score:  304.2970428466797  Average score: 206.86 Best average: 263.45 Epsilon: 0.10 Steps: 141641
# Episode:  4881 Score:  213.61236572265625  Average score: 206.86 Best average: 263.45 Epsilon: 0.10 Steps: 141684
# Episode:  4882 Score:  257.21263122558594  Average score: 206.68 Best average: 263.45 Epsilon: 0.10 Steps: 141727
# Episode:  4883 Score:  255.44102478027344  Average score: 207.73 Best average: 263.45 Epsilon: 0.10 Steps: 141769
# Episode:  4884 Score:  103.25411987304688  Average score: 205.37 Best average: 263.45 Epsilon: 0.10 Steps: 141803
# Episode:  4885 Score:  -76.33909606933594  Average score: 202.38 Best average: 263.45 Epsilon: 0.10 Steps: 141821
# Episode:  4886 Score:  341.07447814941406  Average score: 205.00 Best average: 263.45 Epsilon: 0.10 Steps: 141859
# Episode:  4887 Score:  189.71128845214844  Average score: 203.68 Best average: 263.45 Epsilon: 0.10 Steps: 141886
# Episode:  4888 Score:  234.58604431152344  Average score: 202.04 Best average: 263.45 Epsilon: 0.10 Steps: 141926
# Episode:  4889 Score:  226.13661193847656  Average score: 204.14 Best average: 263.45 Epsilon: 0.10 Steps: 141967
# Episode:  4890 Score:  645.9373016357422  Average score: 206.87 Best average: 263.45 Epsilon: 0.10 Steps: 142056
# Episode:  4891 Score:  263.2900695800781  Average score: 206.31 Best average: 263.45 Epsilon: 0.10 Steps: 142099
# Episode:  4892 Score:  134.57342529296875  Average score: 204.47 Best average: 263.45 Epsilon: 0.10 Steps: 142134
# Episode:  4893 Score:  -91.47650146484375  Average score: 201.55 Best average: 263.45 Epsilon: 0.10 Steps: 142146
# Episode:  4894 Score:  384.601318359375  Average score: 205.71 Best average: 263.45 Epsilon: 0.10 Steps: 142193
# Episode:  4895 Score:  199.74203491210938  Average score: 205.61 Best average: 263.45 Epsilon: 0.10 Steps: 142221
# Episode:  4896 Score:  213.21218872070312  Average score: 204.00 Best average: 263.45 Epsilon: 0.10 Steps: 142249
# Episode:  4897 Score:  49.136322021484375  Average score: 201.08 Best average: 263.45 Epsilon: 0.10 Steps: 142269
# Episode:  4898 Score:  328.1936950683594  Average score: 201.52 Best average: 263.45 Epsilon: 0.10 Steps: 142306
# Episode:  4899 Score:  246.16404724121094  Average score: 201.55 Best average: 263.45 Epsilon: 0.10 Steps: 142335
# Episode:  4900 Score:  270.12257385253906  Average score: 204.89 Best average: 263.45 Epsilon: 0.10 Steps: 142369
# Episode:  4901 Score:  338.84361267089844  Average score: 206.34 Best average: 263.45 Epsilon: 0.10 Steps: 142415
# Episode:  4902 Score:  300.3957214355469  Average score: 205.45 Best average: 263.45 Epsilon: 0.10 Steps: 142467
# Episode:  4903 Score:  238.34312438964844  Average score: 208.20 Best average: 263.45 Epsilon: 0.10 Steps: 142505
# Episode:  4904 Score:  235.21978759765625  Average score: 209.02 Best average: 263.45 Epsilon: 0.10 Steps: 142540
# Episode:  4905 Score:  320.20782470703125  Average score: 210.93 Best average: 263.45 Epsilon: 0.10 Steps: 142588
# Episode:  4906 Score:  213.68650817871094  Average score: 213.17 Best average: 263.45 Epsilon: 0.10 Steps: 142630
# Episode:  4907 Score:  260.68408203125  Average score: 212.35 Best average: 263.45 Epsilon: 0.10 Steps: 142670
# Episode:  4908 Score:  332.2545928955078  Average score: 213.64 Best average: 263.45 Epsilon: 0.10 Steps: 142704
# Episode:  4909 Score:  160.83316040039062  Average score: 212.34 Best average: 263.45 Epsilon: 0.10 Steps: 142739
# Episode:  4910 Score:  -4.8754425048828125  Average score: 212.93 Best average: 263.45 Epsilon: 0.10 Steps: 142766
# Episode:  4911 Score:  277.1127624511719  Average score: 216.24 Best average: 263.45 Epsilon: 0.10 Steps: 142807
# Episode:  4912 Score:  153.0970916748047  Average score: 215.34 Best average: 263.45 Epsilon: 0.10 Steps: 142833
# Episode:  4913 Score:  201.6034393310547  Average score: 215.59 Best average: 263.45 Epsilon: 0.10 Steps: 142867
# Episode:  4914 Score:  68.04342651367188  Average score: 216.87 Best average: 263.45 Epsilon: 0.10 Steps: 142900
# Episode:  4915 Score:  -94.23709106445312  Average score: 212.64 Best average: 263.45 Epsilon: 0.10 Steps: 142911
# Episode:  4916 Score:  -64.72102355957031  Average score: 209.51 Best average: 263.45 Epsilon: 0.10 Steps: 142931
# Episode:  4917 Score:  250.7060089111328  Average score: 209.26 Best average: 263.45 Epsilon: 0.10 Steps: 142971
# Episode:  4918 Score:  226.84561157226562  Average score: 212.13 Best average: 263.45 Epsilon: 0.10 Steps: 143006
# Episode:  4919 Score:  256.89231872558594  Average score: 211.09 Best average: 263.45 Epsilon: 0.10 Steps: 143045
# Episode:  4920 Score:  34.43475341796875  Average score: 209.08 Best average: 263.45 Epsilon: 0.10 Steps: 143071
# Episode:  4921 Score:  290.11070251464844  Average score: 210.61 Best average: 263.45 Epsilon: 0.10 Steps: 143111
# Episode:  4922 Score:  333.9395446777344  Average score: 213.36 Best average: 263.45 Epsilon: 0.10 Steps: 143160
# Episode:  4923 Score:  -89.67790222167969  Average score: 212.56 Best average: 263.45 Epsilon: 0.10 Steps: 143171
# Episode:  4924 Score:  304.6893310546875  Average score: 212.00 Best average: 263.45 Epsilon: 0.10 Steps: 143218
# Episode:  4925 Score:  294.72509765625  Average score: 212.99 Best average: 263.45 Epsilon: 0.10 Steps: 143253
# Episode:  4926 Score:  313.4077911376953  Average score: 215.32 Best average: 263.45 Epsilon: 0.10 Steps: 143294
# Episode:  4927 Score:  -74.65336608886719  Average score: 210.87 Best average: 263.45 Epsilon: 0.10 Steps: 143314
# Episode:  4928 Score:  -111.71530151367188  Average score: 209.86 Best average: 263.45 Epsilon: 0.10 Steps: 143327
# Episode:  4929 Score:  -76.71969604492188  Average score: 208.04 Best average: 263.45 Epsilon: 0.10 Steps: 143348
# Episode:  4930 Score:  100.88580322265625  Average score: 207.28 Best average: 263.45 Epsilon: 0.10 Steps: 143382
# Episode:  4931 Score:  -105.92324829101562  Average score: 205.34 Best average: 263.45 Epsilon: 0.10 Steps: 143408
# Episode:  4932 Score:  -9.1759033203125  Average score: 202.14 Best average: 263.45 Epsilon: 0.10 Steps: 143427
# Episode:  4933 Score:  -90.64137268066406  Average score: 199.28 Best average: 263.45 Epsilon: 0.10 Steps: 143455
# Episode:  4934 Score:  -84.27505493164062  Average score: 195.92 Best average: 263.45 Epsilon: 0.10 Steps: 143475
# Episode:  4935 Score:  288.419677734375  Average score: 196.42 Best average: 263.45 Epsilon: 0.10 Steps: 143519
# Episode:  4936 Score:  -6.785430908203125  Average score: 192.78 Best average: 263.45 Epsilon: 0.10 Steps: 143537
# Episode:  4937 Score:  -109.3841552734375  Average score: 191.94 Best average: 263.45 Epsilon: 0.10 Steps: 143550
# Episode:  4938 Score:  -103.50015258789062  Average score: 187.48 Best average: 263.45 Epsilon: 0.10 Steps: 143562
# Episode:  4939 Score:  128.8097381591797  Average score: 185.93 Best average: 263.45 Epsilon: 0.10 Steps: 143595
# Episode:  4940 Score:  308.8259582519531  Average score: 188.97 Best average: 263.45 Epsilon: 0.10 Steps: 143652
# Episode:  4941 Score:  -18.764999389648438  Average score: 187.81 Best average: 263.45 Epsilon: 0.10 Steps: 143665
# Episode:  4942 Score:  62.712860107421875  Average score: 183.65 Best average: 263.45 Epsilon: 0.10 Steps: 143698
# Episode:  4943 Score:  202.64111328125  Average score: 182.82 Best average: 263.45 Epsilon: 0.10 Steps: 143725
# Episode:  4944 Score:  158.16412353515625  Average score: 181.17 Best average: 263.45 Epsilon: 0.10 Steps: 143752
# Episode:  4945 Score:  65.09455871582031  Average score: 178.48 Best average: 263.45 Epsilon: 0.10 Steps: 143780
# Episode:  4946 Score:  275.68499755859375  Average score: 177.99 Best average: 263.45 Epsilon: 0.10 Steps: 143820
# Episode:  4947 Score:  -95.35818481445312  Average score: 174.65 Best average: 263.45 Epsilon: 0.10 Steps: 143832
# Episode:  4948 Score:  298.87083435058594  Average score: 174.40 Best average: 263.45 Epsilon: 0.10 Steps: 143874
# Episode:  4949 Score:  103.34568786621094  Average score: 173.18 Best average: 263.45 Epsilon: 0.10 Steps: 143895
# Episode:  4950 Score:  293.7293395996094  Average score: 177.06 Best average: 263.45 Epsilon: 0.10 Steps: 143931
# Episode:  4951 Score:  273.186767578125  Average score: 177.23 Best average: 263.45 Epsilon: 0.10 Steps: 143975
# Episode:  4952 Score:  281.3820037841797  Average score: 177.55 Best average: 263.45 Epsilon: 0.10 Steps: 144019
# Episode:  4953 Score:  336.4484558105469  Average score: 177.72 Best average: 263.45 Epsilon: 0.10 Steps: 144059
# Episode:  4954 Score:  242.3070526123047  Average score: 176.63 Best average: 263.45 Epsilon: 0.10 Steps: 144100
# Episode:  4955 Score:  -51.106842041015625  Average score: 174.49 Best average: 263.45 Epsilon: 0.10 Steps: 144119
# Episode:  4956 Score:  20.360580444335938  Average score: 171.63 Best average: 263.45 Epsilon: 0.10 Steps: 144137
# Episode:  4957 Score:  219.21255493164062  Average score: 171.09 Best average: 263.45 Epsilon: 0.10 Steps: 144172
# Episode:  4958 Score:  273.2610626220703  Average score: 170.95 Best average: 263.45 Epsilon: 0.10 Steps: 144212
# Episode:  4959 Score:  346.0780029296875  Average score: 174.36 Best average: 263.45 Epsilon: 0.10 Steps: 144258
# Episode:  4960 Score:  211.09591674804688  Average score: 173.78 Best average: 263.45 Epsilon: 0.10 Steps: 144290
# Episode:  4961 Score:  292.41534423828125  Average score: 174.53 Best average: 263.45 Epsilon: 0.10 Steps: 144333
# Episode:  4962 Score:  269.947021484375  Average score: 177.56 Best average: 263.45 Epsilon: 0.10 Steps: 144375
# Episode:  4963 Score:  351.52191162109375  Average score: 177.47 Best average: 263.45 Epsilon: 0.10 Steps: 144423
# Episode:  4964 Score:  285.97120666503906  Average score: 181.03 Best average: 263.45 Epsilon: 0.10 Steps: 144461
# Episode:  4965 Score:  288.2371368408203  Average score: 180.93 Best average: 263.45 Epsilon: 0.10 Steps: 144497
# Episode:  4966 Score:  343.1591796875  Average score: 181.94 Best average: 263.45 Epsilon: 0.10 Steps: 144545
# Episode:  4967 Score:  -17.663223266601562  Average score: 178.71 Best average: 263.45 Epsilon: 0.10 Steps: 144573
# Episode:  4968 Score:  -109.46902465820312  Average score: 174.33 Best average: 263.45 Epsilon: 0.10 Steps: 144591
# Episode:  4969 Score:  300.1436309814453  Average score: 173.84 Best average: 263.45 Epsilon: 0.10 Steps: 144627
# Episode:  4970 Score:  192.00784301757812  Average score: 173.89 Best average: 263.45 Epsilon: 0.10 Steps: 144670
# Episode:  4971 Score:  286.5924072265625  Average score: 172.84 Best average: 263.45 Epsilon: 0.10 Steps: 144707
# Episode:  4972 Score:  185.8734588623047  Average score: 173.28 Best average: 263.45 Epsilon: 0.10 Steps: 144741
# Episode:  4973 Score:  157.7390899658203  Average score: 174.49 Best average: 263.45 Epsilon: 0.10 Steps: 144774
# Episode:  4974 Score:  25.810440063476562  Average score: 171.70 Best average: 263.45 Epsilon: 0.10 Steps: 144800
# Episode:  4975 Score:  213.13311767578125  Average score: 171.05 Best average: 263.45 Epsilon: 0.10 Steps: 144827
# Episode:  4976 Score:  61.36761474609375  Average score: 172.30 Best average: 263.45 Epsilon: 0.10 Steps: 144860
# Episode:  4977 Score:  296.9736785888672  Average score: 172.82 Best average: 263.45 Epsilon: 0.10 Steps: 144916
# Episode:  4978 Score:  108.12643432617188  Average score: 171.47 Best average: 263.45 Epsilon: 0.10 Steps: 144943
# Episode:  4979 Score:  161.99208068847656  Average score: 170.91 Best average: 263.45 Epsilon: 0.10 Steps: 144976
# Episode:  4980 Score:  355.6056671142578  Average score: 171.43 Best average: 263.45 Epsilon: 0.10 Steps: 145020
# Episode:  4981 Score:  214.50758361816406  Average score: 171.44 Best average: 263.45 Epsilon: 0.10 Steps: 145049
# Episode:  4982 Score:  322.93263244628906  Average score: 172.09 Best average: 263.45 Epsilon: 0.10 Steps: 145105
# Episode:  4983 Score:  263.42120361328125  Average score: 172.17 Best average: 263.45 Epsilon: 0.10 Steps: 145157
# Episode:  4984 Score:  350.99827575683594  Average score: 174.65 Best average: 263.45 Epsilon: 0.10 Steps: 145206
# Episode:  4985 Score:  203.1593475341797  Average score: 177.45 Best average: 263.45 Epsilon: 0.10 Steps: 145243
# Episode:  4986 Score:  349.1339874267578  Average score: 177.53 Best average: 263.45 Epsilon: 0.10 Steps: 145288
# Episode:  4987 Score:  -55.62947082519531  Average score: 175.07 Best average: 263.45 Epsilon: 0.10 Steps: 145314
# Episode:  4988 Score:  107.48382568359375  Average score: 173.80 Best average: 263.45 Epsilon: 0.10 Steps: 145347
# Episode:  4989 Score:  29.949798583984375  Average score: 171.84 Best average: 263.45 Epsilon: 0.10 Steps: 145381
# Episode:  4990 Score:  202.22589111328125  Average score: 167.40 Best average: 263.45 Epsilon: 0.10 Steps: 145423
# Episode:  4991 Score:  305.46240234375  Average score: 167.82 Best average: 263.45 Epsilon: 0.10 Steps: 145463
# Episode:  4992 Score:  269.68775939941406  Average score: 169.18 Best average: 263.45 Epsilon: 0.10 Steps: 145497
# Episode:  4993 Score:  -32.85725402832031  Average score: 169.76 Best average: 263.45 Epsilon: 0.10 Steps: 145537
# Episode:  4994 Score:  305.0298309326172  Average score: 168.97 Best average: 263.45 Epsilon: 0.10 Steps: 145579
# Episode:  4995 Score:  -63.6702880859375  Average score: 166.33 Best average: 263.45 Epsilon: 0.10 Steps: 145598
# Episode:  4996 Score:  321.97483825683594  Average score: 167.42 Best average: 263.45 Epsilon: 0.10 Steps: 145638
# Episode:  4997 Score:  182.32046508789062  Average score: 168.75 Best average: 263.45 Epsilon: 0.10 Steps: 145694
# Episode:  4998 Score:  206.36766052246094  Average score: 167.53 Best average: 263.45 Epsilon: 0.10 Steps: 145726
# Episode:  4999 Score:  122.39236450195312  Average score: 166.30 Best average: 263.45 Epsilon: 0.10 Steps: 145760

# %%
x = [i+1 for i in range(len(scores))]
plot_learning_curve(x, scores, eps_history, figure_file)

# %% [markdown]
# ## Evaluation
#
# Finally, let's visualize our agent's performance, and play a game within the gym environment itself.

# %%
#Visualization cobe for running within Colab

# Install dependencies first for graphics visualization within Colaboratory

#remove " > /dev/null 2>&1" to see what is going on under the hood
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# Out:
# Requirement already up-to-date: setuptools in /usr/local/lib/python3.6/dist-packages (49.6.0)

# %%
#To Evaluate model on OpenAI gym, we will record a video via Ipython display



from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only

import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML

from IPython import display as ipythondisplay


from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
"""
shape = (84,84,1)
new_shape = (shape[2], shape[0], shape[1])
print(new_shape[1:])
#1,84,84

new_frame = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)
resized_screen = cv2.resize(new_frame, self.shape[1:],
                                    interpolation=cv2.INTER_AREA)
new_obs = np.array(resized_screen, dtype=np.uint8).reshape(self.shape)
new_obs = new_obs / 255.0
"""
# Out:
# '\nshape = (84,84,1)\nnew_shape = (shape[2], shape[0], shape[1])\nprint(new_shape[1:])\n#1,84,84\n\nnew_frame = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)\nresized_screen = cv2.resize(new_frame, self.shape[1:],\n                                    interpolation=cv2.INTER_AREA)\nnew_obs = np.array(resized_screen, dtype=np.uint8).reshape(self.shape)\nnew_obs = new_obs / 255.0\n'

# %%
class PreprocessFrameEval(gym.ObservationWrapper):
  #set shape by swapping channels axis
	#set observation space to new shape using gym.spaces.Box (0 to 1.0)
    def __init__(self, shape, env=None):
        super(PreprocessFrameEval, self).__init__(env)
        self.shape = (shape[2], shape[0], shape[1])
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0,
                                    shape=self.shape, dtype=np.float32)

    def observation(self, obs):
        img_array.append(obs)
        new_frame = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)
        resized_screen = cv2.resize(new_frame, self.shape[1:],
                                    interpolation=cv2.INTER_AREA)
        new_obs = np.array(resized_screen, dtype=np.uint8).reshape(self.shape)
        new_obs = new_obs / 255.0

        return new_obs



def make_envEVAL(env_name, shape=(84,84,1), repeat=4, clip_rewards=False,
             no_ops=0, fire_first=False):
    env = gym.make(env_name)
    env = PreprocessFrameEval(shape, env)
    env = RepeatActionAndMaxFrame(env, repeat, clip_rewards, no_ops, fire_first)
    
    env = StackFrames(env, repeat)

    return env

# %%
env = make_envEVAL('VizdoomDefendLine-v0')

n_outputs = env.action_space.n
print(n_outputs)

img_array=[]

observation = env.reset()

#if load_checkpoint:
  #agent.load_models()


for i in range(2):
  done = False
  observation = env.reset()
  
  
  score = 0
  while not done:
    
    action = agent.choose_action(observation)
    observation_, reward, done, info = env.step(action)
    
    
    #img_array.append(observation)
# Out:
# 7

# %%
print(len(img_array))

for i in range(22):
  
  if i > 20:
    print(img_array[i].shape)
    plt.imshow(img_array[i])
    plt.show()
# Out:
# 137
# (240, 320, 3)

# %%
#!pip install sk-video

# %%
from random import choice
import cv2 
from google.colab.patches import cv2_imshow
from torchvision.io import write_video

import numpy as np


out_video =  np.empty([len(img_array), 240, 320, 3], dtype = np.uint8)
out_video =  out_video.astype(np.uint8)

for i in range(len(img_array)):
  frame = img_array[i]
  out_video[i] = frame
# Writes the the output image sequences in a video file

write_video("/content/doom.mp4", out_video, 25, video_codec='libx264', options=None)
#skvideo.io.vwrite("/content/doom.mp4", out_video)
