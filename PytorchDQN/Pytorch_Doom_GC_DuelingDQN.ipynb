# %% [markdown]
# # Automated Doom with Duelling Deep Q-learning, in Pytorch
#
# A Colaboratory notebook for GradientCrescent, by Adrian Yijie Xu.
#
# If you enjoyed this notebook, please consider leaving a star on the GradientCrescent Github (https://github.com/EXJUSTICE/GradientCrescent), and visting the publication for more articles on applied and theoretical aspects of AI (https://medium.com/@adrianitsaxu).

# %% [markdown]
# ## Setup
#
# First we import all the necessary libraries. This may take a significant time, but should only be done once per session. After execution, make sure to restart the runtime.
#
# If you wish rerun the notebook, make sure to comment it out. </font>

# %%
#Visualization cobe for running within Colab
# !sudo apt-get update
# !sudo apt-get install build-essential zlib1g-dev libsdl2-dev libjpeg-dev nasm tar libbz2-dev libgtk2.0-dev cmake git libfluidsynth-dev libgme-dev libopenal-dev timidity libwildmidi-dev unzip

# Boost libraries
# !sudo apt-get install libboost-all-dev

# Lua binding dependencies
# !apt-get install liblua5.1-dev
# !sudo apt-get install cmake libboost-all-dev libgtk2.0-dev libsdl2-dev python-numpy git
# !git clone https://github.com/shakenes/vizdoomgym.git
# !python3 -m pip install -e vizdoomgym/
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release
# Get:5 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:6 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:7 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Get:8 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ Packages [95.7 kB]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:12 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Packages [47.5 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:14 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [1,067 kB]
# Get:15 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic InRelease [15.4 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:17 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [892 kB]
# Get:18 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic/main amd64 Packages [43.0 kB]
# Get:19 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [109 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/restricted amd64 Packages [125 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [1,421 kB]
# Get:22 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main Sources [1,864 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [1,362 kB]
# Get:24 http://ppa.launchpad.net/marutter/c2d4u3.5/ubuntu bionic/main amd64 Packages [900 kB]
# Fetched 8,220 kB in 4s (2,182 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# build-essential is already the newest version (12.4ubuntu1).
# libjpeg-dev is already the newest version (8c-2ubuntu8).
# libjpeg-dev set to manually installed.
# unzip is already the newest version (6.0-21ubuntu1).
# zlib1g-dev is already the newest version (1:1.2.11.dfsg-0ubuntu2).
# zlib1g-dev set to manually installed.
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# git is already the newest version (1:2.17.1-1ubuntu0.7).
# libbz2-dev is already the newest version (1.0.6-8.1ubuntu0.2).
# libbz2-dev set to manually installed.
# tar is already the newest version (1.29b-2ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# The following additional packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file freepats gettext gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-2.0 gir1.2-ibus-1.0
#   gir1.2-pango-1.0 intltool-debian libarchive-cpio-perl libarchive-zip-perl
#   libatk1.0-dev libaudio2 libcairo-script-interpreter2 libcairo2-dev
#   libcapnp-0.6.1 libdbus-1-dev libfile-stripnondeterminism-perl libfluidsynth1
#   libgdk-pixbuf2.0-dev libibus-1.0-5 libibus-1.0-dev libmagic-mgc libmagic1
#   libmail-sendmail-perl libmirclient-dev libmirclient9 libmircommon-dev
#   libmircommon7 libmircookie-dev libmircookie2 libmircore-dev libmircore1
#   libmirprotobuf3 libpango1.0-dev libpangoxft-1.0-0 libpixman-1-dev
#   libprotobuf-dev libprotobuf-lite10 libpulse-dev libpulse-mainloop-glib0
#   libsigsegv2 libsndio-dev libsys-hostname-long-perl libtimedate-perl libtool
#   libudev-dev libwildmidi-config libwildmidi2 libxcb-shm0-dev
#   libxcomposite-dev libxcursor-dev libxinerama-dev libxkbcommon-dev
#   libxml2-utils libxrandr-dev libxv-dev m4 po-debconf timidity-daemon
#   x11proto-composite-dev x11proto-randr-dev x11proto-xinerama-dev
# Suggested packages:
#   autoconf-archive gnu-standards autoconf-doc dh-make dwz gettext-doc
#   libasprintf-dev libgettextpo-dev nas libcairo2-doc fluidr3mono-gm-soundfont
#   | timgm6mb-soundfont | fluid-soundfont-gm libgtk2.0-doc imagemagick
#   libpango1.0-doc libtool-doc gcj-jdk m4-doc libmail-box-perl
#   fluid-soundfont-gm fluid-soundfont-gs pmidi
# The following NEW packages will be installed:
#   autoconf automake autopoint autotools-dev debhelper dh-autoreconf
#   dh-strip-nondeterminism file freepats gettext gettext-base gir1.2-atk-1.0
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-gtk-2.0 gir1.2-ibus-1.0
#   gir1.2-pango-1.0 intltool-debian libarchive-cpio-perl libarchive-zip-perl
#   libatk1.0-dev libaudio2 libcairo-script-interpreter2 libcairo2-dev
#   libcapnp-0.6.1 libdbus-1-dev libfile-stripnondeterminism-perl
#   libfluidsynth-dev libfluidsynth1 libgdk-pixbuf2.0-dev libgme-dev
#   libgtk2.0-dev libibus-1.0-5 libibus-1.0-dev libmagic-mgc libmagic1
#   libmail-sendmail-perl libmirclient-dev libmirclient9 libmircommon-dev
#   libmircommon7 libmircookie-dev libmircookie2 libmircore-dev libmircore1
#   libmirprotobuf3 libopenal-dev libpango1.0-dev libpangoxft-1.0-0
#   libpixman-1-dev libprotobuf-dev libprotobuf-lite10 libpulse-dev
#   libpulse-mainloop-glib0 libsdl2-dev libsigsegv2 libsndio-dev
#   libsys-hostname-long-perl libtimedate-perl libtool libudev-dev
#   libwildmidi-config libwildmidi-dev libwildmidi2 libxcb-shm0-dev
#   libxcomposite-dev libxcursor-dev libxinerama-dev libxkbcommon-dev
#   libxml2-utils libxrandr-dev libxv-dev m4 nasm po-debconf timidity
#   timidity-daemon x11proto-composite-dev x11proto-randr-dev
#   x11proto-xinerama-dev
# 0 upgraded, 80 newly installed, 0 to remove and 72 not upgraded.
# Need to get 43.2 MB of archives.
# After this operation, 114 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic-mgc amd64 1:5.32-2ubuntu0.4 [184 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libmagic1 amd64 1:5.32-2ubuntu0.4 [68.6 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 file amd64 1:5.32-2ubuntu0.4 [22.1 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext-base amd64 0.19.8.1-6ubuntu0.3 [113 kB]
# Get:5 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsigsegv2 amd64 2.12-1 [14.7 kB]
# Get:6 http://archive.ubuntu.com/ubuntu bionic/main amd64 m4 amd64 1.4.18-1 [197 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic/main amd64 autoconf all 2.69-11 [322 kB]
# Get:8 http://archive.ubuntu.com/ubuntu bionic/main amd64 autotools-dev all 20180224.1 [39.6 kB]
# Get:9 http://archive.ubuntu.com/ubuntu bionic/main amd64 automake all 1:1.15.1-3ubuntu2 [509 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 autopoint all 0.19.8.1-6ubuntu0.3 [426 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool all 2.4.6-2 [194 kB]
# Get:12 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-autoreconf all 17 [15.8 kB]
# Get:13 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libarchive-zip-perl all 1.60-1ubuntu0.1 [84.6 kB]
# Get:14 http://archive.ubuntu.com/ubuntu bionic/main amd64 libfile-stripnondeterminism-perl all 0.040-1.1~build1 [13.8 kB]
# Get:15 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtimedate-perl all 2.3000-2 [37.5 kB]
# Get:16 http://archive.ubuntu.com/ubuntu bionic/main amd64 dh-strip-nondeterminism all 0.040-1.1~build1 [5,208 B]
# Get:17 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gettext amd64 0.19.8.1-6ubuntu0.3 [1,293 kB]
# Get:18 http://archive.ubuntu.com/ubuntu bionic/main amd64 intltool-debian all 0.35.0+20060710.4 [24.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu bionic/main amd64 po-debconf all 1.0.20 [232 kB]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 debhelper all 11.1.6ubuntu2 [902 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic/universe amd64 freepats all 20060219-1 [29.0 MB]
# Get:22 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-atk-1.0 amd64 2.28.1-1 [17.8 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-freedesktop amd64 1.56.1-1 [9,080 B]
# Get:24 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gdkpixbuf-2.0 amd64 2.36.11-2 [7,748 B]
# Get:25 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpangoxft-1.0-0 amd64 1.40.14-1ubuntu0.1 [15.0 kB]
# Get:26 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-pango-1.0 amd64 1.40.14-1ubuntu0.1 [21.6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu bionic/main amd64 gir1.2-gtk-2.0 amd64 2.24.32-1ubuntu1 [172 kB]
# Get:28 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libibus-1.0-5 amd64 1.5.17-3ubuntu5.3 [133 kB]
# Get:29 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 gir1.2-ibus-1.0 amd64 1.5.17-3ubuntu5.3 [66.5 kB]
# Get:30 http://archive.ubuntu.com/ubuntu bionic/main amd64 libarchive-cpio-perl all 0.10-1 [9,644 B]
# Get:31 http://archive.ubuntu.com/ubuntu bionic/main amd64 libatk1.0-dev amd64 2.28.1-1 [79.9 kB]
# Get:32 http://archive.ubuntu.com/ubuntu bionic/main amd64 libaudio2 amd64 1.9.4-6 [50.3 kB]
# Get:33 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo-script-interpreter2 amd64 1.15.10-2ubuntu0.1 [53.5 kB]
# Get:34 http://archive.ubuntu.com/ubuntu bionic/main amd64 libpixman-1-dev amd64 0.34.0-2 [244 kB]
# Get:35 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxcb-shm0-dev amd64 1.13-2~ubuntu18.04 [6,684 B]
# Get:36 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libcairo2-dev amd64 1.15.10-2ubuntu0.1 [626 kB]
# Get:37 http://archive.ubuntu.com/ubuntu bionic/main amd64 libcapnp-0.6.1 amd64 0.6.1-1ubuntu1 [658 kB]
# Get:38 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libdbus-1-dev amd64 1.12.2-1ubuntu1.2 [165 kB]
# Get:39 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfluidsynth1 amd64 1.1.9-1 [137 kB]
# Get:40 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libfluidsynth-dev amd64 1.1.9-1 [19.7 kB]
# Get:41 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgdk-pixbuf2.0-dev amd64 2.36.11-2 [46.8 kB]
# Get:42 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libgme-dev amd64 0.6.2-1 [5,796 B]
# Get:43 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpango1.0-dev amd64 1.40.14-1ubuntu0.1 [288 kB]
# Get:44 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-xinerama-dev all 2018.4-4 [2,628 B]
# Get:45 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxinerama-dev amd64 2:1.1.3-1 [8,404 B]
# Get:46 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-randr-dev all 2018.4-4 [2,620 B]
# Get:47 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxrandr-dev amd64 2:1.5.1-1 [24.0 kB]
# Get:48 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcursor-dev amd64 1:1.1.15-1 [26.5 kB]
# Get:49 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11proto-composite-dev all 1:2018.4-4 [2,620 B]
# Get:50 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxcomposite-dev amd64 1:0.4.4-2 [9,136 B]
# Get:51 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxml2-utils amd64 2.9.4+dfsg1-6.1ubuntu1.3 [35.9 kB]
# Get:52 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgtk2.0-dev amd64 2.24.32-1ubuntu1 [2,652 kB]
# Get:53 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libibus-1.0-dev amd64 1.5.17-3ubuntu5.3 [145 kB]
# Get:54 http://archive.ubuntu.com/ubuntu bionic/main amd64 libsys-hostname-long-perl all 1.5-1 [11.7 kB]
# Get:55 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmail-sendmail-perl all 0.80-1 [22.6 kB]
# Get:56 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore1 amd64 0.31.1-0ubuntu1 [26.5 kB]
# Get:57 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon7 amd64 0.31.1-0ubuntu1 [73.9 kB]
# Get:58 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-lite10 amd64 3.0.0-9.1ubuntu1 [97.7 kB]
# Get:59 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirprotobuf3 amd64 0.31.1-0ubuntu1 [127 kB]
# Get:60 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient9 amd64 0.31.1-0ubuntu1 [199 kB]
# Get:61 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircore-dev amd64 0.31.1-0ubuntu1 [21.7 kB]
# Get:62 http://archive.ubuntu.com/ubuntu bionic/main amd64 libprotobuf-dev amd64 3.0.0-9.1ubuntu1 [959 kB]
# Get:63 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libxkbcommon-dev amd64 0.8.2-1~ubuntu18.04.1 [150 kB]
# Get:64 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircommon-dev amd64 0.31.1-0ubuntu1 [13.9 kB]
# Get:65 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie2 amd64 0.31.1-0ubuntu1 [19.7 kB]
# Get:66 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmircookie-dev amd64 0.31.1-0ubuntu1 [4,392 B]
# Get:67 http://archive.ubuntu.com/ubuntu bionic/main amd64 libmirclient-dev amd64 0.31.1-0ubuntu1 [47.8 kB]
# Get:68 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libopenal-dev amd64 1:1.18.2-2 [20.9 kB]
# Get:69 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse-mainloop-glib0 amd64 1:11.1-1ubuntu7.10 [22.1 kB]
# Get:70 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libpulse-dev amd64 1:11.1-1ubuntu7.10 [81.5 kB]
# Get:71 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libsndio-dev amd64 1.1.0-3 [13.3 kB]
# Get:72 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 libudev-dev amd64 237-3ubuntu10.42 [19.1 kB]
# Get:73 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxv-dev amd64 2:1.0.11-1 [32.5 kB]
# Get:74 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 libsdl2-dev amd64 2.0.8+dfsg1-1ubuntu1.18.04.4 [683 kB]
# Get:75 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwildmidi-config all 0.4.2-1 [7,212 B]
# Get:76 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwildmidi2 amd64 0.4.2-1 [55.8 kB]
# Get:77 http://archive.ubuntu.com/ubuntu bionic/universe amd64 libwildmidi-dev amd64 0.4.2-1 [86.4 kB]
# Get:78 http://archive.ubuntu.com/ubuntu bionic/universe amd64 nasm amd64 2.13.02-0.1 [359 kB]
# Get:79 http://archive.ubuntu.com/ubuntu bionic/universe amd64 timidity amd64 2.13.2-41 [585 kB]
# Get:80 http://archive.ubuntu.com/ubuntu bionic/universe amd64 timidity-daemon all 2.13.2-41 [5,984 B]
# Fetched 43.2 MB in 4s (9,730 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 80.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package libmagic-mgc.
# (Reading database ... 144579 files and directories currently installed.)
# Preparing to unpack .../00-libmagic-mgc_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package libmagic1:amd64.
# Preparing to unpack .../01-libmagic1_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package file.
# Preparing to unpack .../02-file_1%3a5.32-2ubuntu0.4_amd64.deb ...
# Unpacking file (1:5.32-2ubuntu0.4) ...
# Selecting previously unselected package gettext-base.
# Preparing to unpack .../03-gettext-base_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext-base (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libsigsegv2:amd64.
# Preparing to unpack .../04-libsigsegv2_2.12-1_amd64.deb ...
# Unpacking libsigsegv2:amd64 (2.12-1) ...
# Selecting previously unselected package m4.
# Preparing to unpack .../05-m4_1.4.18-1_amd64.deb ...
# Unpacking m4 (1.4.18-1) ...
# Selecting previously unselected package autoconf.
# Preparing to unpack .../06-autoconf_2.69-11_all.deb ...
# Unpacking autoconf (2.69-11) ...
# Selecting previously unselected package autotools-dev.
# Preparing to unpack .../07-autotools-dev_20180224.1_all.deb ...
# Unpacking autotools-dev (20180224.1) ...
# Selecting previously unselected package automake.
# Preparing to unpack .../08-automake_1%3a1.15.1-3ubuntu2_all.deb ...
# Unpacking automake (1:1.15.1-3ubuntu2) ...
# Selecting previously unselected package autopoint.
# Preparing to unpack .../09-autopoint_0.19.8.1-6ubuntu0.3_all.deb ...
# Unpacking autopoint (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package libtool.
# Preparing to unpack .../10-libtool_2.4.6-2_all.deb ...
# Unpacking libtool (2.4.6-2) ...
# Selecting previously unselected package dh-autoreconf.
# Preparing to unpack .../11-dh-autoreconf_17_all.deb ...
# Unpacking dh-autoreconf (17) ...
# Selecting previously unselected package libarchive-zip-perl.
# Preparing to unpack .../12-libarchive-zip-perl_1.60-1ubuntu0.1_all.deb ...
# Unpacking libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Selecting previously unselected package libfile-stripnondeterminism-perl.
# Preparing to unpack .../13-libfile-stripnondeterminism-perl_0.040-1.1~build1_all.deb ...
# Unpacking libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Selecting previously unselected package libtimedate-perl.
# Preparing to unpack .../14-libtimedate-perl_2.3000-2_all.deb ...
# Unpacking libtimedate-perl (2.3000-2) ...
# Selecting previously unselected package dh-strip-nondeterminism.
# Preparing to unpack .../15-dh-strip-nondeterminism_0.040-1.1~build1_all.deb ...
# Unpacking dh-strip-nondeterminism (0.040-1.1~build1) ...
# Selecting previously unselected package gettext.
# Preparing to unpack .../16-gettext_0.19.8.1-6ubuntu0.3_amd64.deb ...
# Unpacking gettext (0.19.8.1-6ubuntu0.3) ...
# Selecting previously unselected package intltool-debian.
# Preparing to unpack .../17-intltool-debian_0.35.0+20060710.4_all.deb ...
# Unpacking intltool-debian (0.35.0+20060710.4) ...
# Selecting previously unselected package po-debconf.
# Preparing to unpack .../18-po-debconf_1.0.20_all.deb ...
# Unpacking po-debconf (1.0.20) ...
# Selecting previously unselected package debhelper.
# Preparing to unpack .../19-debhelper_11.1.6ubuntu2_all.deb ...
# Unpacking debhelper (11.1.6ubuntu2) ...
# Selecting previously unselected package freepats.
# Preparing to unpack .../20-freepats_20060219-1_all.deb ...
# Unpacking freepats (20060219-1) ...
# Selecting previously unselected package gir1.2-atk-1.0:amd64.
# Preparing to unpack .../21-gir1.2-atk-1.0_2.28.1-1_amd64.deb ...
# Unpacking gir1.2-atk-1.0:amd64 (2.28.1-1) ...
# Selecting previously unselected package gir1.2-freedesktop:amd64.
# Preparing to unpack .../22-gir1.2-freedesktop_1.56.1-1_amd64.deb ...
# Unpacking gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Selecting previously unselected package gir1.2-gdkpixbuf-2.0:amd64.
# Preparing to unpack .../23-gir1.2-gdkpixbuf-2.0_2.36.11-2_amd64.deb ...
# Unpacking gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Selecting previously unselected package libpangoxft-1.0-0:amd64.
# Preparing to unpack .../24-libpangoxft-1.0-0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-pango-1.0:amd64.
# Preparing to unpack .../25-gir1.2-pango-1.0_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package gir1.2-gtk-2.0.
# Preparing to unpack .../26-gir1.2-gtk-2.0_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking gir1.2-gtk-2.0 (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libibus-1.0-5:amd64.
# Preparing to unpack .../27-libibus-1.0-5_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking libibus-1.0-5:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package gir1.2-ibus-1.0:amd64.
# Preparing to unpack .../28-gir1.2-ibus-1.0_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking gir1.2-ibus-1.0:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package libarchive-cpio-perl.
# Preparing to unpack .../29-libarchive-cpio-perl_0.10-1_all.deb ...
# Unpacking libarchive-cpio-perl (0.10-1) ...
# Selecting previously unselected package libatk1.0-dev:amd64.
# Preparing to unpack .../30-libatk1.0-dev_2.28.1-1_amd64.deb ...
# Unpacking libatk1.0-dev:amd64 (2.28.1-1) ...
# Selecting previously unselected package libaudio2:amd64.
# Preparing to unpack .../31-libaudio2_1.9.4-6_amd64.deb ...
# Unpacking libaudio2:amd64 (1.9.4-6) ...
# Selecting previously unselected package libcairo-script-interpreter2:amd64.
# Preparing to unpack .../32-libcairo-script-interpreter2_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libpixman-1-dev:amd64.
# Preparing to unpack .../33-libpixman-1-dev_0.34.0-2_amd64.deb ...
# Unpacking libpixman-1-dev:amd64 (0.34.0-2) ...
# Selecting previously unselected package libxcb-shm0-dev:amd64.
# Preparing to unpack .../34-libxcb-shm0-dev_1.13-2~ubuntu18.04_amd64.deb ...
# Unpacking libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Selecting previously unselected package libcairo2-dev:amd64.
# Preparing to unpack .../35-libcairo2-dev_1.15.10-2ubuntu0.1_amd64.deb ...
# Unpacking libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Selecting previously unselected package libcapnp-0.6.1:amd64.
# Preparing to unpack .../36-libcapnp-0.6.1_0.6.1-1ubuntu1_amd64.deb ...
# Unpacking libcapnp-0.6.1:amd64 (0.6.1-1ubuntu1) ...
# Selecting previously unselected package libdbus-1-dev:amd64.
# Preparing to unpack .../37-libdbus-1-dev_1.12.2-1ubuntu1.2_amd64.deb ...
# Unpacking libdbus-1-dev:amd64 (1.12.2-1ubuntu1.2) ...
# Selecting previously unselected package libfluidsynth1:amd64.
# Preparing to unpack .../38-libfluidsynth1_1.1.9-1_amd64.deb ...
# Unpacking libfluidsynth1:amd64 (1.1.9-1) ...
# Selecting previously unselected package libfluidsynth-dev:amd64.
# Preparing to unpack .../39-libfluidsynth-dev_1.1.9-1_amd64.deb ...
# Unpacking libfluidsynth-dev:amd64 (1.1.9-1) ...
# Selecting previously unselected package libgdk-pixbuf2.0-dev.
# Preparing to unpack .../40-libgdk-pixbuf2.0-dev_2.36.11-2_amd64.deb ...
# Unpacking libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Selecting previously unselected package libgme-dev:amd64.
# Preparing to unpack .../41-libgme-dev_0.6.2-1_amd64.deb ...
# Unpacking libgme-dev:amd64 (0.6.2-1) ...
# Selecting previously unselected package libpango1.0-dev.
# Preparing to unpack .../42-libpango1.0-dev_1.40.14-1ubuntu0.1_amd64.deb ...
# Unpacking libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Selecting previously unselected package x11proto-xinerama-dev.
# Preparing to unpack .../43-x11proto-xinerama-dev_2018.4-4_all.deb ...
# Unpacking x11proto-xinerama-dev (2018.4-4) ...
# Selecting previously unselected package libxinerama-dev:amd64.
# Preparing to unpack .../44-libxinerama-dev_2%3a1.1.3-1_amd64.deb ...
# Unpacking libxinerama-dev:amd64 (2:1.1.3-1) ...
# Selecting previously unselected package x11proto-randr-dev.
# Preparing to unpack .../45-x11proto-randr-dev_2018.4-4_all.deb ...
# Unpacking x11proto-randr-dev (2018.4-4) ...
# Selecting previously unselected package libxrandr-dev:amd64.
# Preparing to unpack .../46-libxrandr-dev_2%3a1.5.1-1_amd64.deb ...
# Unpacking libxrandr-dev:amd64 (2:1.5.1-1) ...
# Selecting previously unselected package libxcursor-dev:amd64.
# Preparing to unpack .../47-libxcursor-dev_1%3a1.1.15-1_amd64.deb ...
# Unpacking libxcursor-dev:amd64 (1:1.1.15-1) ...
# Selecting previously unselected package x11proto-composite-dev.
# Preparing to unpack .../48-x11proto-composite-dev_1%3a2018.4-4_all.deb ...
# Unpacking x11proto-composite-dev (1:2018.4-4) ...
# Selecting previously unselected package libxcomposite-dev:amd64.
# Preparing to unpack .../49-libxcomposite-dev_1%3a0.4.4-2_amd64.deb ...
# Unpacking libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Selecting previously unselected package libxml2-utils.
# Preparing to unpack .../50-libxml2-utils_2.9.4+dfsg1-6.1ubuntu1.3_amd64.deb ...
# Unpacking libxml2-utils (2.9.4+dfsg1-6.1ubuntu1.3) ...
# Selecting previously unselected package libgtk2.0-dev.
# Preparing to unpack .../51-libgtk2.0-dev_2.24.32-1ubuntu1_amd64.deb ...
# Unpacking libgtk2.0-dev (2.24.32-1ubuntu1) ...
# Selecting previously unselected package libibus-1.0-dev:amd64.
# Preparing to unpack .../52-libibus-1.0-dev_1.5.17-3ubuntu5.3_amd64.deb ...
# Unpacking libibus-1.0-dev:amd64 (1.5.17-3ubuntu5.3) ...
# Selecting previously unselected package libsys-hostname-long-perl.
# Preparing to unpack .../53-libsys-hostname-long-perl_1.5-1_all.deb ...
# Unpacking libsys-hostname-long-perl (1.5-1) ...
# Selecting previously unselected package libmail-sendmail-perl.
# Preparing to unpack .../54-libmail-sendmail-perl_0.80-1_all.deb ...
# Unpacking libmail-sendmail-perl (0.80-1) ...
# Selecting previously unselected package libmircore1:amd64.
# Preparing to unpack .../55-libmircore1_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircore1:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircommon7:amd64.
# Preparing to unpack .../56-libmircommon7_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libprotobuf-lite10:amd64.
# Preparing to unpack .../57-libprotobuf-lite10_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libmirprotobuf3:amd64.
# Preparing to unpack .../58-libmirprotobuf3_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmirclient9:amd64.
# Preparing to unpack .../59-libmirclient9_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircore-dev:amd64.
# Preparing to unpack .../60-libmircore-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircore-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libprotobuf-dev:amd64.
# Preparing to unpack .../61-libprotobuf-dev_3.0.0-9.1ubuntu1_amd64.deb ...
# Unpacking libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Selecting previously unselected package libxkbcommon-dev:amd64.
# Preparing to unpack .../62-libxkbcommon-dev_0.8.2-1~ubuntu18.04.1_amd64.deb ...
# Unpacking libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Selecting previously unselected package libmircommon-dev:amd64.
# Preparing to unpack .../63-libmircommon-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircookie2:amd64.
# Preparing to unpack .../64-libmircookie2_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircookie2:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmircookie-dev:amd64.
# Preparing to unpack .../65-libmircookie-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libmirclient-dev:amd64.
# Preparing to unpack .../66-libmirclient-dev_0.31.1-0ubuntu1_amd64.deb ...
# Unpacking libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Selecting previously unselected package libopenal-dev:amd64.
# Preparing to unpack .../67-libopenal-dev_1%3a1.18.2-2_amd64.deb ...
# Unpacking libopenal-dev:amd64 (1:1.18.2-2) ...
# Selecting previously unselected package libpulse-mainloop-glib0:amd64.
# Preparing to unpack .../68-libpulse-mainloop-glib0_1%3a11.1-1ubuntu7.10_amd64.deb ...
# Unpacking libpulse-mainloop-glib0:amd64 (1:11.1-1ubuntu7.10) ...
# Selecting previously unselected package libpulse-dev:amd64.
# Preparing to unpack .../69-libpulse-dev_1%3a11.1-1ubuntu7.10_amd64.deb ...
# Unpacking libpulse-dev:amd64 (1:11.1-1ubuntu7.10) ...
# Selecting previously unselected package libsndio-dev:amd64.
# Preparing to unpack .../70-libsndio-dev_1.1.0-3_amd64.deb ...
# Unpacking libsndio-dev:amd64 (1.1.0-3) ...
# Selecting previously unselected package libudev-dev:amd64.
# Preparing to unpack .../71-libudev-dev_237-3ubuntu10.42_amd64.deb ...
# Unpacking libudev-dev:amd64 (237-3ubuntu10.42) ...
# Selecting previously unselected package libxv-dev:amd64.
# Preparing to unpack .../72-libxv-dev_2%3a1.0.11-1_amd64.deb ...
# Unpacking libxv-dev:amd64 (2:1.0.11-1) ...
# Selecting previously unselected package libsdl2-dev:amd64.
# Preparing to unpack .../73-libsdl2-dev_2.0.8+dfsg1-1ubuntu1.18.04.4_amd64.deb ...
# Unpacking libsdl2-dev:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# Selecting previously unselected package libwildmidi-config.
# Preparing to unpack .../74-libwildmidi-config_0.4.2-1_all.deb ...
# Unpacking libwildmidi-config (0.4.2-1) ...
# Selecting previously unselected package libwildmidi2:amd64.
# Preparing to unpack .../75-libwildmidi2_0.4.2-1_amd64.deb ...
# Unpacking libwildmidi2:amd64 (0.4.2-1) ...
# Selecting previously unselected package libwildmidi-dev.
# Preparing to unpack .../76-libwildmidi-dev_0.4.2-1_amd64.deb ...
# Unpacking libwildmidi-dev (0.4.2-1) ...
# Selecting previously unselected package nasm.
# Preparing to unpack .../77-nasm_2.13.02-0.1_amd64.deb ...
# Unpacking nasm (2.13.02-0.1) ...
# Selecting previously unselected package timidity.
# Preparing to unpack .../78-timidity_2.13.2-41_amd64.deb ...
# Unpacking timidity (2.13.2-41) ...
# Selecting previously unselected package timidity-daemon.
# Preparing to unpack .../79-timidity-daemon_2.13.2-41_all.deb ...
# Unpacking timidity-daemon (2.13.2-41) ...
# Setting up libdbus-1-dev:amd64 (1.12.2-1ubuntu1.2) ...
# Setting up libxcursor-dev:amd64 (1:1.1.15-1) ...
# Setting up gir1.2-atk-1.0:amd64 (2.28.1-1) ...
# Setting up libxkbcommon-dev:amd64 (0.8.2-1~ubuntu18.04.1) ...
# Setting up libpulse-mainloop-glib0:amd64 (1:11.1-1ubuntu7.10) ...
# Setting up libpulse-dev:amd64 (1:11.1-1ubuntu7.10) ...
# Setting up libarchive-zip-perl (1.60-1ubuntu0.1) ...
# Setting up libmircore-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libtimedate-perl (2.3000-2) ...
# Setting up libcairo-script-interpreter2:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up libsigsegv2:amd64 (2.12-1) ...
# Setting up libgme-dev:amd64 (0.6.2-1) ...
# Setting up gir1.2-freedesktop:amd64 (1.56.1-1) ...
# Setting up libsndio-dev:amd64 (1.1.0-3) ...
# Setting up libxcb-shm0-dev:amd64 (1.13-2~ubuntu18.04) ...
# Setting up libpangoxft-1.0-0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libxml2-utils (2.9.4+dfsg1-6.1ubuntu1.3) ...
# Setting up libarchive-cpio-perl (0.10-1) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-2) ...
# Setting up libatk1.0-dev:amd64 (2.28.1-1) ...
# Setting up gettext-base (0.19.8.1-6ubuntu0.3) ...
# Setting up m4 (1.4.18-1) ...
# Setting up libmagic-mgc (1:5.32-2ubuntu0.4) ...
# Setting up gir1.2-pango-1.0:amd64 (1.40.14-1ubuntu0.1) ...
# Setting up libmagic1:amd64 (1:5.32-2ubuntu0.4) ...
# Setting up libopenal-dev:amd64 (1:1.18.2-2) ...
# Setting up libsys-hostname-long-perl (1.5-1) ...
# Setting up libwildmidi-config (0.4.2-1) ...
# Setting up libmircookie2:amd64 (0.31.1-0ubuntu1) ...
# Setting up libgdk-pixbuf2.0-dev (2.36.11-2) ...
# Setting up libmail-sendmail-perl (0.80-1) ...
# Setting up x11proto-xinerama-dev (2018.4-4) ...
# Setting up autotools-dev (20180224.1) ...
# Setting up libpixman-1-dev:amd64 (0.34.0-2) ...
# Setting up x11proto-randr-dev (2018.4-4) ...
# Setting up libxinerama-dev:amd64 (2:1.1.3-1) ...
# Setting up libxv-dev:amd64 (2:1.0.11-1) ...
# Setting up nasm (2.13.02-0.1) ...
# Setting up libcapnp-0.6.1:amd64 (0.6.1-1ubuntu1) ...
# Setting up libibus-1.0-5:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up libmircore1:amd64 (0.31.1-0ubuntu1) ...
# Setting up freepats (20060219-1) ...
# Setting up libprotobuf-lite10:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up libudev-dev:amd64 (237-3ubuntu10.42) ...
# Setting up libfluidsynth1:amd64 (1.1.9-1) ...
# Setting up x11proto-composite-dev (1:2018.4-4) ...
# Setting up autopoint (0.19.8.1-6ubuntu0.3) ...
# Setting up libaudio2:amd64 (1.9.4-6) ...
# Setting up libfile-stripnondeterminism-perl (0.040-1.1~build1) ...
# Setting up gir1.2-gtk-2.0 (2.24.32-1ubuntu1) ...
# Setting up gir1.2-ibus-1.0:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up libxrandr-dev:amd64 (2:1.5.1-1) ...
# Setting up libcairo2-dev:amd64 (1.15.10-2ubuntu0.1) ...
# Setting up gettext (0.19.8.1-6ubuntu0.3) ...
# Setting up libxcomposite-dev:amd64 (1:0.4.4-2) ...
# Setting up libmirprotobuf3:amd64 (0.31.1-0ubuntu1) ...
# Setting up libprotobuf-dev:amd64 (3.0.0-9.1ubuntu1) ...
# Setting up autoconf (2.69-11) ...
# Setting up libmircookie-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libwildmidi2:amd64 (0.4.2-1) ...
# Setting up file (1:5.32-2ubuntu0.4) ...
# Setting up intltool-debian (0.35.0+20060710.4) ...
# Setting up libibus-1.0-dev:amd64 (1.5.17-3ubuntu5.3) ...
# Setting up automake (1:1.15.1-3ubuntu2) ...
# update-alternatives: using /usr/bin/automake-1.15 to provide /usr/bin/automake (automake) in auto mode
# Setting up libmircommon7:amd64 (0.31.1-0ubuntu1) ...
# Setting up libpango1.0-dev (1.40.14-1ubuntu0.1) ...
# Setting up libfluidsynth-dev:amd64 (1.1.9-1) ...
# Setting up timidity (2.13.2-41) ...
# Setting up libtool (2.4.6-2) ...
# Setting up po-debconf (1.0.20) ...
# Setting up libwildmidi-dev (0.4.2-1) ...
# Setting up libgtk2.0-dev (2.24.32-1ubuntu1) ...
# Setting up libmirclient9:amd64 (0.31.1-0ubuntu1) ...
# Setting up libmircommon-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up timidity-daemon (2.13.2-41) ...
# Adding group timidity....done
# Adding system user timidity....done
# Adding user `timidity' to group `audio' ...
# Adding user timidity to group audio
# Done.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of stop.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up libmirclient-dev:amd64 (0.31.1-0ubuntu1) ...
# Setting up libsdl2-dev:amd64 (2.0.8+dfsg1-1ubuntu1.18.04.4) ...
# Setting up debhelper (11.1.6ubuntu2) ...
# Setting up dh-autoreconf (17) ...
# Setting up dh-strip-nondeterminism (0.040-1.1~build1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.6/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Processing triggers for systemd (237-3ubuntu10.42) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libboost-all-dev is already the newest version (1.65.1.0ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 72 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'liblua5.1-0-dev' instead of 'liblua5.1-dev'
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libtool-bin
# The following NEW packages will be installed:
#   liblua5.1-0-dev libtool-bin
# 0 upgraded, 2 newly installed, 0 to remove and 72 not upgraded.
# Need to get 198 kB of archives.
# After this operation, 1,188 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 liblua5.1-0-dev amd64 5.1.5-8.1build2 [119 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 libtool-bin amd64 2.4.6-2 [79.5 kB]
# Fetched 198 kB in 1s (217 kB/s)
# Selecting previously unselected package liblua5.1-0-dev:amd64.
# (Reading database ... 147605 files and directories currently installed.)
# Preparing to unpack .../liblua5.1-0-dev_5.1.5-8.1build2_amd64.deb ...
# Unpacking liblua5.1-0-dev:amd64 (5.1.5-8.1build2) ...
# Selecting previously unselected package libtool-bin.
# Preparing to unpack .../libtool-bin_2.4.6-2_amd64.deb ...
# Unpacking libtool-bin (2.4.6-2) ...
# Setting up libtool-bin (2.4.6-2) ...
# Setting up liblua5.1-0-dev:amd64 (5.1.5-8.1build2) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgtk2.0-dev is already the newest version (2.24.32-1ubuntu1).
# python-numpy is already the newest version (1:1.13.3-2ubuntu1).
# python-numpy set to manually installed.
# libboost-all-dev is already the newest version (1.65.1.0ubuntu1).
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# git is already the newest version (1:2.17.1-1ubuntu0.7).
# libsdl2-dev is already the newest version (2.0.8+dfsg1-1ubuntu1.18.04.4).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-440
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 72 not upgraded.
# Cloning into 'vizdoomgym'...
# remote: Enumerating objects: 251, done.
# remote: Counting objects: 100% (251/251), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 558 (delta 129), reused 144 (delta 69), pack-reused 307
# Receiving objects: 100% (558/558), 179.04 KiB | 9.42 MiB/s, done.
# Resolving deltas: 100% (295/295), done.
# Obtaining file:///content/vizdoomgym
# Requirement already satisfied: gym in /usr/local/lib/python3.6/dist-packages (from vizdoomgym==1.0) (0.17.2)
# Collecting vizdoom@ https://github.com/mwydmuch/ViZDoom/tarball/1.1.8pre
#   Downloading https://github.com/mwydmuch/ViZDoom/tarball/1.1.8pre
#      / 6.1MB 7.3MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from vizdoomgym==1.0) (1.18.5)
# Collecting pre-commit
#   Downloading https://files.pythonhosted.org/packages/2c/88/966da62ec93566c221bf8bf0c1b7f04e70f002960a98da05d3fd8bc3b2e7/pre_commit-2.7.1-py2.py3-none-any.whl (171kB)
#      |████████████████████████████████| 174kB 4.6MB/s
# Requirement already satisfied: cloudpickle<1.4.0,>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym->vizdoomgym==1.0) (1.3.0)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.6/dist-packages (from gym->vizdoomgym==1.0) (1.5.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym->vizdoomgym==1.0) (1.4.1)
# Collecting nodeenv>=0.11.1
#   Downloading https://files.pythonhosted.org/packages/ae/d0/efdf54539948315cc76e5a66b709212963101d002822c3b54369dbf9b5e0/nodeenv-1.5.0-py2.py3-none-any.whl
# Collecting identify>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/2f/9b/a5104b4747b26d750ce4f8069aed7bb7bc64d81d03cdfe4280e39fba99c1/identify-1.4.30-py2.py3-none-any.whl (97kB)
#      |████████████████████████████████| 102kB 9.2MB/s
# Collecting pyyaml>=5.1
#   Downloading https://files.pythonhosted.org/packages/64/c2/b80047c7ac2478f9501676c988a5411ed5572f35d1beff9cae07d321512c/PyYAML-5.3.1.tar.gz (269kB)
#      |████████████████████████████████| 276kB 14.3MB/s
# Collecting virtualenv>=20.0.8
#   Downloading https://files.pythonhosted.org/packages/12/51/36c685ff2c1b2f7b4b5db29f3153159102ae0e0adaff3a26fd1448232e06/virtualenv-20.0.31-py2.py3-none-any.whl (4.9MB)
#      |████████████████████████████████| 4.9MB 18.6MB/s
# Collecting cfgv>=2.0.0
#   Downloading https://files.pythonhosted.org/packages/45/cd/3878c9248e59e5e2ebd0dc741ab984b18d86e7283ae9b127b05fc287d239/cfgv-3.2.0-py2.py3-none-any.whl
# Requirement already satisfied: toml in /usr/local/lib/python3.6/dist-packages (from pre-commit->vizdoomgym==1.0) (0.10.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from pre-commit->vizdoomgym==1.0) (1.7.0)
# Collecting importlib-resources; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/ba/03/0f9595c0c2ef12590877f3c47e5f579759ce5caf817f8256d5dcbd8a1177/importlib_resources-3.0.0-py2.py3-none-any.whl
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym->vizdoomgym==1.0) (0.16.0)
# Collecting distlib<1,>=0.3.1
#   Downloading https://files.pythonhosted.org/packages/f5/0a/490fa011d699bb5a5f3a0cf57de82237f52a6db9d40f33c53b2736c9a1f9/distlib-0.3.1-py2.py3-none-any.whl (335kB)
#      |████████████████████████████████| 337kB 53.4MB/s
# Requirement already satisfied: six<2,>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from virtualenv>=20.0.8->pre-commit->vizdoomgym==1.0) (1.15.0)
# Collecting appdirs<2,>=1.4.3
#   Downloading https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl
# Requirement already satisfied: filelock<4,>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from virtualenv>=20.0.8->pre-commit->vizdoomgym==1.0) (3.0.12)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->pre-commit->vizdoomgym==1.0) (3.1.0)
# Building wheels for collected packages: vizdoom, pyyaml
#   Building wheel for vizdoom (setup.py) ... done
#   Created wheel for vizdoom: filename=vizdoom-1.1.8-cp36-none-any.whl size=14293709 sha256=e53673f199dbbdd9d5fc829e4c83f2e1d080ef0a00ce1bc6ebe9d3e806558377
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0r1gkju_/wheels/1b/e8/11/2c308b2447cf5421008b1de5216938fb990878fead56eb135d
#   Building wheel for pyyaml (setup.py) ... done
#   Created wheel for pyyaml: filename=PyYAML-5.3.1-cp36-cp36m-linux_x86_64.whl size=44619 sha256=4cc8f85bd16cd8461800a39d0861e4a52cc208d84ff4e883bae26a8b7d3249a4
#   Stored in directory: /root/.cache/pip/wheels/a7/c1/ea/cf5bd31012e735dc1dfea3131a2d5eae7978b251083d6247bd
# Successfully built vizdoom pyyaml
# Installing collected packages: vizdoom, nodeenv, identify, pyyaml, importlib-resources, distlib, appdirs, virtualenv, cfgv, pre-commit, vizdoomgym
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Running setup.py develop for vizdoomgym
# Successfully installed appdirs-1.4.4 cfgv-3.2.0 distlib-0.3.1 identify-1.4.30 importlib-resources-3.0.0 nodeenv-1.5.0 pre-commit-2.7.1 pyyaml-5.3.1 virtualenv-20.0.31 vizdoom-1.1.8 vizdoomgym

# %%
# !pip install av
# Out:
# Collecting av
#   Downloading https://files.pythonhosted.org/packages/9e/62/9a992be76f8e13ce0e3a24a838191b546805545116f9fc869bd11bd21b5f/av-8.0.2-cp36-cp36m-manylinux2010_x86_64.whl (36.9MB)
#      |████████████████████████████████| 36.9MB 82kB/s
# Installing collected packages: av
# Successfully installed av-8.0.2

# %%
# Evaluation code
#Visualization cobe for running within Colab

# Install dependencies first for graphics visualization within Colaboratory
# !pip install folium==0.2.1
#remove " > /dev/null 2>&1" to see what is going on under the hood
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1
# Out:
# Collecting folium==0.2.1
#   Downloading https://files.pythonhosted.org/packages/72/dd/75ced7437bfa7cb9a88b96ee0177953062803c3b4cde411a97d98c35adaf/folium-0.2.1.tar.gz (69kB)
#      |████████████████████████████████| 71kB 3.3MB/s
# Requirement already satisfied: Jinja2 in /usr/local/lib/python3.6/dist-packages (from folium==0.2.1) (2.11.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2->folium==0.2.1) (1.1.1)
# Building wheels for collected packages: folium
#   Building wheel for folium (setup.py) ... done
#   Created wheel for folium: filename=folium-0.2.1-cp36-none-any.whl size=79980 sha256=533a32952b6f3cc344001328b4ec2cda7a0b8896170f6d3bbe96a33d7c1deb8d
#   Stored in directory: /root/.cache/pip/wheels/b8/09/f0/52d2ef419c2aaf4fb149f92a33e0008bdce7ae816f0dd8f0c5
# Successfully built folium
# Installing collected packages: folium
#   Found existing installation: folium 0.8.3
#     Uninstalling folium-0.8.3:
#       Successfully uninstalled folium-0.8.3
# Successfully installed folium-0.2.1
# Collecting setuptools
#   Downloading https://files.pythonhosted.org/packages/7d/53/cd47a7799c5e82de7e408fecd72266dcc6cd7be32629b6022d4d6d91a2fc/setuptools-50.2.0-py3-none-any.whl (784kB)
#      |████████████████████████████████| 788kB 4.8MB/s
# Installing collected packages: setuptools
#   Found existing installation: setuptools 49.6.0
#     Uninstalling setuptools-49.6.0:
#       Successfully uninstalled setuptools-49.6.0
# Successfully installed setuptools-50.2.0

# %% [markdown]
# Inspect the environment. You'll need to restart the runtime for it to work

# %%
#Check the environment. You'll need to restart the runtime for it to work
import gym
import vizdoomgym
!
env = gym.make('VizdoomDefendLine-v0')

# use like a normal Gym environment
state = env.reset()
state, reward, done, info = env.step(env.action_space.sample())
print(state.shape)
# env.render()
env.close()
# Out:
# Cannot connect to "None"
# (240, 320, 3)

# %%
import gym
import vizdoomgym

env = gym.make('VizdoomDefendLine-v0')
n_outputs = env.action_space.n
print(n_outputs)


observation = env.reset()

import matplotlib.pyplot as plt


for i in range(22):
  
  if i > 20:
    print(observation.shape)
    plt.imshow(observation)
    plt.show()

  observation, _, _, _ = env.step(1)
# Out:
# 3
# (240, 320, 3)

# %%
import numpy as np


from collections import deque, Counter
import random
from datetime import datetime
from __future__ import division
from __future__ import print_function
from vizdoom import *
import itertools as it
from random import sample, randint, random
from time import time, sleep
import numpy as np
import skimage.color, skimage.transform
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.autograd import Variable
from tqdm import trange

# %% [markdown]
# ## Preprocessing
#
# We'll define a set of wrappers to modify our gym environment to provide preprocessed observations.
#
# We’ll start defining a wrapper to repeat every action for a number of frames, and perform an element-wise maxima in order to increase the intensity of any actions.
#
# Next, we define the preprocessing function for our observations. We’ll make our environment symmetrical by converting it into the Box space, swapping the channel integer to the front of our tensor, and resizing it to an area of (84,84) from its original (320,480) resolution. We’ll also greyscale our environment, and normalize the entire image by dividing by a constant.
#
# Next, we create a wrapper to handle frame-stacking. The objective here is to help capture motion and direction from stacking frames, by stacking several frames together as a single batch. In this way, we can capture position, translation, velocity, and acceleration of the elements in the environment. With stacking, our input adopts a shape of (4,84,84,1).

# %%
#11072020 Utililities support class

import collections
import cv2
import numpy as np
import matplotlib.pyplot as plt
import gym

def plot_learning_curve(x, scores, epsilons, filename, lines=None):
    fig=plt.figure()
    ax=fig.add_subplot(111, label="1")
    ax2=fig.add_subplot(111, label="2", frame_on=False)

    ax.plot(x, epsilons, color="C0")
    ax.set_xlabel("Episodes", color="C0")
    ax.set_ylabel("Epsilon", color="C0")
    ax.tick_params(axis='x', colors="C0")
    ax.tick_params(axis='y', colors="C0")

    N = len(scores)
    running_avg = np.empty(N)
    for t in range(N):
	    running_avg[t] = np.mean(scores[max(0, t-20):(t+1)])

    ax2.scatter(x, running_avg, color="C1")
    ax2.axes.get_xaxis().set_visible(False)
    ax2.yaxis.tick_right()
    ax2.set_ylabel('Average Score', color="C1")
    ax2.yaxis.set_label_position('right')
    ax2.tick_params(axis='y', colors="C1")

    if lines is not None:
        for line in lines:
            plt.axvline(x=line)

    

class RepeatActionAndMaxFrame(gym.Wrapper):
  #input: environment, repeat
  #init frame buffer as an array of zeros in shape 2 x the obs space
    def __init__(self, env=None, repeat=4, clip_reward=False, no_ops=0,
                 fire_first=False):
        super(RepeatActionAndMaxFrame, self).__init__(env)
        self.repeat = repeat
        self.shape = env.observation_space.low.shape
        self.frame_buffer = np.zeros_like((2, self.shape))
        self.clip_reward = clip_reward
        self.no_ops = no_ops
        self.fire_first = fire_first

    def step(self, action):
        t_reward = 0.0
        done = False
        for i in range(self.repeat):
            obs, reward, done, info = self.env.step(action)
            if self.clip_reward:
                reward = np.clip(np.array([reward]), -1, 1)[0]
            t_reward += reward
            idx = i % 2
            self.frame_buffer[idx] = obs
            if done:
                break

        max_frame = np.maximum(self.frame_buffer[0], self.frame_buffer[1])
        return max_frame, t_reward, done, info

    def reset(self):
        obs = self.env.reset()
        no_ops = np.random.randint(self.no_ops)+1 if self.no_ops > 0 else 0
        for _ in range(no_ops):
            _, _, done, _ = self.env.step(0)
            if done:
                self.env.reset()
        #Fire first seems quite useless, probably meant for something like space invader
        if self.fire_first:
            assert self.env.unwrapped.get_action_meanings()[1] == 'FIRE'
            obs, _, _, _ = self.env.step(1)

        self.frame_buffer = np.zeros_like((2,self.shape))
        self.frame_buffer[0] = obs

        return obs

class PreprocessFrame(gym.ObservationWrapper):
  #set shape by swapping channels axis
	#set observation space to new shape using gym.spaces.Box (0 to 1.0)
    def __init__(self, shape, env=None):
        super(PreprocessFrame, self).__init__(env)
        self.shape = (shape[2], shape[0], shape[1])
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0,
                                    shape=self.shape, dtype=np.float32)

    def observation(self, obs):
        new_frame = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)
        resized_screen = cv2.resize(new_frame, self.shape[1:],
                                    interpolation=cv2.INTER_AREA)
        new_obs = np.array(resized_screen, dtype=np.uint8).reshape(self.shape)
        new_obs = new_obs / 255.0

        return new_obs

class StackFrames(gym.ObservationWrapper):
  #init the new obs space (gym.spaces.Box) low & high bounds as repeat of n_steps. These should have been defined for vizdooom
  #WE may not have to use boxes in ur final model. But we can keep it for now
  #Create a return a stack of observations
    def __init__(self, env, repeat):
        super(StackFrames, self).__init__(env)
        self.observation_space = gym.spaces.Box(
                            env.observation_space.low.repeat(repeat, axis=0),
                            env.observation_space.high.repeat(repeat, axis=0),
                            dtype=np.float32)
        self.stack = collections.deque(maxlen=repeat)

    def reset(self):
        self.stack.clear()
        observation = self.env.reset()
        for _ in range(self.stack.maxlen):
            self.stack.append(observation)

        return np.array(self.stack).reshape(self.observation_space.low.shape)

    def observation(self, observation):
        self.stack.append(observation)

        return np.array(self.stack).reshape(self.observation_space.low.shape)

#This shape command should not be 84,84,1 take a look at what we went with in our TF example
#Note how fire_first is false here, probably useless in the context of Pong
def make_env(env_name, shape=(84,84,1), repeat=4, clip_rewards=False,
             no_ops=0, fire_first=False):
    env = gym.make(env_name)
    env = PreprocessFrame(shape, env)
    env = RepeatActionAndMaxFrame(env, repeat, clip_rewards, no_ops, fire_first)
    
    env = StackFrames(env, repeat)

    return env

# %% [markdown]
# Next, let’s define our model, a deep Q-network. This is essentially a three layer convolutional network that takes preprocessed input obserations, with the generated flattened output fed to a fully-connected layer, which is then split into two streams, one representing the state-value and one representing the actin space of the game (between 4 and 18 in the Atari games)

# %%
import os
import torch as T
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import numpy as np

class DeepQNetwork(nn.Module):
    def __init__(self, lr, n_actions, name, input_dims, chkpt_dir):
        super(DeepQNetwork, self).__init__()
        self.checkpoint_dir = chkpt_dir
        self.checkpoint_file = os.path.join(self.checkpoint_dir, name)

        self.conv1 = nn.Conv2d(input_dims[0], 32, 8, stride=4)
        self.conv2 = nn.Conv2d(32, 64, 4, stride=2)
        self.conv3 = nn.Conv2d(64, 64, 3, stride=1)

        fc_input_dims = self.calculate_conv_output_dims(input_dims)

        self.fc1 = nn.Linear(fc_input_dims,1024)
        self.fc2 = nn.Linear(1024, 512)
        #Here we split the linear layer into the State and Advantage streams
        self.V = nn.Linear(512, 1)
        self.A = nn.Linear(512, n_actions)

        self.optimizer = optim.RMSprop(self.parameters(), lr=lr)

        self.loss = nn.MSELoss()
        self.device = T.device('cuda:0' if T.cuda.is_available() else 'cpu')
        self.to(self.device)

    def calculate_conv_output_dims(self, input_dims):
        state = T.zeros(1, *input_dims)
        dims = self.conv1(state)
        dims = self.conv2(dims)
        dims = self.conv3(dims)
        return int(np.prod(dims.size()))

    def forward(self, state):
        conv1 = F.relu(self.conv1(state))
        conv2 = F.relu(self.conv2(conv1))
        conv3 = F.relu(self.conv3(conv2))
        # conv3 shape is BS x n_filters x H x W
        conv_state = conv3.view(conv3.size()[0], -1)
        # conv_state shape is BS x (n_filters * H * W)
        flat1 = F.relu(self.fc1(conv_state))
        flat2 = F.relu(self.fc2(flat1))

        V = self.V(flat2)
        A = self.A(flat2)

        return V, A

    def save_checkpoint(self):
        print('... saving checkpoint ...')
        T.save(self.state_dict(), self.checkpoint_file)

    def load_checkpoint(self):
        print('... loading checkpoint ...')
        self.load_state_dict(T.load(self.checkpoint_file))

# %% [markdown]
# ## Storing Replay Memories
#
# In this section we will create a mechanism for the agent to keep track of states, actions, rewards, new states, and the final state.
#
# All of these factors will be used in the calculation of the Target for the loss function of the DQN.
#
# For maximum flexibility of the agent the memory should accomodate states with an arbitrary shape.
#
# We should also sample from the memory uniformly, meaning each memory will have an equal probability of being sampled, and we should not repeat memories.

# %%
#11072020 New ReplayMemory Class

import numpy as np

class ReplayBuffer(object):
    def __init__(self, max_size, input_shape, n_actions):
        self.mem_size = max_size
        self.mem_cntr = 0
        self.state_memory = np.zeros((self.mem_size, *input_shape),
                                     dtype=np.float32)
        self.new_state_memory = np.zeros((self.mem_size, *input_shape),
                                         dtype=np.float32)

        self.action_memory = np.zeros(self.mem_size, dtype=np.int64)
        self.reward_memory = np.zeros(self.mem_size, dtype=np.float32)
        self.terminal_memory = np.zeros(self.mem_size, dtype=np.bool)

    #Identify index and store  the the current SARSA into batch memory
    def store_transition(self, state, action, reward, state_, done):
        index = self.mem_cntr % self.mem_size
        self.state_memory[index] = state
        self.new_state_memory[index] = state_
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.terminal_memory[index] = done
        self.mem_cntr += 1

    def sample_buffer(self, batch_size):
        max_mem = min(self.mem_cntr, self.mem_size)
        batch = np.random.choice(max_mem, batch_size, replace=False)
        #I believe batch here is creating a list limit that is acquired through max_mem, whihch we use to subselect memory
        states = self.state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        states_ = self.new_state_memory[batch]
        terminal = self.terminal_memory[batch]

        return states, actions, rewards, states_, terminal

# %% [markdown]
# ## Agent Class
#
# Our agent be using an epsilon greedy policy with a decaying exploration rate, in order to maximize exploitation over time. To learn to predict state-action-values that maximize our cumulative reward, our agent will be using the discounted future rewards obtained by sampling the memory.
#
# You’’ll notice that we initialize two copies of our DQN as part of our agent, with methods to copy weight parameters of our original network into a target network. This dual-network approach allows us to generate data during the training process using an existing policy while still optimizing our parameters for the next policy iteration, reducing loss oscillations. We will leverage this for our DDQN implementation.
#
# For reference, the original vanilla DQN update function is shown below:
#
# ![image.png](data:image/png;base64,...)

# %%
#11072020 New self-contained DQNAgent Class

import numpy as np
import torch as T
#from deep_q_network import DeepQNetwork
#from replay_memory import ReplayBuffer

class DuelDQNAgent(object):
    def __init__(self, gamma, epsilon, lr, n_actions, input_dims,
                 mem_size, batch_size, eps_min=0.01, eps_dec=5e-7,
                 replace=1000, algo=None, env_name=None, chkpt_dir='tmp/dqn'):
        self.gamma = gamma
        self.epsilon = epsilon
        self.lr = lr
        self.n_actions = n_actions
        self.input_dims = input_dims
        self.batch_size = batch_size
        self.eps_min = eps_min
        self.eps_dec = eps_dec
        self.replace_target_cnt = replace
        self.algo = algo
        self.env_name = env_name
        self.chkpt_dir = chkpt_dir
        self.action_space = [i for i in range(n_actions)]
        self.learn_step_counter = 0

        self.memory = ReplayBuffer(mem_size, input_dims, n_actions)

        self.q_eval = DeepQNetwork(self.lr, self.n_actions,
                                    input_dims=self.input_dims,
                                    name=self.env_name+'_'+self.algo+'_q_eval',
                                    chkpt_dir=self.chkpt_dir)

        self.q_next = DeepQNetwork(self.lr, self.n_actions,
                                    input_dims=self.input_dims,
                                    name=self.env_name+'_'+self.algo+'_q_next',
                                    chkpt_dir=self.chkpt_dir)

    #Epsilon greedy action selection
    def choose_action(self, observation):
        if np.random.random() > self.epsilon:
          # Add dimension to observation to match input_dims x batch_size by placing in list, then converting to tensor
            state = T.tensor([observation],dtype=T.float).to(self.q_eval.device)
            #As our forward function now has both state and advantage, fetch latter for actio selection
            _, advantage = self.q_eval.forward(state)
            action = T.argmax(advantage).item()
        else:
            action = np.random.choice(self.action_space)

        return action

    def store_transition(self, state, action, reward, state_, done):
        self.memory.store_transition(state, action, reward, state_, done)

    def sample_memory(self):
        state, action, reward, new_state, done = \
                                self.memory.sample_buffer(self.batch_size)

        states = T.tensor(state).to(self.q_eval.device)
        rewards = T.tensor(reward).to(self.q_eval.device)
        dones = T.tensor(done).to(self.q_eval.device)
        actions = T.tensor(action).to(self.q_eval.device)
        states_ = T.tensor(new_state).to(self.q_eval.device)

        return states, actions, rewards, states_, dones

    def replace_target_network(self):
        if self.learn_step_counter % self.replace_target_cnt == 0:
            self.q_next.load_state_dict(self.q_eval.state_dict())

    def decrement_epsilon(self):
        self.epsilon = self.epsilon - self.eps_dec \
                           if self.epsilon > self.eps_min else self.eps_min

    def save_models(self):
        self.q_eval.save_checkpoint()
        self.q_next.save_checkpoint()

    def load_models(self):
        self.q_eval.load_checkpoint()
        self.q_next.load_checkpoint()
    #Make sure you understand this line by line
    #For DDQN main difference is here - Consult the lecture to gain a stronger understanding of why things differe here
    def learn(self):

      #First check if memory is even big enough
        if self.memory.mem_cntr < self.batch_size:
            return

        self.q_eval.optimizer.zero_grad()

        #Replace target network if appropriate
        self.replace_target_network()

        states, actions, rewards, states_, dones = self.sample_memory()
        #Fetch states and advantage actions for current state using eval network
        #Also fetch the same for next state using target network
        V_s, A_s = self.q_eval.forward(states)
        V_s_, A_s_ = self.q_next.forward(states_)

        #Indices for matrix multiplication
        indices = np.arange(self.batch_size)

        #Calculate current state Q-values and next state max Q-value by aggregation, subtracting constant advantage mean
        #Along first dimension, which is action dimension, keeping original matrix dimensions
        
        #recall [indices,actions] is used to maintain array shape of (batch_size) instead of (batch_size,actions)
        #Essentilly by adding a a batch index to our vector array we ensure that calculated Q_pred is not tabular, but applicable for a batch update
        q_pred = T.add(V_s,
                        (A_s - A_s.mean(dim=1, keepdim=True)))[indices, actions]
        #For q_next, fetch max along the action dimension. 0th element, because max returns a tuple,
        #of which 0th position are values and 1st position the indices.
        q_next = T.add(V_s_,
                        (A_s_ - A_s_.mean(dim=1, keepdim=True))).max(dim=1)[0]

        q_next[dones] = 0.0
        #Build your target using the current state reward and q_next
        q_target = rewards + self.gamma*q_next

        loss = self.q_eval.loss(q_target, q_pred).to(self.q_eval.device)
        loss.backward()
        self.q_eval.optimizer.step()
        self.learn_step_counter += 1

        self.decrement_epsilon()

# %% [markdown]
# # Main Training Loop
#
# 1. For every step of a training episode, we feed an input image stack into our network to generate a probability distribution of the available actions, before using an epsilon-greedy policy to select the next action.
#
# 2. We then input this into the network, and obtain information on the next state and accompanying rewards, and store this into our buffer. We update our stack and repeat this process over a number of pre-defined steps.
#
# 3. At the end of an episode, we feed the next states into our network in order to obtain the next action. We also calculate the next reward by discounting the current one.
#
# 4. We generate our target y-values through the Q-learning update function, and train our network.
#
# 5. By minimizing the training loss, we update the network weight parameters to output improved state-action values for the next policy.

# %%
# Main thread

env = make_env('VizdoomDefendLine-v0')
best_score = -np.inf
load_checkpoint = False
n_games = 2000
agent = DuelDQNAgent(gamma=0.99, epsilon=1.0, lr=0.0001,input_dims=(env.observation_space.shape),n_actions=env.action_space.n, mem_size=5000, eps_min=0.1,batch_size=32, replace=1000, eps_dec=1e-5,chkpt_dir='/content/', algo='DuelDQNAgent',env_name='vizdoogym')

if load_checkpoint:
  agent.load_models()

fname = agent.algo + '_' + agent.env_name + '_lr' + str(agent.lr) +'_'+ str(n_games) + 'games'
figure_file = 'plots/' + fname + '.png'

n_steps = 0
scores, eps_history, steps_array = [], [], []

for i in range(n_games):
  done = False
  observation = env.reset()

  score = 0
  while not done:
    action = agent.choose_action(observation)
    observation_, reward, done, info = env.step(action)
    score += reward

    if not load_checkpoint:
      agent.store_transition(observation, action,reward, observation_, int(done))
      agent.learn()
    observation = observation_
    n_steps += 1

  scores.append(score)
  steps_array.append(n_steps)

  avg_score = np.mean(scores[-100:])
 

  if avg_score > best_score:
    best_score = avg_score
      
    
    print('Checkpoint saved at episode ', i)
    agent.save_models()

  print('Episode: ', i,'Score: ', score,' Average score: %.2f' % avg_score, 'Best average: %.2f' % best_score,'Epsilon: %.2f' % agent.epsilon, 'Steps:', n_steps)  

  eps_history.append(agent.epsilon)
  if load_checkpoint and n_steps >= 18000:
    break

#x = [i+1 for i in range(len(scores))]
# Out:
# Checkpoint saved at episode  0
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  0 Score:  9.0  Average score: 9.00 Best average: 9.00 Epsilon: 1.00 Steps: 150
# Episode:  1 Score:  2.0  Average score: 5.50 Best average: 9.00 Epsilon: 1.00 Steps: 209
# Episode:  2 Score:  8.0  Average score: 6.33 Best average: 9.00 Epsilon: 1.00 Steps: 380
# Episode:  3 Score:  13.0  Average score: 8.00 Best average: 9.00 Epsilon: 0.99 Steps: 557
# Episode:  4 Score:  7.0  Average score: 7.80 Best average: 9.00 Epsilon: 0.99 Steps: 704
# Episode:  5 Score:  4.0  Average score: 7.17 Best average: 9.00 Epsilon: 0.99 Steps: 803
# Episode:  6 Score:  8.0  Average score: 7.29 Best average: 9.00 Epsilon: 0.99 Steps: 902
# Episode:  7 Score:  2.0  Average score: 6.62 Best average: 9.00 Epsilon: 0.99 Steps: 968
# Episode:  8 Score:  10.0  Average score: 7.00 Best average: 9.00 Epsilon: 0.99 Steps: 1132
# Episode:  9 Score:  10.0  Average score: 7.30 Best average: 9.00 Epsilon: 0.99 Steps: 1349
# Episode:  10 Score:  9.0  Average score: 7.45 Best average: 9.00 Epsilon: 0.99 Steps: 1475
# Episode:  11 Score:  5.0  Average score: 7.25 Best average: 9.00 Epsilon: 0.98 Steps: 1571
# Episode:  12 Score:  9.0  Average score: 7.38 Best average: 9.00 Epsilon: 0.98 Steps: 1723
# Episode:  13 Score:  13.0  Average score: 7.79 Best average: 9.00 Epsilon: 0.98 Steps: 1897
# Episode:  14 Score:  14.0  Average score: 8.20 Best average: 9.00 Epsilon: 0.98 Steps: 2156
# Episode:  15 Score:  7.0  Average score: 8.12 Best average: 9.00 Epsilon: 0.98 Steps: 2314
# Episode:  16 Score:  7.0  Average score: 8.06 Best average: 9.00 Epsilon: 0.98 Steps: 2434
# Episode:  17 Score:  7.0  Average score: 8.00 Best average: 9.00 Epsilon: 0.97 Steps: 2572
# Episode:  18 Score:  7.0  Average score: 7.95 Best average: 9.00 Epsilon: 0.97 Steps: 2719
# Episode:  19 Score:  11.0  Average score: 8.10 Best average: 9.00 Epsilon: 0.97 Steps: 2909
# Episode:  20 Score:  4.0  Average score: 7.90 Best average: 9.00 Epsilon: 0.97 Steps: 2988
# Episode:  21 Score:  6.0  Average score: 7.82 Best average: 9.00 Epsilon: 0.97 Steps: 3111
# Episode:  22 Score:  3.0  Average score: 7.61 Best average: 9.00 Epsilon: 0.97 Steps: 3209
# Episode:  23 Score:  4.0  Average score: 7.46 Best average: 9.00 Epsilon: 0.97 Steps: 3306
# Episode:  24 Score:  6.0  Average score: 7.40 Best average: 9.00 Epsilon: 0.97 Steps: 3436
# Episode:  25 Score:  5.0  Average score: 7.31 Best average: 9.00 Epsilon: 0.96 Steps: 3562
# Episode:  26 Score:  5.0  Average score: 7.22 Best average: 9.00 Epsilon: 0.96 Steps: 3681
# Episode:  27 Score:  8.0  Average score: 7.25 Best average: 9.00 Epsilon: 0.96 Steps: 3833
# Episode:  28 Score:  7.0  Average score: 7.24 Best average: 9.00 Epsilon: 0.96 Steps: 3965
# Episode:  29 Score:  6.0  Average score: 7.20 Best average: 9.00 Epsilon: 0.96 Steps: 4074
# Episode:  30 Score:  11.0  Average score: 7.32 Best average: 9.00 Epsilon: 0.96 Steps: 4219
# Episode:  31 Score:  7.0  Average score: 7.31 Best average: 9.00 Epsilon: 0.96 Steps: 4344
# Episode:  32 Score:  5.0  Average score: 7.24 Best average: 9.00 Epsilon: 0.96 Steps: 4449
# Episode:  33 Score:  11.0  Average score: 7.35 Best average: 9.00 Epsilon: 0.95 Steps: 4603
# Episode:  34 Score:  6.0  Average score: 7.31 Best average: 9.00 Epsilon: 0.95 Steps: 4730
# Episode:  35 Score:  7.0  Average score: 7.31 Best average: 9.00 Epsilon: 0.95 Steps: 4821
# Episode:  36 Score:  11.0  Average score: 7.41 Best average: 9.00 Epsilon: 0.95 Steps: 5017
# Episode:  37 Score:  5.0  Average score: 7.34 Best average: 9.00 Epsilon: 0.95 Steps: 5109
# Episode:  38 Score:  6.0  Average score: 7.31 Best average: 9.00 Epsilon: 0.95 Steps: 5216
# Episode:  39 Score:  7.0  Average score: 7.30 Best average: 9.00 Epsilon: 0.95 Steps: 5357
# Episode:  40 Score:  11.0  Average score: 7.39 Best average: 9.00 Epsilon: 0.95 Steps: 5486
# Episode:  41 Score:  7.0  Average score: 7.38 Best average: 9.00 Epsilon: 0.94 Steps: 5628
# Episode:  42 Score:  4.0  Average score: 7.30 Best average: 9.00 Epsilon: 0.94 Steps: 5715
# Episode:  43 Score:  7.0  Average score: 7.30 Best average: 9.00 Epsilon: 0.94 Steps: 5827
# Episode:  44 Score:  9.0  Average score: 7.33 Best average: 9.00 Epsilon: 0.94 Steps: 5947
# Episode:  45 Score:  8.0  Average score: 7.35 Best average: 9.00 Epsilon: 0.94 Steps: 6072
# Episode:  46 Score:  4.0  Average score: 7.28 Best average: 9.00 Epsilon: 0.94 Steps: 6151
# Episode:  47 Score:  12.0  Average score: 7.38 Best average: 9.00 Epsilon: 0.94 Steps: 6348
# Episode:  48 Score:  9.0  Average score: 7.41 Best average: 9.00 Epsilon: 0.94 Steps: 6518
# Episode:  49 Score:  10.0  Average score: 7.46 Best average: 9.00 Epsilon: 0.93 Steps: 6690
# Episode:  50 Score:  6.0  Average score: 7.43 Best average: 9.00 Epsilon: 0.93 Steps: 6790
# Episode:  51 Score:  3.0  Average score: 7.35 Best average: 9.00 Epsilon: 0.93 Steps: 6885
# Episode:  52 Score:  1.0  Average score: 7.23 Best average: 9.00 Epsilon: 0.93 Steps: 6927
# Episode:  53 Score:  8.0  Average score: 7.24 Best average: 9.00 Epsilon: 0.93 Steps: 7086
# Episode:  54 Score:  4.0  Average score: 7.18 Best average: 9.00 Epsilon: 0.93 Steps: 7178
# Episode:  55 Score:  20.0  Average score: 7.41 Best average: 9.00 Epsilon: 0.93 Steps: 7452
# Episode:  56 Score:  8.0  Average score: 7.42 Best average: 9.00 Epsilon: 0.92 Steps: 7559
# Episode:  57 Score:  7.0  Average score: 7.41 Best average: 9.00 Epsilon: 0.92 Steps: 7679
# Episode:  58 Score:  11.0  Average score: 7.47 Best average: 9.00 Epsilon: 0.92 Steps: 7797
# Episode:  59 Score:  18.0  Average score: 7.65 Best average: 9.00 Epsilon: 0.92 Steps: 8057
# Episode:  60 Score:  12.0  Average score: 7.72 Best average: 9.00 Epsilon: 0.92 Steps: 8242
# Episode:  61 Score:  5.0  Average score: 7.68 Best average: 9.00 Epsilon: 0.92 Steps: 8320
# Episode:  62 Score:  11.0  Average score: 7.73 Best average: 9.00 Epsilon: 0.92 Steps: 8459
# Episode:  63 Score:  8.0  Average score: 7.73 Best average: 9.00 Epsilon: 0.91 Steps: 8591
# Episode:  64 Score:  6.0  Average score: 7.71 Best average: 9.00 Epsilon: 0.91 Steps: 8706
# Episode:  65 Score:  7.0  Average score: 7.70 Best average: 9.00 Epsilon: 0.91 Steps: 8806
# Episode:  66 Score:  7.0  Average score: 7.69 Best average: 9.00 Epsilon: 0.91 Steps: 8955
# Episode:  67 Score:  12.0  Average score: 7.75 Best average: 9.00 Epsilon: 0.91 Steps: 9134
# Episode:  68 Score:  15.0  Average score: 7.86 Best average: 9.00 Epsilon: 0.91 Steps: 9323
# Episode:  69 Score:  7.0  Average score: 7.84 Best average: 9.00 Epsilon: 0.91 Steps: 9425
# Episode:  70 Score:  2.0  Average score: 7.76 Best average: 9.00 Epsilon: 0.91 Steps: 9500
# Episode:  71 Score:  9.0  Average score: 7.78 Best average: 9.00 Epsilon: 0.90 Steps: 9645
# Episode:  72 Score:  9.0  Average score: 7.79 Best average: 9.00 Epsilon: 0.90 Steps: 9770
# Episode:  73 Score:  12.0  Average score: 7.85 Best average: 9.00 Epsilon: 0.90 Steps: 9940
# Episode:  74 Score:  10.0  Average score: 7.88 Best average: 9.00 Epsilon: 0.90 Steps: 10132
# Episode:  75 Score:  16.0  Average score: 7.99 Best average: 9.00 Epsilon: 0.90 Steps: 10350
# Episode:  76 Score:  13.0  Average score: 8.05 Best average: 9.00 Epsilon: 0.90 Steps: 10493
# Episode:  77 Score:  8.0  Average score: 8.05 Best average: 9.00 Epsilon: 0.89 Steps: 10626
# Episode:  78 Score:  11.0  Average score: 8.09 Best average: 9.00 Epsilon: 0.89 Steps: 10769
# Episode:  79 Score:  9.0  Average score: 8.10 Best average: 9.00 Epsilon: 0.89 Steps: 10913
# Episode:  80 Score:  6.0  Average score: 8.07 Best average: 9.00 Epsilon: 0.89 Steps: 11022
# Episode:  81 Score:  10.0  Average score: 8.10 Best average: 9.00 Epsilon: 0.89 Steps: 11161
# Episode:  82 Score:  9.0  Average score: 8.11 Best average: 9.00 Epsilon: 0.89 Steps: 11295
# Episode:  83 Score:  3.0  Average score: 8.05 Best average: 9.00 Epsilon: 0.89 Steps: 11384
# Episode:  84 Score:  6.0  Average score: 8.02 Best average: 9.00 Epsilon: 0.89 Steps: 11518
# Episode:  85 Score:  5.0  Average score: 7.99 Best average: 9.00 Epsilon: 0.88 Steps: 11588
# Episode:  86 Score:  7.0  Average score: 7.98 Best average: 9.00 Epsilon: 0.88 Steps: 11728
# Episode:  87 Score:  4.0  Average score: 7.93 Best average: 9.00 Epsilon: 0.88 Steps: 11818
# Episode:  88 Score:  7.0  Average score: 7.92 Best average: 9.00 Epsilon: 0.88 Steps: 11950
# Episode:  89 Score:  6.0  Average score: 7.90 Best average: 9.00 Epsilon: 0.88 Steps: 12077
# Episode:  90 Score:  2.0  Average score: 7.84 Best average: 9.00 Epsilon: 0.88 Steps: 12151
# Episode:  91 Score:  5.0  Average score: 7.80 Best average: 9.00 Epsilon: 0.88 Steps: 12268
# Episode:  92 Score:  15.0  Average score: 7.88 Best average: 9.00 Epsilon: 0.88 Steps: 12505
# Episode:  93 Score:  19.0  Average score: 8.00 Best average: 9.00 Epsilon: 0.87 Steps: 12739
# Episode:  94 Score:  1.0  Average score: 7.93 Best average: 9.00 Epsilon: 0.87 Steps: 12787
# Episode:  95 Score:  14.0  Average score: 7.99 Best average: 9.00 Epsilon: 0.87 Steps: 13020
# Episode:  96 Score:  7.0  Average score: 7.98 Best average: 9.00 Epsilon: 0.87 Steps: 13171
# Episode:  97 Score:  8.0  Average score: 7.98 Best average: 9.00 Epsilon: 0.87 Steps: 13322
# Episode:  98 Score:  14.0  Average score: 8.04 Best average: 9.00 Epsilon: 0.87 Steps: 13478
# Episode:  99 Score:  10.0  Average score: 8.06 Best average: 9.00 Epsilon: 0.86 Steps: 13667
# Episode:  100 Score:  9.0  Average score: 8.06 Best average: 9.00 Epsilon: 0.86 Steps: 13789
# Episode:  101 Score:  7.0  Average score: 8.11 Best average: 9.00 Epsilon: 0.86 Steps: 13949
# Episode:  102 Score:  5.0  Average score: 8.08 Best average: 9.00 Epsilon: 0.86 Steps: 14041
# Episode:  103 Score:  14.0  Average score: 8.09 Best average: 9.00 Epsilon: 0.86 Steps: 14235
# Episode:  104 Score:  6.0  Average score: 8.08 Best average: 9.00 Epsilon: 0.86 Steps: 14344
# Episode:  105 Score:  10.0  Average score: 8.14 Best average: 9.00 Epsilon: 0.86 Steps: 14524
# Episode:  106 Score:  13.0  Average score: 8.19 Best average: 9.00 Epsilon: 0.85 Steps: 14712
# Episode:  107 Score:  3.0  Average score: 8.20 Best average: 9.00 Epsilon: 0.85 Steps: 14797
# Episode:  108 Score:  3.0  Average score: 8.13 Best average: 9.00 Epsilon: 0.85 Steps: 14887
# Episode:  109 Score:  10.0  Average score: 8.13 Best average: 9.00 Epsilon: 0.85 Steps: 15038
# Episode:  110 Score:  8.0  Average score: 8.12 Best average: 9.00 Epsilon: 0.85 Steps: 15169
# Episode:  111 Score:  3.0  Average score: 8.10 Best average: 9.00 Epsilon: 0.85 Steps: 15238
# Episode:  112 Score:  11.0  Average score: 8.12 Best average: 9.00 Epsilon: 0.85 Steps: 15396
# Episode:  113 Score:  8.0  Average score: 8.07 Best average: 9.00 Epsilon: 0.84 Steps: 15577
# Episode:  114 Score:  10.0  Average score: 8.03 Best average: 9.00 Epsilon: 0.84 Steps: 15717
# Episode:  115 Score:  6.0  Average score: 8.02 Best average: 9.00 Epsilon: 0.84 Steps: 15829
# Episode:  116 Score:  13.0  Average score: 8.08 Best average: 9.00 Epsilon: 0.84 Steps: 16002
# Episode:  117 Score:  14.0  Average score: 8.15 Best average: 9.00 Epsilon: 0.84 Steps: 16195
# Episode:  118 Score:  19.0  Average score: 8.27 Best average: 9.00 Epsilon: 0.84 Steps: 16501
# Episode:  119 Score:  8.0  Average score: 8.24 Best average: 9.00 Epsilon: 0.83 Steps: 16643
# Episode:  120 Score:  15.0  Average score: 8.35 Best average: 9.00 Epsilon: 0.83 Steps: 16846
# Episode:  121 Score:  14.0  Average score: 8.43 Best average: 9.00 Epsilon: 0.83 Steps: 17029
# Episode:  122 Score:  24.0  Average score: 8.64 Best average: 9.00 Epsilon: 0.83 Steps: 17299
# Episode:  123 Score:  12.0  Average score: 8.72 Best average: 9.00 Epsilon: 0.83 Steps: 17441
# Episode:  124 Score:  3.0  Average score: 8.69 Best average: 9.00 Epsilon: 0.82 Steps: 17555
# Episode:  125 Score:  3.0  Average score: 8.67 Best average: 9.00 Epsilon: 0.82 Steps: 17648
# Episode:  126 Score:  22.0  Average score: 8.84 Best average: 9.00 Epsilon: 0.82 Steps: 17903
# Episode:  127 Score:  10.0  Average score: 8.86 Best average: 9.00 Epsilon: 0.82 Steps: 18046
# Episode:  128 Score:  6.0  Average score: 8.85 Best average: 9.00 Epsilon: 0.82 Steps: 18122
# Episode:  129 Score:  12.0  Average score: 8.91 Best average: 9.00 Epsilon: 0.82 Steps: 18257
# Episode:  130 Score:  9.0  Average score: 8.89 Best average: 9.00 Epsilon: 0.82 Steps: 18369
# Checkpoint saved at episode  131
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  131 Score:  23.0  Average score: 9.05 Best average: 9.05 Epsilon: 0.81 Steps: 18591
# Episode:  132 Score:  4.0  Average score: 9.04 Best average: 9.05 Epsilon: 0.81 Steps: 18679
# Episode:  133 Score:  8.0  Average score: 9.01 Best average: 9.05 Epsilon: 0.81 Steps: 18780
# Episode:  134 Score:  9.0  Average score: 9.04 Best average: 9.05 Epsilon: 0.81 Steps: 18907
# Episode:  135 Score:  5.0  Average score: 9.02 Best average: 9.05 Epsilon: 0.81 Steps: 18963
# Episode:  136 Score:  11.0  Average score: 9.02 Best average: 9.05 Epsilon: 0.81 Steps: 19094
# Checkpoint saved at episode  137
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  137 Score:  9.0  Average score: 9.06 Best average: 9.06 Epsilon: 0.81 Steps: 19220
# Episode:  138 Score:  6.0  Average score: 9.06 Best average: 9.06 Epsilon: 0.81 Steps: 19326
# Checkpoint saved at episode  139
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  139 Score:  9.0  Average score: 9.08 Best average: 9.08 Epsilon: 0.81 Steps: 19450
# Episode:  140 Score:  6.0  Average score: 9.03 Best average: 9.08 Epsilon: 0.80 Steps: 19553
# Episode:  141 Score:  12.0  Average score: 9.08 Best average: 9.08 Epsilon: 0.80 Steps: 19740
# Checkpoint saved at episode  142
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  142 Score:  14.0  Average score: 9.18 Best average: 9.18 Epsilon: 0.80 Steps: 19950
# Episode:  143 Score:  6.0  Average score: 9.17 Best average: 9.18 Epsilon: 0.80 Steps: 20048
# Checkpoint saved at episode  144
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  144 Score:  15.0  Average score: 9.23 Best average: 9.23 Epsilon: 0.80 Steps: 20242
# Episode:  145 Score:  8.0  Average score: 9.23 Best average: 9.23 Epsilon: 0.80 Steps: 20346
# Checkpoint saved at episode  146
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  146 Score:  15.0  Average score: 9.34 Best average: 9.34 Epsilon: 0.79 Steps: 20587
# Episode:  147 Score:  9.0  Average score: 9.31 Best average: 9.34 Epsilon: 0.79 Steps: 20688
# Checkpoint saved at episode  148
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  148 Score:  21.0  Average score: 9.43 Best average: 9.43 Epsilon: 0.79 Steps: 21018
# Episode:  149 Score:  5.0  Average score: 9.38 Best average: 9.43 Epsilon: 0.79 Steps: 21113
# Checkpoint saved at episode  150
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  150 Score:  13.0  Average score: 9.45 Best average: 9.45 Epsilon: 0.79 Steps: 21279
# Checkpoint saved at episode  151
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  151 Score:  11.0  Average score: 9.53 Best average: 9.53 Epsilon: 0.79 Steps: 21407
# Checkpoint saved at episode  152
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  152 Score:  8.0  Average score: 9.60 Best average: 9.60 Epsilon: 0.78 Steps: 21565
# Checkpoint saved at episode  153
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  153 Score:  16.0  Average score: 9.68 Best average: 9.68 Epsilon: 0.78 Steps: 21787
# Checkpoint saved at episode  154
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  154 Score:  13.0  Average score: 9.77 Best average: 9.77 Epsilon: 0.78 Steps: 21978
# Episode:  155 Score:  6.0  Average score: 9.63 Best average: 9.77 Epsilon: 0.78 Steps: 22101
# Episode:  156 Score:  5.0  Average score: 9.60 Best average: 9.77 Epsilon: 0.78 Steps: 22209
# Episode:  157 Score:  20.0  Average score: 9.73 Best average: 9.77 Epsilon: 0.78 Steps: 22476
# Episode:  158 Score:  8.0  Average score: 9.70 Best average: 9.77 Epsilon: 0.77 Steps: 22607
# Episode:  159 Score:  14.0  Average score: 9.66 Best average: 9.77 Epsilon: 0.77 Steps: 22798
# Episode:  160 Score:  10.0  Average score: 9.64 Best average: 9.77 Epsilon: 0.77 Steps: 22957
# Checkpoint saved at episode  161
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  161 Score:  19.0  Average score: 9.78 Best average: 9.78 Epsilon: 0.77 Steps: 23181
# Episode:  162 Score:  3.0  Average score: 9.70 Best average: 9.78 Epsilon: 0.77 Steps: 23274
# Episode:  163 Score:  7.0  Average score: 9.69 Best average: 9.78 Epsilon: 0.77 Steps: 23391
# Episode:  164 Score:  2.0  Average score: 9.65 Best average: 9.78 Epsilon: 0.77 Steps: 23465
# Episode:  165 Score:  16.0  Average score: 9.74 Best average: 9.78 Epsilon: 0.76 Steps: 23699
# Episode:  166 Score:  4.0  Average score: 9.71 Best average: 9.78 Epsilon: 0.76 Steps: 23783
# Episode:  167 Score:  5.0  Average score: 9.64 Best average: 9.78 Epsilon: 0.76 Steps: 23888
# Episode:  168 Score:  8.0  Average score: 9.57 Best average: 9.78 Epsilon: 0.76 Steps: 24000
# Episode:  169 Score:  8.0  Average score: 9.58 Best average: 9.78 Epsilon: 0.76 Steps: 24137
# Episode:  170 Score:  12.0  Average score: 9.68 Best average: 9.78 Epsilon: 0.76 Steps: 24320
# Episode:  171 Score:  19.0  Average score: 9.78 Best average: 9.78 Epsilon: 0.75 Steps: 24541
# Checkpoint saved at episode  172
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  172 Score:  18.0  Average score: 9.87 Best average: 9.87 Epsilon: 0.75 Steps: 24738
# Episode:  173 Score:  9.0  Average score: 9.84 Best average: 9.87 Epsilon: 0.75 Steps: 24865
# Episode:  174 Score:  12.0  Average score: 9.86 Best average: 9.87 Epsilon: 0.75 Steps: 25069
# Episode:  175 Score:  7.0  Average score: 9.77 Best average: 9.87 Epsilon: 0.75 Steps: 25168
# Episode:  176 Score:  18.0  Average score: 9.82 Best average: 9.87 Epsilon: 0.75 Steps: 25407
# Checkpoint saved at episode  177
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  177 Score:  16.0  Average score: 9.90 Best average: 9.90 Epsilon: 0.74 Steps: 25599
# Episode:  178 Score:  6.0  Average score: 9.85 Best average: 9.90 Epsilon: 0.74 Steps: 25717
# Episode:  179 Score:  13.0  Average score: 9.89 Best average: 9.90 Epsilon: 0.74 Steps: 25879
# Episode:  180 Score:  6.0  Average score: 9.89 Best average: 9.90 Epsilon: 0.74 Steps: 25990
# Episode:  181 Score:  8.0  Average score: 9.87 Best average: 9.90 Epsilon: 0.74 Steps: 26121
# Checkpoint saved at episode  182
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  182 Score:  14.0  Average score: 9.92 Best average: 9.92 Epsilon: 0.74 Steps: 26280
# Checkpoint saved at episode  183
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  183 Score:  12.0  Average score: 10.01 Best average: 10.01 Epsilon: 0.74 Steps: 26417
# Checkpoint saved at episode  184
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  184 Score:  11.0  Average score: 10.06 Best average: 10.06 Epsilon: 0.73 Steps: 26565
# Episode:  185 Score:  5.0  Average score: 10.06 Best average: 10.06 Epsilon: 0.73 Steps: 26667
# Episode:  186 Score:  7.0  Average score: 10.06 Best average: 10.06 Epsilon: 0.73 Steps: 26783
# Checkpoint saved at episode  187
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  187 Score:  12.0  Average score: 10.14 Best average: 10.14 Epsilon: 0.73 Steps: 26954
# Checkpoint saved at episode  188
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  188 Score:  9.0  Average score: 10.16 Best average: 10.16 Epsilon: 0.73 Steps: 27094
# Checkpoint saved at episode  189
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  189 Score:  8.0  Average score: 10.18 Best average: 10.18 Epsilon: 0.73 Steps: 27217
# Checkpoint saved at episode  190
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  190 Score:  10.0  Average score: 10.26 Best average: 10.26 Epsilon: 0.73 Steps: 27345
# Checkpoint saved at episode  191
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  191 Score:  15.0  Average score: 10.36 Best average: 10.36 Epsilon: 0.72 Steps: 27595
# Episode:  192 Score:  3.0  Average score: 10.24 Best average: 10.36 Epsilon: 0.72 Steps: 27674
# Episode:  193 Score:  15.0  Average score: 10.20 Best average: 10.36 Epsilon: 0.72 Steps: 27849
# Episode:  194 Score:  5.0  Average score: 10.24 Best average: 10.36 Epsilon: 0.72 Steps: 27940
# Episode:  195 Score:  13.0  Average score: 10.23 Best average: 10.36 Epsilon: 0.72 Steps: 28130
# Episode:  196 Score:  8.0  Average score: 10.24 Best average: 10.36 Epsilon: 0.72 Steps: 28254
# Episode:  197 Score:  7.0  Average score: 10.23 Best average: 10.36 Epsilon: 0.72 Steps: 28377
# Episode:  198 Score:  10.0  Average score: 10.19 Best average: 10.36 Epsilon: 0.72 Steps: 28482
# Episode:  199 Score:  6.0  Average score: 10.15 Best average: 10.36 Epsilon: 0.71 Steps: 28610
# Episode:  200 Score:  13.0  Average score: 10.19 Best average: 10.36 Epsilon: 0.71 Steps: 28808
# Episode:  201 Score:  21.0  Average score: 10.33 Best average: 10.36 Epsilon: 0.71 Steps: 29057
# Checkpoint saved at episode  202
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  202 Score:  12.0  Average score: 10.40 Best average: 10.40 Epsilon: 0.71 Steps: 29197
# Episode:  203 Score:  14.0  Average score: 10.40 Best average: 10.40 Epsilon: 0.71 Steps: 29384
# Checkpoint saved at episode  204
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  204 Score:  17.0  Average score: 10.51 Best average: 10.51 Epsilon: 0.70 Steps: 29563
# Episode:  205 Score:  6.0  Average score: 10.47 Best average: 10.51 Epsilon: 0.70 Steps: 29693
# Episode:  206 Score:  15.0  Average score: 10.49 Best average: 10.51 Epsilon: 0.70 Steps: 29863
# Checkpoint saved at episode  207
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  207 Score:  13.0  Average score: 10.59 Best average: 10.59 Epsilon: 0.70 Steps: 30039
# Checkpoint saved at episode  208
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  208 Score:  14.0  Average score: 10.70 Best average: 10.70 Epsilon: 0.70 Steps: 30209
# Checkpoint saved at episode  209
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  209 Score:  15.0  Average score: 10.75 Best average: 10.75 Epsilon: 0.70 Steps: 30384
# Checkpoint saved at episode  210
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  210 Score:  9.0  Average score: 10.76 Best average: 10.76 Epsilon: 0.70 Steps: 30498
# Checkpoint saved at episode  211
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  211 Score:  14.0  Average score: 10.87 Best average: 10.87 Epsilon: 0.69 Steps: 30690
# Checkpoint saved at episode  212
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  212 Score:  14.0  Average score: 10.90 Best average: 10.90 Epsilon: 0.69 Steps: 30877
# Checkpoint saved at episode  213
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  213 Score:  10.0  Average score: 10.92 Best average: 10.92 Epsilon: 0.69 Steps: 31030
# Checkpoint saved at episode  214
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  214 Score:  12.0  Average score: 10.94 Best average: 10.94 Epsilon: 0.69 Steps: 31189
# Episode:  215 Score:  4.0  Average score: 10.92 Best average: 10.94 Epsilon: 0.69 Steps: 31256
# Checkpoint saved at episode  216
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  216 Score:  20.0  Average score: 10.99 Best average: 10.99 Epsilon: 0.69 Steps: 31472
# Episode:  217 Score:  11.0  Average score: 10.96 Best average: 10.99 Epsilon: 0.68 Steps: 31596
# Episode:  218 Score:  8.0  Average score: 10.85 Best average: 10.99 Epsilon: 0.68 Steps: 31707
# Episode:  219 Score:  9.0  Average score: 10.86 Best average: 10.99 Epsilon: 0.68 Steps: 31855
# Episode:  220 Score:  16.0  Average score: 10.87 Best average: 10.99 Epsilon: 0.68 Steps: 32060
# Episode:  221 Score:  17.0  Average score: 10.90 Best average: 10.99 Epsilon: 0.68 Steps: 32311
# Episode:  222 Score:  12.0  Average score: 10.78 Best average: 10.99 Epsilon: 0.68 Steps: 32494
# Episode:  223 Score:  16.0  Average score: 10.82 Best average: 10.99 Epsilon: 0.67 Steps: 32672
# Episode:  224 Score:  13.0  Average score: 10.92 Best average: 10.99 Epsilon: 0.67 Steps: 32802
# Checkpoint saved at episode  225
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  225 Score:  17.0  Average score: 11.06 Best average: 11.06 Epsilon: 0.67 Steps: 33024
# Episode:  226 Score:  5.0  Average score: 10.89 Best average: 11.06 Epsilon: 0.67 Steps: 33100
# Episode:  227 Score:  18.0  Average score: 10.97 Best average: 11.06 Epsilon: 0.67 Steps: 33328
# Checkpoint saved at episode  228
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  228 Score:  32.0  Average score: 11.23 Best average: 11.23 Epsilon: 0.66 Steps: 33795
# Episode:  229 Score:  12.0  Average score: 11.23 Best average: 11.23 Epsilon: 0.66 Steps: 33963
# Episode:  230 Score:  8.0  Average score: 11.22 Best average: 11.23 Epsilon: 0.66 Steps: 34051
# Episode:  231 Score:  8.0  Average score: 11.07 Best average: 11.23 Epsilon: 0.66 Steps: 34154
# Checkpoint saved at episode  232
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  232 Score:  22.0  Average score: 11.25 Best average: 11.25 Epsilon: 0.66 Steps: 34412
# Checkpoint saved at episode  233
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  233 Score:  13.0  Average score: 11.30 Best average: 11.30 Epsilon: 0.65 Steps: 34607
# Episode:  234 Score:  8.0  Average score: 11.29 Best average: 11.30 Epsilon: 0.65 Steps: 34729
# Checkpoint saved at episode  235
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  235 Score:  14.0  Average score: 11.38 Best average: 11.38 Epsilon: 0.65 Steps: 34912
# Episode:  236 Score:  7.0  Average score: 11.34 Best average: 11.38 Epsilon: 0.65 Steps: 35010
# Checkpoint saved at episode  237
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  237 Score:  15.0  Average score: 11.40 Best average: 11.40 Epsilon: 0.65 Steps: 35188
# Episode:  238 Score:  4.0  Average score: 11.38 Best average: 11.40 Epsilon: 0.65 Steps: 35252
# Episode:  239 Score:  9.0  Average score: 11.38 Best average: 11.40 Epsilon: 0.65 Steps: 35355
# Checkpoint saved at episode  240
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  240 Score:  17.0  Average score: 11.49 Best average: 11.49 Epsilon: 0.65 Steps: 35531
# Checkpoint saved at episode  241
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  241 Score:  14.0  Average score: 11.51 Best average: 11.51 Epsilon: 0.64 Steps: 35697
# Episode:  242 Score:  11.0  Average score: 11.48 Best average: 11.51 Epsilon: 0.64 Steps: 35855
# Episode:  243 Score:  3.0  Average score: 11.45 Best average: 11.51 Epsilon: 0.64 Steps: 35923
# Episode:  244 Score:  17.0  Average score: 11.47 Best average: 11.51 Epsilon: 0.64 Steps: 36130
# Episode:  245 Score:  11.0  Average score: 11.50 Best average: 11.51 Epsilon: 0.64 Steps: 36278
# Checkpoint saved at episode  246
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  246 Score:  18.0  Average score: 11.53 Best average: 11.53 Epsilon: 0.64 Steps: 36495
# Episode:  247 Score:  5.0  Average score: 11.49 Best average: 11.53 Epsilon: 0.63 Steps: 36562
# Episode:  248 Score:  5.0  Average score: 11.33 Best average: 11.53 Epsilon: 0.63 Steps: 36638
# Episode:  249 Score:  10.0  Average score: 11.38 Best average: 11.53 Epsilon: 0.63 Steps: 36768
# Episode:  250 Score:  16.0  Average score: 11.41 Best average: 11.53 Epsilon: 0.63 Steps: 36964
# Episode:  251 Score:  18.0  Average score: 11.48 Best average: 11.53 Epsilon: 0.63 Steps: 37176
# Checkpoint saved at episode  252
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  252 Score:  18.0  Average score: 11.58 Best average: 11.58 Epsilon: 0.63 Steps: 37453
# Episode:  253 Score:  11.0  Average score: 11.53 Best average: 11.58 Epsilon: 0.62 Steps: 37631
# Checkpoint saved at episode  254
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  254 Score:  19.0  Average score: 11.59 Best average: 11.59 Epsilon: 0.62 Steps: 37899
# Checkpoint saved at episode  255
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  255 Score:  15.0  Average score: 11.68 Best average: 11.68 Epsilon: 0.62 Steps: 38070
# Checkpoint saved at episode  256
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  256 Score:  19.0  Average score: 11.82 Best average: 11.82 Epsilon: 0.62 Steps: 38302
# Episode:  257 Score:  8.0  Average score: 11.70 Best average: 11.82 Epsilon: 0.62 Steps: 38433
# Episode:  258 Score:  12.0  Average score: 11.74 Best average: 11.82 Epsilon: 0.61 Steps: 38578
# Episode:  259 Score:  14.0  Average score: 11.74 Best average: 11.82 Epsilon: 0.61 Steps: 38746
# Episode:  260 Score:  7.0  Average score: 11.71 Best average: 11.82 Epsilon: 0.61 Steps: 38842
# Episode:  261 Score:  5.0  Average score: 11.57 Best average: 11.82 Epsilon: 0.61 Steps: 38932
# Episode:  262 Score:  8.0  Average score: 11.62 Best average: 11.82 Epsilon: 0.61 Steps: 39034
# Episode:  263 Score:  14.0  Average score: 11.69 Best average: 11.82 Epsilon: 0.61 Steps: 39241
# Episode:  264 Score:  13.0  Average score: 11.80 Best average: 11.82 Epsilon: 0.61 Steps: 39427
# Checkpoint saved at episode  265
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  265 Score:  24.0  Average score: 11.88 Best average: 11.88 Epsilon: 0.60 Steps: 39723
# Checkpoint saved at episode  266
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  266 Score:  7.0  Average score: 11.91 Best average: 11.91 Epsilon: 0.60 Steps: 39840
# Checkpoint saved at episode  267
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  267 Score:  16.0  Average score: 12.02 Best average: 12.02 Epsilon: 0.60 Steps: 40029
# Checkpoint saved at episode  268
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  268 Score:  14.0  Average score: 12.08 Best average: 12.08 Epsilon: 0.60 Steps: 40180
# Checkpoint saved at episode  269
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  269 Score:  14.0  Average score: 12.14 Best average: 12.14 Epsilon: 0.60 Steps: 40334
# Episode:  270 Score:  2.0  Average score: 12.04 Best average: 12.14 Epsilon: 0.60 Steps: 40411
# Episode:  271 Score:  17.0  Average score: 12.02 Best average: 12.14 Epsilon: 0.59 Steps: 40628
# Episode:  272 Score:  18.0  Average score: 12.02 Best average: 12.14 Epsilon: 0.59 Steps: 40871
# Checkpoint saved at episode  273
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  273 Score:  24.0  Average score: 12.17 Best average: 12.17 Epsilon: 0.59 Steps: 41129
# Checkpoint saved at episode  274
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  274 Score:  17.0  Average score: 12.22 Best average: 12.22 Epsilon: 0.59 Steps: 41323
# Checkpoint saved at episode  275
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  275 Score:  8.0  Average score: 12.23 Best average: 12.23 Epsilon: 0.59 Steps: 41423
# Episode:  276 Score:  13.0  Average score: 12.18 Best average: 12.23 Epsilon: 0.58 Steps: 41607
# Episode:  277 Score:  6.0  Average score: 12.08 Best average: 12.23 Epsilon: 0.58 Steps: 41707
# Episode:  278 Score:  19.0  Average score: 12.21 Best average: 12.23 Epsilon: 0.58 Steps: 41919
# Checkpoint saved at episode  279
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  279 Score:  17.0  Average score: 12.25 Best average: 12.25 Epsilon: 0.58 Steps: 42123
# Episode:  280 Score:  3.0  Average score: 12.22 Best average: 12.25 Epsilon: 0.58 Steps: 42203
# Checkpoint saved at episode  281
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  281 Score:  17.0  Average score: 12.31 Best average: 12.31 Epsilon: 0.58 Steps: 42408
# Checkpoint saved at episode  282
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  282 Score:  18.0  Average score: 12.35 Best average: 12.35 Epsilon: 0.57 Steps: 42605
# Episode:  283 Score:  12.0  Average score: 12.35 Best average: 12.35 Epsilon: 0.57 Steps: 42750
# Checkpoint saved at episode  284
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  284 Score:  13.0  Average score: 12.37 Best average: 12.37 Epsilon: 0.57 Steps: 42952
# Checkpoint saved at episode  285
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  285 Score:  6.0  Average score: 12.38 Best average: 12.38 Epsilon: 0.57 Steps: 43061
# Checkpoint saved at episode  286
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  286 Score:  22.0  Average score: 12.53 Best average: 12.53 Epsilon: 0.57 Steps: 43295
# Episode:  287 Score:  12.0  Average score: 12.53 Best average: 12.53 Epsilon: 0.57 Steps: 43468
# Episode:  288 Score:  8.0  Average score: 12.52 Best average: 12.53 Epsilon: 0.56 Steps: 43597
# Checkpoint saved at episode  289
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  289 Score:  18.0  Average score: 12.62 Best average: 12.62 Epsilon: 0.56 Steps: 43808
# Checkpoint saved at episode  290
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  290 Score:  22.0  Average score: 12.74 Best average: 12.74 Epsilon: 0.56 Steps: 44071
# Episode:  291 Score:  15.0  Average score: 12.74 Best average: 12.74 Epsilon: 0.56 Steps: 44273
# Checkpoint saved at episode  292
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  292 Score:  13.0  Average score: 12.84 Best average: 12.84 Epsilon: 0.56 Steps: 44411
# Checkpoint saved at episode  293
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  293 Score:  16.0  Average score: 12.85 Best average: 12.85 Epsilon: 0.55 Steps: 44608
# Checkpoint saved at episode  294
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  294 Score:  14.0  Average score: 12.94 Best average: 12.94 Epsilon: 0.55 Steps: 44792
# Episode:  295 Score:  10.0  Average score: 12.91 Best average: 12.94 Epsilon: 0.55 Steps: 44941
# Episode:  296 Score:  11.0  Average score: 12.94 Best average: 12.94 Epsilon: 0.55 Steps: 45057
# Checkpoint saved at episode  297
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  297 Score:  8.0  Average score: 12.95 Best average: 12.95 Epsilon: 0.55 Steps: 45170
# Episode:  298 Score:  8.0  Average score: 12.93 Best average: 12.95 Epsilon: 0.55 Steps: 45269
# Checkpoint saved at episode  299
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  299 Score:  16.0  Average score: 13.03 Best average: 13.03 Epsilon: 0.55 Steps: 45482
# Episode:  300 Score:  8.0  Average score: 12.98 Best average: 13.03 Epsilon: 0.54 Steps: 45610
# Episode:  301 Score:  18.0  Average score: 12.95 Best average: 13.03 Epsilon: 0.54 Steps: 45819
# Episode:  302 Score:  6.0  Average score: 12.89 Best average: 13.03 Epsilon: 0.54 Steps: 45940
# Episode:  303 Score:  12.0  Average score: 12.87 Best average: 13.03 Epsilon: 0.54 Steps: 46130
# Episode:  304 Score:  12.0  Average score: 12.82 Best average: 13.03 Epsilon: 0.54 Steps: 46270
# Episode:  305 Score:  18.0  Average score: 12.94 Best average: 13.03 Epsilon: 0.54 Steps: 46522
# Episode:  306 Score:  16.0  Average score: 12.95 Best average: 13.03 Epsilon: 0.53 Steps: 46702
# Episode:  307 Score:  19.0  Average score: 13.01 Best average: 13.03 Epsilon: 0.53 Steps: 46943
# Episode:  308 Score:  12.0  Average score: 12.99 Best average: 13.03 Epsilon: 0.53 Steps: 47101
# Checkpoint saved at episode  309
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  309 Score:  25.0  Average score: 13.09 Best average: 13.09 Epsilon: 0.53 Steps: 47349
# Checkpoint saved at episode  310
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  310 Score:  13.0  Average score: 13.13 Best average: 13.13 Epsilon: 0.53 Steps: 47514
# Episode:  311 Score:  14.0  Average score: 13.13 Best average: 13.13 Epsilon: 0.52 Steps: 47664
# Episode:  312 Score:  14.0  Average score: 13.13 Best average: 13.13 Epsilon: 0.52 Steps: 47836
# Checkpoint saved at episode  313
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  313 Score:  22.0  Average score: 13.25 Best average: 13.25 Epsilon: 0.52 Steps: 48103
# Checkpoint saved at episode  314
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  314 Score:  14.0  Average score: 13.27 Best average: 13.27 Epsilon: 0.52 Steps: 48254
# Checkpoint saved at episode  315
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  315 Score:  21.0  Average score: 13.44 Best average: 13.44 Epsilon: 0.52 Steps: 48528
# Episode:  316 Score:  15.0  Average score: 13.39 Best average: 13.44 Epsilon: 0.51 Steps: 48743
# Checkpoint saved at episode  317
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  317 Score:  24.0  Average score: 13.52 Best average: 13.52 Epsilon: 0.51 Steps: 49046
# Checkpoint saved at episode  318
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  318 Score:  17.0  Average score: 13.61 Best average: 13.61 Epsilon: 0.51 Steps: 49209
# Checkpoint saved at episode  319
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  319 Score:  14.0  Average score: 13.66 Best average: 13.66 Epsilon: 0.51 Steps: 49359
# Episode:  320 Score:  11.0  Average score: 13.61 Best average: 13.66 Epsilon: 0.51 Steps: 49490
# Episode:  321 Score:  17.0  Average score: 13.61 Best average: 13.66 Epsilon: 0.50 Steps: 49690
# Checkpoint saved at episode  322
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  322 Score:  19.0  Average score: 13.68 Best average: 13.68 Epsilon: 0.50 Steps: 49866
# Episode:  323 Score:  10.0  Average score: 13.62 Best average: 13.68 Epsilon: 0.50 Steps: 49988
# Episode:  324 Score:  14.0  Average score: 13.63 Best average: 13.68 Epsilon: 0.50 Steps: 50166
# Episode:  325 Score:  14.0  Average score: 13.60 Best average: 13.68 Epsilon: 0.50 Steps: 50327
# Episode:  326 Score:  10.0  Average score: 13.65 Best average: 13.68 Epsilon: 0.50 Steps: 50417
# Episode:  327 Score:  12.0  Average score: 13.59 Best average: 13.68 Epsilon: 0.49 Steps: 50565
# Episode:  328 Score:  14.0  Average score: 13.41 Best average: 13.68 Epsilon: 0.49 Steps: 50709
# Episode:  329 Score:  7.0  Average score: 13.36 Best average: 13.68 Epsilon: 0.49 Steps: 50815
# Episode:  330 Score:  11.0  Average score: 13.39 Best average: 13.68 Epsilon: 0.49 Steps: 50975
# Episode:  331 Score:  8.0  Average score: 13.39 Best average: 13.68 Epsilon: 0.49 Steps: 51093
# Episode:  332 Score:  17.0  Average score: 13.34 Best average: 13.68 Epsilon: 0.49 Steps: 51267
# Episode:  333 Score:  27.0  Average score: 13.48 Best average: 13.68 Epsilon: 0.48 Steps: 51642
# Episode:  334 Score:  8.0  Average score: 13.48 Best average: 13.68 Epsilon: 0.48 Steps: 51760
# Episode:  335 Score:  15.0  Average score: 13.49 Best average: 13.68 Epsilon: 0.48 Steps: 51950
# Episode:  336 Score:  23.0  Average score: 13.65 Best average: 13.68 Epsilon: 0.48 Steps: 52215
# Episode:  337 Score:  15.0  Average score: 13.65 Best average: 13.68 Epsilon: 0.48 Steps: 52403
# Episode:  338 Score:  6.0  Average score: 13.67 Best average: 13.68 Epsilon: 0.48 Steps: 52486
# Checkpoint saved at episode  339
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  339 Score:  14.0  Average score: 13.72 Best average: 13.72 Epsilon: 0.47 Steps: 52665
# Episode:  340 Score:  13.0  Average score: 13.68 Best average: 13.72 Epsilon: 0.47 Steps: 52828
# Episode:  341 Score:  17.0  Average score: 13.71 Best average: 13.72 Epsilon: 0.47 Steps: 53015
# Checkpoint saved at episode  342
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  342 Score:  20.0  Average score: 13.80 Best average: 13.80 Epsilon: 0.47 Steps: 53216
# Checkpoint saved at episode  343
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  343 Score:  14.0  Average score: 13.91 Best average: 13.91 Epsilon: 0.47 Steps: 53405
# Episode:  344 Score:  7.0  Average score: 13.81 Best average: 13.91 Epsilon: 0.47 Steps: 53516
# Episode:  345 Score:  16.0  Average score: 13.86 Best average: 13.91 Epsilon: 0.46 Steps: 53701
# Episode:  346 Score:  19.0  Average score: 13.87 Best average: 13.91 Epsilon: 0.46 Steps: 53921
# Checkpoint saved at episode  347
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  347 Score:  19.0  Average score: 14.01 Best average: 14.01 Epsilon: 0.46 Steps: 54187
# Checkpoint saved at episode  348
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  348 Score:  18.0  Average score: 14.14 Best average: 14.14 Epsilon: 0.46 Steps: 54389
# Checkpoint saved at episode  349
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  349 Score:  17.0  Average score: 14.21 Best average: 14.21 Epsilon: 0.45 Steps: 54570
# Episode:  350 Score:  11.0  Average score: 14.16 Best average: 14.21 Epsilon: 0.45 Steps: 54721
# Episode:  351 Score:  22.0  Average score: 14.20 Best average: 14.21 Epsilon: 0.45 Steps: 54961
# Episode:  352 Score:  14.0  Average score: 14.16 Best average: 14.21 Epsilon: 0.45 Steps: 55135
# Episode:  353 Score:  15.0  Average score: 14.20 Best average: 14.21 Epsilon: 0.45 Steps: 55328
# Episode:  354 Score:  20.0  Average score: 14.21 Best average: 14.21 Epsilon: 0.44 Steps: 55555
# Checkpoint saved at episode  355
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  355 Score:  17.0  Average score: 14.23 Best average: 14.23 Epsilon: 0.44 Steps: 55769
# Episode:  356 Score:  9.0  Average score: 14.13 Best average: 14.23 Epsilon: 0.44 Steps: 55928
# Episode:  357 Score:  10.0  Average score: 14.15 Best average: 14.23 Epsilon: 0.44 Steps: 56086
# Episode:  358 Score:  12.0  Average score: 14.15 Best average: 14.23 Epsilon: 0.44 Steps: 56282
# Episode:  359 Score:  18.0  Average score: 14.19 Best average: 14.23 Epsilon: 0.44 Steps: 56494
# Checkpoint saved at episode  360
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  360 Score:  15.0  Average score: 14.27 Best average: 14.27 Epsilon: 0.43 Steps: 56675
# Checkpoint saved at episode  361
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  361 Score:  9.0  Average score: 14.31 Best average: 14.31 Epsilon: 0.43 Steps: 56795
# Checkpoint saved at episode  362
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  362 Score:  13.0  Average score: 14.36 Best average: 14.36 Epsilon: 0.43 Steps: 56968
# Checkpoint saved at episode  363
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  363 Score:  17.0  Average score: 14.39 Best average: 14.39 Epsilon: 0.43 Steps: 57220
# Episode:  364 Score:  9.0  Average score: 14.35 Best average: 14.39 Epsilon: 0.43 Steps: 57329
# Episode:  365 Score:  13.0  Average score: 14.24 Best average: 14.39 Epsilon: 0.43 Steps: 57450
# Episode:  366 Score:  13.0  Average score: 14.30 Best average: 14.39 Epsilon: 0.42 Steps: 57619
# Episode:  367 Score:  13.0  Average score: 14.27 Best average: 14.39 Epsilon: 0.42 Steps: 57815
# Episode:  368 Score:  11.0  Average score: 14.24 Best average: 14.39 Epsilon: 0.42 Steps: 57966
# Episode:  369 Score:  10.0  Average score: 14.20 Best average: 14.39 Epsilon: 0.42 Steps: 58132
# Episode:  370 Score:  12.0  Average score: 14.30 Best average: 14.39 Epsilon: 0.42 Steps: 58267
# Episode:  371 Score:  5.0  Average score: 14.18 Best average: 14.39 Epsilon: 0.42 Steps: 58352
# Episode:  372 Score:  12.0  Average score: 14.12 Best average: 14.39 Epsilon: 0.42 Steps: 58499
# Episode:  373 Score:  18.0  Average score: 14.06 Best average: 14.39 Epsilon: 0.41 Steps: 58744
# Episode:  374 Score:  12.0  Average score: 14.01 Best average: 14.39 Epsilon: 0.41 Steps: 58940
# Episode:  375 Score:  7.0  Average score: 14.00 Best average: 14.39 Epsilon: 0.41 Steps: 59037
# Episode:  376 Score:  11.0  Average score: 13.98 Best average: 14.39 Epsilon: 0.41 Steps: 59156
# Episode:  377 Score:  23.0  Average score: 14.15 Best average: 14.39 Epsilon: 0.41 Steps: 59402
# Episode:  378 Score:  14.0  Average score: 14.10 Best average: 14.39 Epsilon: 0.40 Steps: 59560
# Episode:  379 Score:  13.0  Average score: 14.06 Best average: 14.39 Epsilon: 0.40 Steps: 59716
# Episode:  380 Score:  12.0  Average score: 14.15 Best average: 14.39 Epsilon: 0.40 Steps: 59889
# Episode:  381 Score:  12.0  Average score: 14.10 Best average: 14.39 Epsilon: 0.40 Steps: 60050
# Episode:  382 Score:  11.0  Average score: 14.03 Best average: 14.39 Epsilon: 0.40 Steps: 60206
# Episode:  383 Score:  22.0  Average score: 14.13 Best average: 14.39 Epsilon: 0.40 Steps: 60436
# Episode:  384 Score:  8.0  Average score: 14.08 Best average: 14.39 Epsilon: 0.39 Steps: 60534
# Episode:  385 Score:  17.0  Average score: 14.19 Best average: 14.39 Epsilon: 0.39 Steps: 60722
# Episode:  386 Score:  21.0  Average score: 14.18 Best average: 14.39 Epsilon: 0.39 Steps: 60941
# Episode:  387 Score:  10.0  Average score: 14.16 Best average: 14.39 Epsilon: 0.39 Steps: 61089
# Episode:  388 Score:  14.0  Average score: 14.22 Best average: 14.39 Epsilon: 0.39 Steps: 61267
# Episode:  389 Score:  9.0  Average score: 14.13 Best average: 14.39 Epsilon: 0.39 Steps: 61388
# Episode:  390 Score:  18.0  Average score: 14.09 Best average: 14.39 Epsilon: 0.38 Steps: 61600
# Episode:  391 Score:  23.0  Average score: 14.17 Best average: 14.39 Epsilon: 0.38 Steps: 61865
# Episode:  392 Score:  17.0  Average score: 14.21 Best average: 14.39 Epsilon: 0.38 Steps: 62090
# Episode:  393 Score:  18.0  Average score: 14.23 Best average: 14.39 Epsilon: 0.38 Steps: 62281
# Episode:  394 Score:  14.0  Average score: 14.23 Best average: 14.39 Epsilon: 0.38 Steps: 62418
# Episode:  395 Score:  13.0  Average score: 14.26 Best average: 14.39 Epsilon: 0.37 Steps: 62574
# Episode:  396 Score:  18.0  Average score: 14.33 Best average: 14.39 Epsilon: 0.37 Steps: 62764
# Checkpoint saved at episode  397
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  397 Score:  20.0  Average score: 14.45 Best average: 14.45 Epsilon: 0.37 Steps: 62994
# Checkpoint saved at episode  398
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  398 Score:  13.0  Average score: 14.50 Best average: 14.50 Epsilon: 0.37 Steps: 63148
# Episode:  399 Score:  13.0  Average score: 14.47 Best average: 14.50 Epsilon: 0.37 Steps: 63298
# Checkpoint saved at episode  400
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  400 Score:  18.0  Average score: 14.57 Best average: 14.57 Epsilon: 0.37 Steps: 63529
# Episode:  401 Score:  7.0  Average score: 14.46 Best average: 14.57 Epsilon: 0.36 Steps: 63627
# Episode:  402 Score:  12.0  Average score: 14.52 Best average: 14.57 Epsilon: 0.36 Steps: 63753
# Episode:  403 Score:  14.0  Average score: 14.54 Best average: 14.57 Epsilon: 0.36 Steps: 63907
# Episode:  404 Score:  9.0  Average score: 14.51 Best average: 14.57 Epsilon: 0.36 Steps: 64030
# Episode:  405 Score:  17.0  Average score: 14.50 Best average: 14.57 Epsilon: 0.36 Steps: 64296
# Episode:  406 Score:  9.0  Average score: 14.43 Best average: 14.57 Epsilon: 0.36 Steps: 64396
# Episode:  407 Score:  25.0  Average score: 14.49 Best average: 14.57 Epsilon: 0.35 Steps: 64683
# Episode:  408 Score:  9.0  Average score: 14.46 Best average: 14.57 Epsilon: 0.35 Steps: 64836
# Episode:  409 Score:  19.0  Average score: 14.40 Best average: 14.57 Epsilon: 0.35 Steps: 65056
# Episode:  410 Score:  9.0  Average score: 14.36 Best average: 14.57 Epsilon: 0.35 Steps: 65194
# Episode:  411 Score:  12.0  Average score: 14.34 Best average: 14.57 Epsilon: 0.35 Steps: 65317
# Episode:  412 Score:  13.0  Average score: 14.33 Best average: 14.57 Epsilon: 0.35 Steps: 65472
# Episode:  413 Score:  14.0  Average score: 14.25 Best average: 14.57 Epsilon: 0.34 Steps: 65623
# Episode:  414 Score:  23.0  Average score: 14.34 Best average: 14.57 Epsilon: 0.34 Steps: 65863
# Episode:  415 Score:  21.0  Average score: 14.34 Best average: 14.57 Epsilon: 0.34 Steps: 66079
# Episode:  416 Score:  16.0  Average score: 14.35 Best average: 14.57 Epsilon: 0.34 Steps: 66263
# Episode:  417 Score:  14.0  Average score: 14.25 Best average: 14.57 Epsilon: 0.34 Steps: 66464
# Episode:  418 Score:  21.0  Average score: 14.29 Best average: 14.57 Epsilon: 0.33 Steps: 66705
# Episode:  419 Score:  15.0  Average score: 14.30 Best average: 14.57 Epsilon: 0.33 Steps: 66886
# Episode:  420 Score:  22.0  Average score: 14.41 Best average: 14.57 Epsilon: 0.33 Steps: 67114
# Episode:  421 Score:  21.0  Average score: 14.45 Best average: 14.57 Epsilon: 0.33 Steps: 67370
# Episode:  422 Score:  8.0  Average score: 14.34 Best average: 14.57 Epsilon: 0.33 Steps: 67476
# Episode:  423 Score:  17.0  Average score: 14.41 Best average: 14.57 Epsilon: 0.32 Steps: 67665
# Episode:  424 Score:  17.0  Average score: 14.44 Best average: 14.57 Epsilon: 0.32 Steps: 67862
# Episode:  425 Score:  8.0  Average score: 14.38 Best average: 14.57 Epsilon: 0.32 Steps: 67943
# ...
# Episode:  1841 Score:  27.0  Average score: 19.82 Best average: 20.44 Epsilon: 0.10 Steps: 352633
# Episode:  1842 Score:  25.0  Average score: 19.96 Best average: 20.44 Epsilon: 0.10 Steps: 352851
# Episode:  1843 Score:  16.0  Average score: 19.95 Best average: 20.44 Epsilon: 0.10 Steps: 353041
# Episode:  1844 Score:  28.0  Average score: 20.00 Best average: 20.44 Epsilon: 0.10 Steps: 353362
# Episode:  1845 Score:  23.0  Average score: 20.06 Best average: 20.44 Epsilon: 0.10 Steps: 353624
# Episode:  1846 Score:  12.0  Average score: 19.88 Best average: 20.44 Epsilon: 0.10 Steps: 353779
# Episode:  1847 Score:  11.0  Average score: 19.82 Best average: 20.44 Epsilon: 0.10 Steps: 353922
# Episode:  1848 Score:  20.0  Average score: 19.93 Best average: 20.44 Epsilon: 0.10 Steps: 354137
# Episode:  1849 Score:  17.0  Average score: 19.94 Best average: 20.44 Epsilon: 0.10 Steps: 354340
# Episode:  1850 Score:  16.0  Average score: 19.88 Best average: 20.44 Epsilon: 0.10 Steps: 354501
# Episode:  1851 Score:  5.0  Average score: 19.83 Best average: 20.44 Epsilon: 0.10 Steps: 354588
# Episode:  1852 Score:  20.0  Average score: 19.80 Best average: 20.44 Epsilon: 0.10 Steps: 354821
# Episode:  1853 Score:  17.0  Average score: 19.83 Best average: 20.44 Epsilon: 0.10 Steps: 354998
# Episode:  1854 Score:  25.0  Average score: 19.83 Best average: 20.44 Epsilon: 0.10 Steps: 355275
# Episode:  1855 Score:  23.0  Average score: 19.87 Best average: 20.44 Epsilon: 0.10 Steps: 355529
# Episode:  1856 Score:  22.0  Average score: 19.86 Best average: 20.44 Epsilon: 0.10 Steps: 355763
# Episode:  1857 Score:  22.0  Average score: 19.87 Best average: 20.44 Epsilon: 0.10 Steps: 355987
# Episode:  1858 Score:  10.0  Average score: 19.71 Best average: 20.44 Epsilon: 0.10 Steps: 356097
# Episode:  1859 Score:  19.0  Average score: 19.72 Best average: 20.44 Epsilon: 0.10 Steps: 356277
# Episode:  1860 Score:  15.0  Average score: 19.75 Best average: 20.44 Epsilon: 0.10 Steps: 356411
# Episode:  1861 Score:  19.0  Average score: 19.78 Best average: 20.44 Epsilon: 0.10 Steps: 356620
# Episode:  1862 Score:  17.0  Average score: 19.74 Best average: 20.44 Epsilon: 0.10 Steps: 356785
# Episode:  1863 Score:  12.0  Average score: 19.62 Best average: 20.44 Epsilon: 0.10 Steps: 356924
# Episode:  1864 Score:  15.0  Average score: 19.55 Best average: 20.44 Epsilon: 0.10 Steps: 357109
# Episode:  1865 Score:  13.0  Average score: 19.57 Best average: 20.44 Epsilon: 0.10 Steps: 357244
# Episode:  1866 Score:  20.0  Average score: 19.49 Best average: 20.44 Epsilon: 0.10 Steps: 357460
# Episode:  1867 Score:  29.0  Average score: 19.53 Best average: 20.44 Epsilon: 0.10 Steps: 357765
# Episode:  1868 Score:  21.0  Average score: 19.52 Best average: 20.44 Epsilon: 0.10 Steps: 357980
# Episode:  1869 Score:  16.0  Average score: 19.42 Best average: 20.44 Epsilon: 0.10 Steps: 358157
# Episode:  1870 Score:  8.0  Average score: 19.30 Best average: 20.44 Epsilon: 0.10 Steps: 358281
# Episode:  1871 Score:  22.0  Average score: 19.21 Best average: 20.44 Epsilon: 0.10 Steps: 358490
# Episode:  1872 Score:  21.0  Average score: 19.28 Best average: 20.44 Epsilon: 0.10 Steps: 358714
# Episode:  1873 Score:  26.0  Average score: 19.30 Best average: 20.44 Epsilon: 0.10 Steps: 358975
# Episode:  1874 Score:  22.0  Average score: 19.28 Best average: 20.44 Epsilon: 0.10 Steps: 359215
# Episode:  1875 Score:  13.0  Average score: 19.30 Best average: 20.44 Epsilon: 0.10 Steps: 359377
# Episode:  1876 Score:  11.0  Average score: 19.21 Best average: 20.44 Epsilon: 0.10 Steps: 359514
# Episode:  1877 Score:  19.0  Average score: 19.19 Best average: 20.44 Epsilon: 0.10 Steps: 359730
# Episode:  1878 Score:  29.0  Average score: 19.33 Best average: 20.44 Epsilon: 0.10 Steps: 360090
# Episode:  1879 Score:  18.0  Average score: 19.33 Best average: 20.44 Epsilon: 0.10 Steps: 360258
# Episode:  1880 Score:  15.0  Average score: 19.26 Best average: 20.44 Epsilon: 0.10 Steps: 360397
# Episode:  1881 Score:  14.0  Average score: 19.18 Best average: 20.44 Epsilon: 0.10 Steps: 360547
# Episode:  1882 Score:  22.0  Average score: 19.16 Best average: 20.44 Epsilon: 0.10 Steps: 360791
# Episode:  1883 Score:  18.0  Average score: 19.23 Best average: 20.44 Epsilon: 0.10 Steps: 360973
# Episode:  1884 Score:  19.0  Average score: 19.23 Best average: 20.44 Epsilon: 0.10 Steps: 361159
# Episode:  1885 Score:  18.0  Average score: 19.21 Best average: 20.44 Epsilon: 0.10 Steps: 361327
# Episode:  1886 Score:  17.0  Average score: 19.19 Best average: 20.44 Epsilon: 0.10 Steps: 361477
# Episode:  1887 Score:  13.0  Average score: 19.08 Best average: 20.44 Epsilon: 0.10 Steps: 361605
# Episode:  1888 Score:  24.0  Average score: 19.12 Best average: 20.44 Epsilon: 0.10 Steps: 361843
# Episode:  1889 Score:  20.0  Average score: 19.11 Best average: 20.44 Epsilon: 0.10 Steps: 362062
# Episode:  1890 Score:  24.0  Average score: 19.07 Best average: 20.44 Epsilon: 0.10 Steps: 362367
# Episode:  1891 Score:  26.0  Average score: 19.16 Best average: 20.44 Epsilon: 0.10 Steps: 362613
# Episode:  1892 Score:  19.0  Average score: 19.15 Best average: 20.44 Epsilon: 0.10 Steps: 362813
# Episode:  1893 Score:  29.0  Average score: 19.30 Best average: 20.44 Epsilon: 0.10 Steps: 363118
# Episode:  1894 Score:  27.0  Average score: 19.46 Best average: 20.44 Epsilon: 0.10 Steps: 363450
# Episode:  1895 Score:  33.0  Average score: 19.63 Best average: 20.44 Epsilon: 0.10 Steps: 363800
# Episode:  1896 Score:  21.0  Average score: 19.60 Best average: 20.44 Epsilon: 0.10 Steps: 364031
# Episode:  1897 Score:  24.0  Average score: 19.65 Best average: 20.44 Epsilon: 0.10 Steps: 364256
# Episode:  1898 Score:  12.0  Average score: 19.54 Best average: 20.44 Epsilon: 0.10 Steps: 364366
# Episode:  1899 Score:  21.0  Average score: 19.55 Best average: 20.44 Epsilon: 0.10 Steps: 364560
# Episode:  1900 Score:  14.0  Average score: 19.51 Best average: 20.44 Epsilon: 0.10 Steps: 364689
# Episode:  1901 Score:  19.0  Average score: 19.58 Best average: 20.44 Epsilon: 0.10 Steps: 364881
# Episode:  1902 Score:  17.0  Average score: 19.51 Best average: 20.44 Epsilon: 0.10 Steps: 365079
# Episode:  1903 Score:  15.0  Average score: 19.48 Best average: 20.44 Epsilon: 0.10 Steps: 365270
# Episode:  1904 Score:  17.0  Average score: 19.25 Best average: 20.44 Epsilon: 0.10 Steps: 365451
# Episode:  1905 Score:  16.0  Average score: 19.19 Best average: 20.44 Epsilon: 0.10 Steps: 365600
# Episode:  1906 Score:  25.0  Average score: 19.34 Best average: 20.44 Epsilon: 0.10 Steps: 365880
# Episode:  1907 Score:  23.0  Average score: 19.42 Best average: 20.44 Epsilon: 0.10 Steps: 366103
# Episode:  1908 Score:  18.0  Average score: 19.43 Best average: 20.44 Epsilon: 0.10 Steps: 366278
# Episode:  1909 Score:  11.0  Average score: 19.33 Best average: 20.44 Epsilon: 0.10 Steps: 366420
# Episode:  1910 Score:  29.0  Average score: 19.32 Best average: 20.44 Epsilon: 0.10 Steps: 366718
# Episode:  1911 Score:  23.0  Average score: 19.34 Best average: 20.44 Epsilon: 0.10 Steps: 366944
# Episode:  1912 Score:  18.0  Average score: 19.29 Best average: 20.44 Epsilon: 0.10 Steps: 367128
# Episode:  1913 Score:  20.0  Average score: 19.34 Best average: 20.44 Epsilon: 0.10 Steps: 367322
# Episode:  1914 Score:  22.0  Average score: 19.37 Best average: 20.44 Epsilon: 0.10 Steps: 367577
# Episode:  1915 Score:  20.0  Average score: 19.35 Best average: 20.44 Epsilon: 0.10 Steps: 367801
# Episode:  1916 Score:  18.0  Average score: 19.27 Best average: 20.44 Epsilon: 0.10 Steps: 368006
# Episode:  1917 Score:  23.0  Average score: 19.37 Best average: 20.44 Epsilon: 0.10 Steps: 368237
# Episode:  1918 Score:  21.0  Average score: 19.34 Best average: 20.44 Epsilon: 0.10 Steps: 368471
# Episode:  1919 Score:  27.0  Average score: 19.48 Best average: 20.44 Epsilon: 0.10 Steps: 368795
# Episode:  1920 Score:  20.0  Average score: 19.54 Best average: 20.44 Epsilon: 0.10 Steps: 369021
# Episode:  1921 Score:  20.0  Average score: 19.62 Best average: 20.44 Epsilon: 0.10 Steps: 369237
# Episode:  1922 Score:  18.0  Average score: 19.66 Best average: 20.44 Epsilon: 0.10 Steps: 369439
# Episode:  1923 Score:  23.0  Average score: 19.70 Best average: 20.44 Epsilon: 0.10 Steps: 369672
# Episode:  1924 Score:  16.0  Average score: 19.66 Best average: 20.44 Epsilon: 0.10 Steps: 369863
# Episode:  1925 Score:  26.0  Average score: 19.69 Best average: 20.44 Epsilon: 0.10 Steps: 370144
# Episode:  1926 Score:  12.0  Average score: 19.57 Best average: 20.44 Epsilon: 0.10 Steps: 370277
# Episode:  1927 Score:  12.0  Average score: 19.48 Best average: 20.44 Epsilon: 0.10 Steps: 370417
# Episode:  1928 Score:  25.0  Average score: 19.50 Best average: 20.44 Epsilon: 0.10 Steps: 370709
# Episode:  1929 Score:  16.0  Average score: 19.45 Best average: 20.44 Epsilon: 0.10 Steps: 370886
# Episode:  1930 Score:  17.0  Average score: 19.47 Best average: 20.44 Epsilon: 0.10 Steps: 371091
# Episode:  1931 Score:  16.0  Average score: 19.45 Best average: 20.44 Epsilon: 0.10 Steps: 371237
# Episode:  1932 Score:  22.0  Average score: 19.51 Best average: 20.44 Epsilon: 0.10 Steps: 371474
# Episode:  1933 Score:  22.0  Average score: 19.60 Best average: 20.44 Epsilon: 0.10 Steps: 371736
# Episode:  1934 Score:  17.0  Average score: 19.54 Best average: 20.44 Epsilon: 0.10 Steps: 371940
# Episode:  1935 Score:  26.0  Average score: 19.56 Best average: 20.44 Epsilon: 0.10 Steps: 372246
# Episode:  1936 Score:  27.0  Average score: 19.65 Best average: 20.44 Epsilon: 0.10 Steps: 372536
# Episode:  1937 Score:  35.0  Average score: 19.72 Best average: 20.44 Epsilon: 0.10 Steps: 372933
# Episode:  1938 Score:  23.0  Average score: 19.73 Best average: 20.44 Epsilon: 0.10 Steps: 373182
# Episode:  1939 Score:  11.0  Average score: 19.65 Best average: 20.44 Epsilon: 0.10 Steps: 373303
# Episode:  1940 Score:  12.0  Average score: 19.52 Best average: 20.44 Epsilon: 0.10 Steps: 373428
# Episode:  1941 Score:  31.0  Average score: 19.56 Best average: 20.44 Epsilon: 0.10 Steps: 373763
# Episode:  1942 Score:  20.0  Average score: 19.51 Best average: 20.44 Epsilon: 0.10 Steps: 373978
# Episode:  1943 Score:  23.0  Average score: 19.58 Best average: 20.44 Epsilon: 0.10 Steps: 374182
# Episode:  1944 Score:  18.0  Average score: 19.48 Best average: 20.44 Epsilon: 0.10 Steps: 374353
# Episode:  1945 Score:  28.0  Average score: 19.53 Best average: 20.44 Epsilon: 0.10 Steps: 374635
# Episode:  1946 Score:  22.0  Average score: 19.63 Best average: 20.44 Epsilon: 0.10 Steps: 374842
# Episode:  1947 Score:  23.0  Average score: 19.75 Best average: 20.44 Epsilon: 0.10 Steps: 375120
# Episode:  1948 Score:  25.0  Average score: 19.80 Best average: 20.44 Epsilon: 0.10 Steps: 375403
# Episode:  1949 Score:  22.0  Average score: 19.85 Best average: 20.44 Epsilon: 0.10 Steps: 375663
# Episode:  1950 Score:  19.0  Average score: 19.88 Best average: 20.44 Epsilon: 0.10 Steps: 375847
# Episode:  1951 Score:  29.0  Average score: 20.12 Best average: 20.44 Epsilon: 0.10 Steps: 376156
# Episode:  1952 Score:  20.0  Average score: 20.12 Best average: 20.44 Epsilon: 0.10 Steps: 376383
# Episode:  1953 Score:  18.0  Average score: 20.13 Best average: 20.44 Epsilon: 0.10 Steps: 376592
# Episode:  1954 Score:  14.0  Average score: 20.02 Best average: 20.44 Epsilon: 0.10 Steps: 376726
# Episode:  1955 Score:  17.0  Average score: 19.96 Best average: 20.44 Epsilon: 0.10 Steps: 376899
# Episode:  1956 Score:  20.0  Average score: 19.94 Best average: 20.44 Epsilon: 0.10 Steps: 377089
# Episode:  1957 Score:  21.0  Average score: 19.93 Best average: 20.44 Epsilon: 0.10 Steps: 377296
# Episode:  1958 Score:  17.0  Average score: 20.00 Best average: 20.44 Epsilon: 0.10 Steps: 377469
# Episode:  1959 Score:  20.0  Average score: 20.01 Best average: 20.44 Epsilon: 0.10 Steps: 377670
# Episode:  1960 Score:  17.0  Average score: 20.03 Best average: 20.44 Epsilon: 0.10 Steps: 377835
# Episode:  1961 Score:  14.0  Average score: 19.98 Best average: 20.44 Epsilon: 0.10 Steps: 377962
# Episode:  1962 Score:  23.0  Average score: 20.04 Best average: 20.44 Epsilon: 0.10 Steps: 378175
# Episode:  1963 Score:  28.0  Average score: 20.20 Best average: 20.44 Epsilon: 0.10 Steps: 378466
# Episode:  1964 Score:  21.0  Average score: 20.26 Best average: 20.44 Epsilon: 0.10 Steps: 378665
# Episode:  1965 Score:  30.0  Average score: 20.43 Best average: 20.44 Epsilon: 0.10 Steps: 378971
# Episode:  1966 Score:  18.0  Average score: 20.41 Best average: 20.44 Epsilon: 0.10 Steps: 379169
# Episode:  1967 Score:  16.0  Average score: 20.28 Best average: 20.44 Epsilon: 0.10 Steps: 379350
# Episode:  1968 Score:  22.0  Average score: 20.29 Best average: 20.44 Epsilon: 0.10 Steps: 379591
# Episode:  1969 Score:  19.0  Average score: 20.32 Best average: 20.44 Epsilon: 0.10 Steps: 379786
# Episode:  1970 Score:  20.0  Average score: 20.44 Best average: 20.44 Epsilon: 0.10 Steps: 380005
# Checkpoint saved at episode  1971
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1971 Score:  23.0  Average score: 20.45 Best average: 20.45 Epsilon: 0.10 Steps: 380248
# Episode:  1972 Score:  19.0  Average score: 20.43 Best average: 20.45 Epsilon: 0.10 Steps: 380423
# Episode:  1973 Score:  15.0  Average score: 20.32 Best average: 20.45 Epsilon: 0.10 Steps: 380579
# Episode:  1974 Score:  11.0  Average score: 20.21 Best average: 20.45 Epsilon: 0.10 Steps: 380689
# Episode:  1975 Score:  31.0  Average score: 20.39 Best average: 20.45 Epsilon: 0.10 Steps: 381046
# Checkpoint saved at episode  1976
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1976 Score:  20.0  Average score: 20.48 Best average: 20.48 Epsilon: 0.10 Steps: 381240
# Episode:  1977 Score:  18.0  Average score: 20.47 Best average: 20.48 Epsilon: 0.10 Steps: 381437
# Episode:  1978 Score:  11.0  Average score: 20.29 Best average: 20.48 Epsilon: 0.10 Steps: 381558
# Episode:  1979 Score:  17.0  Average score: 20.28 Best average: 20.48 Epsilon: 0.10 Steps: 381743
# Episode:  1980 Score:  17.0  Average score: 20.30 Best average: 20.48 Epsilon: 0.10 Steps: 381890
# Episode:  1981 Score:  13.0  Average score: 20.29 Best average: 20.48 Epsilon: 0.10 Steps: 382030
# Episode:  1982 Score:  22.0  Average score: 20.29 Best average: 20.48 Epsilon: 0.10 Steps: 382267
# Episode:  1983 Score:  25.0  Average score: 20.36 Best average: 20.48 Epsilon: 0.10 Steps: 382547
# Episode:  1984 Score:  14.0  Average score: 20.31 Best average: 20.48 Epsilon: 0.10 Steps: 382705
# Episode:  1985 Score:  30.0  Average score: 20.43 Best average: 20.48 Epsilon: 0.10 Steps: 383029
# Checkpoint saved at episode  1986
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1986 Score:  29.0  Average score: 20.55 Best average: 20.55 Epsilon: 0.10 Steps: 383370
# Checkpoint saved at episode  1987
# ... saving checkpoint ...
# ... saving checkpoint ...
# Episode:  1987 Score:  32.0  Average score: 20.74 Best average: 20.74 Epsilon: 0.10 Steps: 383736
# Episode:  1988 Score:  18.0  Average score: 20.68 Best average: 20.74 Epsilon: 0.10 Steps: 383965
# Episode:  1989 Score:  13.0  Average score: 20.61 Best average: 20.74 Epsilon: 0.10 Steps: 384104
# Episode:  1990 Score:  13.0  Average score: 20.50 Best average: 20.74 Epsilon: 0.10 Steps: 384235
# Episode:  1991 Score:  24.0  Average score: 20.48 Best average: 20.74 Epsilon: 0.10 Steps: 384485
# Episode:  1992 Score:  17.0  Average score: 20.46 Best average: 20.74 Epsilon: 0.10 Steps: 384651
# Episode:  1993 Score:  22.0  Average score: 20.39 Best average: 20.74 Epsilon: 0.10 Steps: 384874
# Episode:  1994 Score:  17.0  Average score: 20.29 Best average: 20.74 Epsilon: 0.10 Steps: 385118
# Episode:  1995 Score:  25.0  Average score: 20.21 Best average: 20.74 Epsilon: 0.10 Steps: 385381
# Episode:  1996 Score:  13.0  Average score: 20.13 Best average: 20.74 Epsilon: 0.10 Steps: 385547
# Episode:  1997 Score:  22.0  Average score: 20.11 Best average: 20.74 Epsilon: 0.10 Steps: 385785
# Episode:  1998 Score:  26.0  Average score: 20.25 Best average: 20.74 Epsilon: 0.10 Steps: 386074
# Episode:  1999 Score:  18.0  Average score: 20.22 Best average: 20.74 Epsilon: 0.10 Steps: 386253

# %%
x = [i+1 for i in range(len(scores))]
plot_learning_curve(x, scores, eps_history, figure_file)

# %% [markdown]
# ## Evaluation
#
# Finally, let's visualize our agent's performance, and play a game within the gym environment itself.

# %%
#Visualization cobe for running within Colab

# Install dependencies first for graphics visualization within Colaboratory

#remove " > /dev/null 2>&1" to see what is going on under the hood
"""
# !pip install gym pyvirtualdisplay > /dev/null 2>&1
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1

# !apt-get update > /dev/null 2>&1
# !apt-get install cmake > /dev/null 2>&1
# !pip install --upgrade setuptools 2>&1
# !pip install ez_setup > /dev/null 2>&1

"""
# Out:
# '\n!pip install gym pyvirtualdisplay > /dev/null 2>&1\n!apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1\n\n!apt-get update > /dev/null 2>&1\n!apt-get install cmake > /dev/null 2>&1\n!pip install --upgrade setuptools 2>&1\n!pip install ez_setup > /dev/null 2>&1\n\n'

# %%
#To Evaluate model on OpenAI gym, we will record a video via Ipython display



from gym import logger as gymlogger
from gym.wrappers import Monitor
gymlogger.set_level(40) #error only

import numpy as np
import random
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import glob
import io
import base64
from IPython.display import HTML

from IPython import display as ipythondisplay


from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()

# %%
"""
shape = (84,84,1)
new_shape = (shape[2], shape[0], shape[1])
print(new_shape[1:])
#1,84,84

new_frame = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)
resized_screen = cv2.resize(new_frame, self.shape[1:],
                                    interpolation=cv2.INTER_AREA)
new_obs = np.array(resized_screen, dtype=np.uint8).reshape(self.shape)
new_obs = new_obs / 255.0
"""
# Out:
# '\nshape = (84,84,1)\nnew_shape = (shape[2], shape[0], shape[1])\nprint(new_shape[1:])\n#1,84,84\n\nnew_frame = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)\nresized_screen = cv2.resize(new_frame, self.shape[1:],\n                                    interpolation=cv2.INTER_AREA)\nnew_obs = np.array(resized_screen, dtype=np.uint8).reshape(self.shape)\nnew_obs = new_obs / 255.0\n'

# %%
class PreprocessFrameEval(gym.ObservationWrapper):
  #set shape by swapping channels axis
	#set observation space to new shape using gym.spaces.Box (0 to 1.0)
    def __init__(self, shape, env=None):
        super(PreprocessFrameEval, self).__init__(env)
        self.shape = (shape[2], shape[0], shape[1])
        self.observation_space = gym.spaces.Box(low=0.0, high=1.0,
                                    shape=self.shape, dtype=np.float32)

    def observation(self, obs):
        img_array.append(obs)
        new_frame = cv2.cvtColor(obs, cv2.COLOR_RGB2GRAY)
        resized_screen = cv2.resize(new_frame, self.shape[1:],
                                    interpolation=cv2.INTER_AREA)
        new_obs = np.array(resized_screen, dtype=np.uint8).reshape(self.shape)
        new_obs = new_obs / 255.0

        return new_obs



def make_envEVAL(env_name, shape=(84,84,1), repeat=4, clip_rewards=False,
             no_ops=0, fire_first=False):
    env = gym.make(env_name)
    env = PreprocessFrameEval(shape, env)
    env = RepeatActionAndMaxFrame(env, repeat, clip_rewards, no_ops, fire_first)
    
    env = StackFrames(env, repeat)

    return env

# %%
env = make_envEVAL('VizdoomDefendLine-v0')

n_outputs = env.action_space.n
print(n_outputs)

img_array=[]

observation = env.reset()

#if load_checkpoint:
  #agent.load_models()


for i in range(2):
  done = False
  observation = env.reset()
  
  
  score = 0
  while not done:
    
    action = agent.choose_action(observation)
    observation_, reward, done, info = env.step(action)
    
    
    #img_array.append(observation)
# Out:
# 3

# %%
print(len(img_array))

for i in range(22):
  
  if i > 20:
    print(img_array[i].shape)
    plt.imshow(img_array[i])
    plt.show()
# Out:
# 1007
# (240, 320, 3)

# %%
#!pip install sk-video

# %%
from random import choice
import cv2 
from google.colab.patches import cv2_imshow
from torchvision.io import write_video

import numpy as np


out_video =  np.empty([len(img_array), 240, 320, 3], dtype = np.uint8)
out_video =  out_video.astype(np.uint8)

for i in range(len(img_array)):
  frame = img_array[i]
  out_video[i] = frame
# Writes the the output image sequences in a video file

write_video("/content/doom.mp4", out_video, 25, video_codec='libx264', options=None)
#skvideo.io.vwrite("/content/doom.mp4", out_video)
